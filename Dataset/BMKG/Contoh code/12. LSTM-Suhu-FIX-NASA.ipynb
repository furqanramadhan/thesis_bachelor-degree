# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
df = pd.read_csv("nasa1.csv", index_col='Tanggal', parse_dates=True)
df.index.freq = 'D'

# %%
df.head
# Out:
# <bound method NDFrame.head of              Suhu  Kelembaban  Curah_Hujan
# Tanggal
# 2011-01-01  26.02       81.94        10.95
# 2011-01-02  25.93       84.81         6.97
# 2011-01-03  26.10       80.88         4.85
# 2011-01-04  25.73       80.56         9.94
# 2011-01-05  25.60       84.00         5.04
# ...           ...         ...          ...
# 2024-10-27  27.44       79.94         2.33
# 2024-10-28  27.52       79.69         1.27
# 2024-10-29  27.20       80.50         1.39
# 2024-10-30  27.35       79.31         1.97
# 2024-10-31  27.82       75.31         0.41
#
# [5053 rows x 3 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5053 entries, 2011-01-01 to 2024-10-31
# Freq: D
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Suhu         5050 non-null   float64
#  1   Kelembaban   5050 non-null   float64
#  2   Curah_Hujan  5050 non-null   float64
# dtypes: float64(3)
# memory usage: 157.9 KB

# %%
df.describe()
# Out:
#               Suhu   Kelembaban  Curah_Hujan
# count  5050.000000  5050.000000  5050.000000
# mean     26.990713    79.178727     6.194432
# std       0.826380     4.462853    10.158024
# min      24.370000    63.690000     0.000000
# 25%      26.410000    76.250000     0.740000
# 50%      26.950000    79.250000     2.665000
# 75%      27.550000    82.250000     7.060000
# max      30.070000    92.000000   149.120000

# %%
# Mengisi data kosong dengan mean dari masing-masing kolom
cols_to_fill = ['Curah_Hujan', 'Kelembaban', 'Suhu']  # Kolom target

for col in cols_to_fill:
    mean_value = df[col].mean()  # Menghitung mean dari kolom
    df[col] = df[col].fillna(mean_value)  # Mengisi nilai kosong dengan mean

print(df)
# Out:
#              Suhu  Kelembaban  Curah_Hujan
# Tanggal
# 2011-01-01  26.02       81.94        10.95
# 2011-01-02  25.93       84.81         6.97
# 2011-01-03  26.10       80.88         4.85
# 2011-01-04  25.73       80.56         9.94
# 2011-01-05  25.60       84.00         5.04
# ...           ...         ...          ...
# 2024-10-27  27.44       79.94         2.33
# 2024-10-28  27.52       79.69         1.27
# 2024-10-29  27.20       80.50         1.39
# 2024-10-30  27.35       79.31         1.97
# 2024-10-31  27.82       75.31         0.41
#
# [5053 rows x 3 columns]

# %%
df.describe()
# Out:
#               Suhu   Kelembaban  Curah_Hujan
# count  5053.000000  5053.000000  5053.000000
# mean     26.990713    79.178727     6.194432
# std       0.826134     4.461528    10.155008
# min      24.370000    63.690000     0.000000
# 25%      26.410000    76.250000     0.740000
# 50%      26.950000    79.250000     2.670000
# 75%      27.550000    82.250000     7.060000
# max      30.070000    92.000000   149.120000

# %%
from sklearn.preprocessing import StandardScaler
# === Step 2: Standardization ===
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df[['Suhu']])

# === Step 3: Create Sequences for LSTM ===
sequence_length = 700  # Menggunakan 60 hari terakhir untuk memprediksi
X, y = [], []
for i in range(sequence_length, len(data_scaled)):
    X.append(data_scaled[i-sequence_length:i])
    y.append(data_scaled[i])

X, y = np.array(X), np.array(y)

# Split data (80% train, 20% test)
train_size = int(len(X) * 0.9)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# === Step 4: Build LSTM Model ===
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(1)  # Output layer untuk satu langkah prediksi
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 123/123 [==============================] - 80s 613ms/step - loss: 0.4618 - val_loss: 0.4435
# Epoch 2/100
# 123/123 [==============================] - 75s 613ms/step - loss: 0.3757 - val_loss: 0.3522
# Epoch 3/100
# 123/123 [==============================] - 75s 612ms/step - loss: 0.3369 - val_loss: 0.3388
# Epoch 4/100
# 123/123 [==============================] - 76s 619ms/step - loss: 0.3152 - val_loss: 0.3160
# Epoch 5/100
# 123/123 [==============================] - 77s 628ms/step - loss: 0.2999 - val_loss: 0.3029
# Epoch 6/100
# 123/123 [==============================] - 77s 629ms/step - loss: 0.2982 - val_loss: 0.3063
# Epoch 7/100
# 123/123 [==============================] - 77s 629ms/step - loss: 0.2957 - val_loss: 0.3158
# Epoch 8/100
# 123/123 [==============================] - 77s 629ms/step - loss: 0.2949 - val_loss: 0.2998
# Epoch 9/100
# 123/123 [==============================] - 77s 627ms/step - loss: 0.2967 - val_loss: 0.3051
# Epoch 10/100
# 123/123 [==============================] - 77s 630ms/step - loss: 0.2990 - val_loss: 0.3132
# Epoch 11/100
# 123/123 [==============================] - 77s 630ms/step - loss: 0.2940 - val_loss: 0.3065
# Epoch 12/100
# 123/123 [==============================] - 79s 642ms/step - loss: 0.2965 - val_loss: 0.3210
# Epoch 13/100
# 123/123 [==============================] - 77s 630ms/step - loss: 0.2907 - val_loss: 0.3208
# Epoch 14/100
# 123/123 [==============================] - 77s 629ms/step - loss: 0.2930 - val_loss: 0.3066
# Epoch 15/100
# 123/123 [==============================] - 77s 626ms/step - loss: 0.2940 - val_loss: 0.3038
# Epoch 16/100
# 123/123 [==============================] - 77s 626ms/step - loss: 0.2904 - val_loss: 0.3067
# Epoch 17/100
# 123/123 [==============================] - 77s 629ms/step - loss: 0.2929 - val_loss: 0.3010
# Epoch 18/100
# 123/123 [==============================] - 78s 631ms/step - loss: 0.2920 - val_loss: 0.3099

# %%
# Plot training history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# %%
forecast = []
current_sequence = data_scaled[-sequence_length:].copy()  # Ambil sequence terakhir dari data

for i in range(365):
    # Prediksi langkah berikutnya
    pred = model.predict(current_sequence[np.newaxis, :, :], verbose=0)
    forecast.append(pred.flatten()[0])

    # Teacher forcing: tambahkan nilai aktual jika tersedia
    if i < len(y_test):
        current_sequence = np.append(current_sequence[1:], y_test[i]).reshape(-1, 1)
    else:
        current_sequence = np.append(current_sequence[1:], pred).reshape(-1, 1)

# Inverse scaling
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1))

# %%
# === Step 6: Visualize Results ===
forecast_dates = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=365)
forecast_df = pd.DataFrame({'Date': forecast_dates, 'Forecast': forecast.flatten()})
forecast_df.set_index('Date', inplace=True)

# Combine historical data and forecast
df_combined = pd.concat([df, forecast_df])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(df_combined.index, df_combined['Suhu'], label='Data Historis')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Peramalan', color='red')
plt.title('Data Historis dan 365-hari Peramalan Suhu Udara')
plt.legend()
plt.show()

# %%
forecast_df
# Out:
#              Forecast
# Date
# 2024-11-01  27.622120
# 2024-11-02  28.004936
# 2024-11-03  27.960382
# 2024-11-04  27.877375
# 2024-11-05  27.973124
# ...               ...
# 2025-10-27  27.839745
# 2025-10-28  27.450315
# 2025-10-29  26.864367
# 2025-10-30  27.004841
# 2025-10-31  27.705336
#
# [365 rows x 1 columns]

# %%
#forecast_df.to_csv('D:/cool/TA/data/forecast_results.csv', index=False)

# %%
# Step 1: Filter data aktual tahun 2024
df_2024 = df[df.index.year == 2024]

# Step 2: Gabungkan data aktual tahun 2024 dan hasil forecast
# Data aktual berhenti di akhir tahun 2023, sehingga prediksi forecast dimulai di tahun 2024
combined_forecast = pd.concat([df_2024, forecast_df], axis=0)

# Step 3: Visualisasi
plt.figure(figsize=(12, 6))
plt.plot(df_2024.index, df_2024.iloc[:, 0], label="Data Aktual Tahun 2024", color='blue')
plt.plot(forecast_df.index, forecast_df['Forecast'], label="Permalan 365 hari kedepan", color='red')

# Tambahkan judul dan label
plt.title("Data Aktual 2024 dan Peramalan Suhu Udara Menggunakan LSTM")
plt.xlabel("Tanggal")
plt.ylabel("Nilai")
plt.legend()

# Tampilkan plot
plt.show()

# %%
# === Step 2: Scaling Data ===
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(df[['Suhu']])

# === Step 3: Create Sequences for LSTM ===
sequence_length =   # Menggunakan 30 hari terakhir untuk memprediksi
X, y = [], []
for i in range(sequence_length, len(data_scaled)):
    X.append(data_scaled[i-sequence_length:i])
    y.append(data_scaled[i])

X, y = np.array(X), np.array(y)

# Split data (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# Create the LSTM model
model = Sequential()

# Add LSTM layers with dropout
model.add(LSTM(units=128, input_shape=(train_x.shape[1], train_x.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=64, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=32, return_sequences=False))
model.add(Dropout(0.2))

# Add a dense output layer
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# === Step 4: Build LSTM Model ===
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(365)
])

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 126/126 [==============================] - 9s 36ms/step - loss: 0.0407 - val_loss: 0.0115
# Epoch 2/100
# 126/126 [==============================] - 4s 29ms/step - loss: 0.0132 - val_loss: 0.0098
# Epoch 3/100
# 126/126 [==============================] - 4s 28ms/step - loss: 0.0115 - val_loss: 0.0095
# Epoch 4/100
# 126/126 [==============================] - 4s 29ms/step - loss: 0.0109 - val_loss: 0.0087
# Epoch 5/100
# 126/126 [==============================] - 4s 29ms/step - loss: 0.0101 - val_loss: 0.0082
# Epoch 6/100
# 126/126 [==============================] - 4s 29ms/step - loss: 0.0093 - val_loss: 0.0075
# Epoch 7/100
# 126/126 [==============================] - 3s 27ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 8/100
# 126/126 [==============================] - 4s 28ms/step - loss: 0.0088 - val_loss: 0.0080
# Epoch 9/100
# 126/126 [==============================] - 3s 28ms/step - loss: 0.0082 - val_loss: 0.0071
# Epoch 10/100
# 126/126 [==============================] - 3s 27ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 11/100
# 126/126 [==============================] - 4s 29ms/step - loss: 0.0079 - val_loss: 0.0065
# Epoch 12/100
# 126/126 [==============================] - 4s 28ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 13/100
# 126/126 [==============================] - 4s 28ms/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 14/100
# 126/126 [==============================] - 3s 28ms/step - loss: 0.0073 - val_loss: 0.0066
# Epoch 15/100
# 126/126 [==============================] - 3s 28ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 16/100
# 126/126 [==============================] - 3s 27ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 17/100
# 126/126 [==============================] - 3s 27ms/step - loss: 0.0071 - val_loss: 0.0065
# Epoch 18/100
# 126/126 [==============================] - 4s 29ms/step - loss: 0.0071 - val_loss: 0.0065
# Epoch 19/100
# 126/126 [==============================] - 3s 27ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 20/100
# 126/126 [==============================] - 3s 27ms/step - loss: 0.0069 - val_loss: 0.0073
# Epoch 21/100
# 126/126 [==============================] - 4s 28ms/step - loss: 0.0069 - val_loss: 0.0065
# Epoch 22/100
# 126/126 [==============================] - 3s 28ms/step - loss: 0.0071 - val_loss: 0.0068
# Epoch 23/100
# 126/126 [==============================] - 4s 28ms/step - loss: 0.0069 - val_loss: 0.0064

# %%
# Plot training history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# %%
# Recursive Forecasting
forecast = []
current_sequence = last_sequence.copy()

for _ in range(365):
    pred = model.predict(current_sequence[np.newaxis, :, :], verbose=0)
    forecast.append(pred.flatten()[0])
    # Update sequence with the predicted value
    current_sequence = np.append(current_sequence[1:], pred).reshape(-1, 1)

# Inverse scaling
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1))

# Create forecast dataframe
forecast_dates = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=365)
forecast_df = pd.DataFrame({'Date': forecast_dates, 'Forecast': forecast.flatten()})
forecast_df.set_index('Date', inplace=True)

# %%
# Combine historical data and forecast
df_combined = pd.concat([df, forecast_df])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(df_combined.index, df_combined['Suhu'], label='Historical Data')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Forecast', color='red')
plt.title('Historical Data and 365-day Forecast')
plt.legend()
plt.show()

# %%
# === Step 5: Forecast 365 Days Ahead ===
def forecast_lstm_direct(model, last_sequence):
    forecast_scaled = model.predict(last_sequence[np.newaxis, :, :], verbose=0)
    return forecast_scaled.flatten()

# Menggunakan data terakhir dari dataset untuk memulai forecast
last_sequence = data_scaled[-sequence_length:]
forecast_scaled = forecast_lstm_direct(model, last_sequence)

# Inverse scaling
forecast = scaler.inverse_transform(forecast_scaled.reshape(-1, 1))

# %%
forecast_scaled
# Out:
# array([0.56025803, 0.5594156 , 0.5626263 , 0.5584918 , 0.5614729 ,
#        0.5604276 , 0.5570596 , 0.5587357 , 0.5588226 , 0.5610838 ,
#        0.55803055, 0.55810547, 0.56118685, 0.55826336, 0.5561854 ,
#        0.5561808 , 0.5572159 , 0.5640203 , 0.5560561 , 0.5598853 ,
#        0.55558914, 0.56121033, 0.5605089 , 0.560815  , 0.5570475 ,
#        0.5612971 , 0.5609874 , 0.5617394 , 0.55798936, 0.5649295 ,
#        0.5583565 , 0.55614185, 0.5628422 , 0.55729526, 0.5574609 ,
#        0.56212413, 0.55604464, 0.562397  , 0.55822796, 0.5574412 ,
#        0.56026775, 0.56129   , 0.5600682 , 0.55983686, 0.55902004,
#        0.5620529 , 0.56186885, 0.55988   , 0.5612136 , 0.56010395,
#        0.5586245 , 0.55454797, 0.5611744 , 0.56174076, 0.5563968 ,
#        0.56924343, 0.5557452 , 0.55608064, 0.55975485, 0.56085783,
#        0.5639009 , 0.559306  , 0.5578713 , 0.5624678 , 0.5616769 ,
#        0.55958736, 0.5576198 , 0.55291194, 0.5569308 , 0.56161803,
#        0.5566007 , 0.5560359 , 0.5608487 , 0.56025517, 0.55792737,
#        0.56129676, 0.5562725 , 0.5598378 , 0.5589336 , 0.5563663 ,
#        0.5624733 , 0.5592008 , 0.5624394 , 0.5577069 , 0.55433017,
#        0.5642266 , 0.5602813 , 0.55691874, 0.5611567 , 0.55879104,
#        0.5566078 , 0.5613425 , 0.5558188 , 0.5590437 , 0.5574739 ,
#        0.56401694, 0.5529269 , 0.5640577 , 0.5619587 , 0.55895203,
#        0.5608974 , 0.5577523 , 0.5570394 , 0.55909693, 0.55876887,
#        0.5619738 , 0.5612806 , 0.5541824 , 0.5614706 , 0.558427  ,
#        0.55332714, 0.561018  , 0.5604559 , 0.55810297, 0.5556799 ,
#        0.5581048 , 0.55722785, 0.5640627 , 0.5588523 , 0.55846936,
#        0.5592902 , 0.5657685 , 0.5627612 , 0.54700506, 0.5594079 ,
#        0.5572225 , 0.56393254, 0.5602245 , 0.5553342 , 0.560796  ,
#        0.56363827, 0.5563805 , 0.5624618 , 0.5602124 , 0.5608707 ,
#        0.55997074, 0.56274366, 0.55899787, 0.5552136 , 0.5626387 ,
#        0.5583457 , 0.55735606, 0.5647171 , 0.5611628 , 0.5644637 ,
#        0.5576385 , 0.55807614, 0.5598952 , 0.5558536 , 0.56004274,
#        0.5613009 , 0.55759686, 0.5652174 , 0.5569491 , 0.56426984,
#        0.5628491 , 0.56081903, 0.5616887 , 0.556682  , 0.5616897 ,
#        0.557601  , 0.5606733 , 0.5639331 , 0.5583269 , 0.56212395,
#        0.55906856, 0.55884296, 0.56279296, 0.55990046, 0.5579402 ,
#        0.5636611 , 0.558948  , 0.5545377 , 0.5622865 , 0.5603378 ,
#        0.5612743 , 0.5625869 , 0.5589208 , 0.5597056 , 0.55738515,
#        0.558072  , 0.5614719 , 0.5593422 , 0.56109744, 0.56058633,
#        0.55639476, 0.5652651 , 0.5591036 , 0.56104225, 0.55911964,
#        0.5617183 , 0.55826163, 0.5661708 , 0.55922824, 0.56723344,
#        0.5632833 , 0.5589256 , 0.5628003 , 0.5608913 , 0.55918515,
#        0.5617717 , 0.56223476, 0.5617006 , 0.56163734, 0.56255776,
#        0.55967367, 0.5576924 , 0.56048185, 0.5635837 , 0.55980086,
#        0.5611022 , 0.5607902 , 0.5634038 , 0.56218994, 0.56155485,
#        0.5564909 , 0.56201845, 0.56286055, 0.5607892 , 0.5588614 ,
#        0.55885273, 0.56220126, 0.56146777, 0.5580457 , 0.5623927 ,
#        0.5598022 , 0.5566222 , 0.5622722 , 0.55961674, 0.5620678 ,
#        0.55985683, 0.56489587, 0.5650369 , 0.56058097, 0.5611588 ,
#        0.55876875, 0.55608636, 0.5590508 , 0.55852604, 0.56069374,
#        0.5610229 , 0.5610776 , 0.5558646 , 0.55891055, 0.55980945,
#        0.56451404, 0.56211555, 0.5578865 , 0.56389725, 0.55967903,
#        0.5580074 , 0.5594606 , 0.5583323 , 0.5586682 , 0.5589085 ,
#        0.5567271 , 0.5578007 , 0.5599901 , 0.5588948 , 0.56756675,
#        0.5618201 , 0.5543039 , 0.5592032 , 0.5602046 , 0.55488753,
#        0.5591528 , 0.5623524 , 0.5522498 , 0.55734694, 0.562498  ,
#        0.5579312 , 0.5555342 , 0.5584178 , 0.56453246, 0.5616061 ,
#        0.5604917 , 0.5590228 , 0.56161755, 0.5598582 , 0.5625506 ,
#        0.5591365 , 0.5632179 , 0.5585952 , 0.5622109 , 0.5585404 ,
#        0.56072366, 0.56010807, 0.5569898 , 0.5635144 , 0.56065065,
#        0.5595263 , 0.55994606, 0.5593631 , 0.5582256 , 0.5582417 ,
#        0.5597305 , 0.5623157 , 0.562585  , 0.55360985, 0.5621591 ,
#        0.55569845, 0.5588024 , 0.55532706, 0.55930305, 0.5597255 ,
#        0.5586244 , 0.5558442 , 0.5621077 , 0.5597755 , 0.5618744 ,
#        0.55826956, 0.56045866, 0.56073546, 0.5571387 , 0.5583909 ,
#        0.5573135 , 0.55783534, 0.55563563, 0.5580238 , 0.55582756,
#        0.55941796, 0.557932  , 0.5600304 , 0.55899096, 0.5595785 ,
#        0.5581788 , 0.56008166, 0.5634633 , 0.56203645, 0.5615919 ,
#        0.55991757, 0.5584111 , 0.55902344, 0.5583493 , 0.55901694,
#        0.55999917, 0.5549053 , 0.56027836, 0.56144047, 0.5640427 ,
#        0.5624625 , 0.56092334, 0.5587657 , 0.5560863 , 0.56114763,
#        0.5645361 , 0.5595079 , 0.5547643 , 0.5614271 , 0.5569616 ,
#        0.5584215 , 0.5591296 , 0.5614802 , 0.5576041 , 0.557179  ,
#        0.5622356 , 0.5599006 , 0.5627714 , 0.55912745, 0.5624496 ,
#        0.5590065 , 0.55845296, 0.55896175, 0.55535644, 0.5599066 ],
#       dtype=float32)

# %%
# === Step 6: Visualize Results ===
forecast_dates = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=365)
forecast_df = pd.DataFrame({'Date': forecast_dates, 'Forecast': forecast.flatten()})
forecast_df.set_index('Date', inplace=True)

# Combine historical data and forecast
df_combined = pd.concat([df, forecast_df])

# Plot
plt.figure(figsize=(12, 6))
plt.plot(df_combined.index, df_combined['Suhu'], label='Historical Data')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Forecast', color='red')
plt.title('Historical Data and 365-day Forecast')
plt.legend()
plt.show()

# %%
# Step 1: Filter data aktual tahun 2024
df_2024 = df[df.index.year == 2024]

# Step 2: Gabungkan data aktual tahun 2024 dan hasil forecast
# Data aktual berhenti di akhir tahun 2023, sehingga prediksi forecast dimulai di tahun 2024
combined_forecast = pd.concat([df_2024, forecast_df], axis=0)

# Step 3: Visualisasi
plt.figure(figsize=(12, 6))
plt.plot(df_2024.index, df_2024.iloc[:, 0], label="Data Aktual Tahun 2024", color='blue')
plt.plot(forecast_df.index, forecast_df['Forecast'], label="Forecast Tahun 2024", color='red')

# Tambahkan judul dan label
plt.title("Prediksi Tahun 2024 Menggunakan LSTM")
plt.xlabel("Tanggal")
plt.ylabel("Nilai")
plt.legend()

# Tampilkan plot
plt.show()

# %%
n_cols = 3
cols = list(df.loc[:, ['Suhu', 'Kelembaban', 'Curah_Hujan']])
dataset = df[cols]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (5053, 3)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %%
train_size = int(len(data) * 0.9)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 4547 Test Size : 506

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (4547, 3)

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 365
n_cols = 3

for i in range(time_steps, len(train_data)):
    x_train.append(train_data[i-time_steps:i, :n_cols])
    y_train.append(train_data[i, :n_cols])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))
x_train.shape , y_train.shape
# Out:
# ((4182, 365, 3), (4182, 3))

# %%
model2 = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model2.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 365, 50)           10800
#
#  lstm_7 (LSTM)               (None, 64)                29440
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 42,899
# Trainable params: 42,899
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the LSTM to the Training set
history2 = model2.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 131/131 [==============================] - 39s 267ms/step - loss: 0.0157 - mean_absolute_error: 0.0885
# Epoch 2/100
# 131/131 [==============================] - 36s 278ms/step - loss: 0.0102 - mean_absolute_error: 0.0729
# Epoch 3/100
# 131/131 [==============================] - 38s 293ms/step - loss: 0.0098 - mean_absolute_error: 0.0720
# Epoch 4/100
# 131/131 [==============================] - 37s 282ms/step - loss: 0.0092 - mean_absolute_error: 0.0690
# Epoch 5/100
# 131/131 [==============================] - 36s 271ms/step - loss: 0.0087 - mean_absolute_error: 0.0675
# Epoch 6/100
# 131/131 [==============================] - 37s 284ms/step - loss: 0.0084 - mean_absolute_error: 0.0661
# Epoch 7/100
# 131/131 [==============================] - 37s 279ms/step - loss: 0.0083 - mean_absolute_error: 0.0659
# Epoch 8/100
# 131/131 [==============================] - 37s 286ms/step - loss: 0.0081 - mean_absolute_error: 0.0645
# Epoch 9/100
# 131/131 [==============================] - 38s 289ms/step - loss: 0.0079 - mean_absolute_error: 0.0639
# Epoch 10/100
# 131/131 [==============================] - 39s 296ms/step - loss: 0.0079 - mean_absolute_error: 0.0635
# Epoch 11/100
# 131/131 [==============================] - 36s 278ms/step - loss: 0.0078 - mean_absolute_error: 0.0634
# Epoch 12/100
# 131/131 [==============================] - 39s 296ms/step - loss: 0.0077 - mean_absolute_error: 0.0630
# Epoch 13/100
# 131/131 [==============================] - 39s 295ms/step - loss: 0.0077 - mean_absolute_error: 0.0625
# Epoch 14/100
# 131/131 [==============================] - 40s 306ms/step - loss: 0.0075 - mean_absolute_error: 0.0619
# Epoch 15/100
# 131/131 [==============================] - 41s 312ms/step - loss: 0.0075 - mean_absolute_error: 0.0617
# Epoch 16/100
# 131/131 [==============================] - 40s 303ms/step - loss: 0.0075 - mean_absolute_error: 0.0617
# Epoch 17/100
# 131/131 [==============================] - 39s 299ms/step - loss: 0.0076 - mean_absolute_error: 0.0624
# Epoch 18/100
# 131/131 [==============================] - 40s 304ms/step - loss: 0.0075 - mean_absolute_error: 0.0616
# Epoch 19/100
# 131/131 [==============================] - 39s 301ms/step - loss: 0.0074 - mean_absolute_error: 0.0612
# Epoch 20/100
# 131/131 [==============================] - 41s 313ms/step - loss: 0.0075 - mean_absolute_error: 0.0616
# Epoch 21/100
# 131/131 [==============================] - 50s 379ms/step - loss: 0.0075 - mean_absolute_error: 0.0616
# Epoch 22/100
# 131/131 [==============================] - 41s 311ms/step - loss: 0.0075 - mean_absolute_error: 0.0615
# Epoch 23/100
# 131/131 [==============================] - 38s 290ms/step - loss: 0.0074 - mean_absolute_error: 0.0612
# Epoch 24/100
# 131/131 [==============================] - 39s 301ms/step - loss: 0.0074 - mean_absolute_error: 0.0613
# Epoch 25/100
# 131/131 [==============================] - 37s 284ms/step - loss: 0.0074 - mean_absolute_error: 0.0609
# Epoch 26/100
# 131/131 [==============================] - 37s 285ms/step - loss: 0.0074 - mean_absolute_error: 0.0615
# Epoch 27/100
# 131/131 [==============================] - 38s 286ms/step - loss: 0.0074 - mean_absolute_error: 0.0611
# Epoch 28/100
# 131/131 [==============================] - 38s 286ms/step - loss: 0.0074 - mean_absolute_error: 0.0609
# Epoch 29/100
# 131/131 [==============================] - 38s 292ms/step - loss: 0.0074 - mean_absolute_error: 0.0614
# Epoch 30/100
# 131/131 [==============================] - 37s 281ms/step - loss: 0.0074 - mean_absolute_error: 0.0613
# Epoch 31/100
# 131/131 [==============================] - 36s 273ms/step - loss: 0.0073 - mean_absolute_error: 0.0606
# Epoch 32/100
# 131/131 [==============================] - 36s 278ms/step - loss: 0.0073 - mean_absolute_error: 0.0609
# Epoch 33/100
# 131/131 [==============================] - 35s 271ms/step - loss: 0.0073 - mean_absolute_error: 0.0608
# Epoch 34/100
# 131/131 [==============================] - 36s 274ms/step - loss: 0.0074 - mean_absolute_error: 0.0608
# Epoch 35/100
# 131/131 [==============================] - 36s 271ms/step - loss: 0.0073 - mean_absolute_error: 0.0609
# Epoch 36/100
# 131/131 [==============================] - 35s 270ms/step - loss: 0.0073 - mean_absolute_error: 0.0608
# Epoch 37/100
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0074 - mean_absolute_error: 0.0610
# Epoch 38/100
# 131/131 [==============================] - 37s 279ms/step - loss: 0.0073 - mean_absolute_error: 0.0607
# Epoch 39/100
# 131/131 [==============================] - 40s 308ms/step - loss: 0.0073 - mean_absolute_error: 0.0604
# Epoch 40/100
# 131/131 [==============================] - 40s 302ms/step - loss: 0.0073 - mean_absolute_error: 0.0606
# Epoch 41/100
# 131/131 [==============================] - 38s 289ms/step - loss: 0.0073 - mean_absolute_error: 0.0608
# Epoch 42/100
# 131/131 [==============================] - 38s 289ms/step - loss: 0.0073 - mean_absolute_error: 0.0605
# Epoch 43/100
# 131/131 [==============================] - 39s 297ms/step - loss: 0.0073 - mean_absolute_error: 0.0606
# Epoch 44/100
# 131/131 [==============================] - 43s 331ms/step - loss: 0.0073 - mean_absolute_error: 0.0606
# Epoch 45/100
# 131/131 [==============================] - 38s 291ms/step - loss: 0.0073 - mean_absolute_error: 0.0605
# Epoch 46/100
# 131/131 [==============================] - 47s 362ms/step - loss: 0.0073 - mean_absolute_error: 0.0609
# Epoch 47/100
# 131/131 [==============================] - 40s 308ms/step - loss: 0.0073 - mean_absolute_error: 0.0608
# Epoch 48/100
# 131/131 [==============================] - 42s 320ms/step - loss: 0.0073 - mean_absolute_error: 0.0607
# Epoch 49/100
# 131/131 [==============================] - 41s 314ms/step - loss: 0.0073 - mean_absolute_error: 0.0605
# Epoch 50/100
# 131/131 [==============================] - 36s 277ms/step - loss: 0.0072 - mean_absolute_error: 0.0605
# Epoch 51/100
# 131/131 [==============================] - 36s 277ms/step - loss: 0.0072 - mean_absolute_error: 0.0604
# Epoch 52/100
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0072 - mean_absolute_error: 0.0605
# Epoch 53/100
# 131/131 [==============================] - 36s 273ms/step - loss: 0.0072 - mean_absolute_error: 0.0602
# Epoch 54/100
# 131/131 [==============================] - 38s 293ms/step - loss: 0.0072 - mean_absolute_error: 0.0604
# Epoch 55/100
# 131/131 [==============================] - 37s 285ms/step - loss: 0.0072 - mean_absolute_error: 0.0601
# Epoch 56/100
# 131/131 [==============================] - 37s 283ms/step - loss: 0.0072 - mean_absolute_error: 0.0602
# Epoch 57/100
# 131/131 [==============================] - 40s 304ms/step - loss: 0.0072 - mean_absolute_error: 0.0601
# Epoch 58/100
# 131/131 [==============================] - 39s 299ms/step - loss: 0.0072 - mean_absolute_error: 0.0600
# Epoch 59/100
# 131/131 [==============================] - 38s 290ms/step - loss: 0.0072 - mean_absolute_error: 0.0600
# Epoch 60/100
# 131/131 [==============================] - 39s 297ms/step - loss: 0.0072 - mean_absolute_error: 0.0604
# Epoch 61/100
# 131/131 [==============================] - 40s 304ms/step - loss: 0.0072 - mean_absolute_error: 0.0602
# Epoch 62/100
# 131/131 [==============================] - 42s 320ms/step - loss: 0.0072 - mean_absolute_error: 0.0601
# Epoch 63/100
# 131/131 [==============================] - 45s 343ms/step - loss: 0.0072 - mean_absolute_error: 0.0602
# Epoch 64/100
# 131/131 [==============================] - 40s 306ms/step - loss: 0.0072 - mean_absolute_error: 0.0601
# Epoch 65/100
# 131/131 [==============================] - 40s 306ms/step - loss: 0.0072 - mean_absolute_error: 0.0604
# Epoch 66/100
# 131/131 [==============================] - 44s 334ms/step - loss: 0.0071 - mean_absolute_error: 0.0600
# Epoch 67/100
# 131/131 [==============================] - 39s 297ms/step - loss: 0.0072 - mean_absolute_error: 0.0604
# Epoch 68/100
# 131/131 [==============================] - 39s 301ms/step - loss: 0.0072 - mean_absolute_error: 0.0601
# Epoch 69/100
# 131/131 [==============================] - 38s 294ms/step - loss: 0.0071 - mean_absolute_error: 0.0600
# Epoch 70/100
# 131/131 [==============================] - 42s 323ms/step - loss: 0.0071 - mean_absolute_error: 0.0599
# Epoch 71/100
# 131/131 [==============================] - 40s 302ms/step - loss: 0.0071 - mean_absolute_error: 0.0600
# Epoch 72/100
# 131/131 [==============================] - 40s 306ms/step - loss: 0.0071 - mean_absolute_error: 0.0598
# Epoch 73/100
# 131/131 [==============================] - 37s 285ms/step - loss: 0.0071 - mean_absolute_error: 0.0598
# Epoch 74/100
# 131/131 [==============================] - 37s 285ms/step - loss: 0.0071 - mean_absolute_error: 0.0599
# Epoch 75/100
# 131/131 [==============================] - 37s 285ms/step - loss: 0.0071 - mean_absolute_error: 0.0597
# Epoch 76/100
# 131/131 [==============================] - 38s 293ms/step - loss: 0.0071 - mean_absolute_error: 0.0600
# Epoch 77/100
# 131/131 [==============================] - 40s 305ms/step - loss: 0.0071 - mean_absolute_error: 0.0597
# Epoch 78/100
# 131/131 [==============================] - 39s 299ms/step - loss: 0.0071 - mean_absolute_error: 0.0598
# Epoch 79/100
# 131/131 [==============================] - 42s 324ms/step - loss: 0.0071 - mean_absolute_error: 0.0595
# Epoch 80/100
# 131/131 [==============================] - 40s 307ms/step - loss: 0.0071 - mean_absolute_error: 0.0597
# Epoch 81/100
# 131/131 [==============================] - 39s 299ms/step - loss: 0.0072 - mean_absolute_error: 0.0601
# Epoch 82/100
# 131/131 [==============================] - 41s 312ms/step - loss: 0.0071 - mean_absolute_error: 0.0595
# Epoch 83/100
# 131/131 [==============================] - 40s 301ms/step - loss: 0.0070 - mean_absolute_error: 0.0596
# Epoch 84/100
# 131/131 [==============================] - 39s 296ms/step - loss: 0.0071 - mean_absolute_error: 0.0595
# Epoch 85/100
# 131/131 [==============================] - 39s 295ms/step - loss: 0.0071 - mean_absolute_error: 0.0596
# Epoch 86/100
# 131/131 [==============================] - 39s 295ms/step - loss: 0.0071 - mean_absolute_error: 0.0596
# Epoch 87/100
# 131/131 [==============================] - 38s 293ms/step - loss: 0.0071 - mean_absolute_error: 0.0597
# Epoch 88/100
# 131/131 [==============================] - 42s 318ms/step - loss: 0.0070 - mean_absolute_error: 0.0595
# Epoch 89/100
# 131/131 [==============================] - 39s 295ms/step - loss: 0.0070 - mean_absolute_error: 0.0595
# Epoch 90/100
# 131/131 [==============================] - 37s 284ms/step - loss: 0.0071 - mean_absolute_error: 0.0597
# Epoch 91/100
# 131/131 [==============================] - 39s 295ms/step - loss: 0.0070 - mean_absolute_error: 0.0594
# Epoch 92/100
# 131/131 [==============================] - 37s 283ms/step - loss: 0.0070 - mean_absolute_error: 0.0592
# Epoch 93/100
# 131/131 [==============================] - 37s 284ms/step - loss: 0.0070 - mean_absolute_error: 0.0595
# Epoch 94/100
# 131/131 [==============================] - 37s 284ms/step - loss: 0.0070 - mean_absolute_error: 0.0596
# Epoch 95/100
# 131/131 [==============================] - 37s 283ms/step - loss: 0.0069 - mean_absolute_error: 0.0590
# Epoch 96/100
# 131/131 [==============================] - 37s 284ms/step - loss: 0.0069 - mean_absolute_error: 0.0590
# Epoch 97/100
# 131/131 [==============================] - 37s 286ms/step - loss: 0.0069 - mean_absolute_error: 0.0593
# Epoch 98/100
# 131/131 [==============================] - 38s 288ms/step - loss: 0.0070 - mean_absolute_error: 0.0593
# Epoch 99/100
# 131/131 [==============================] - 40s 306ms/step - loss: 0.0070 - mean_absolute_error: 0.0592
# Epoch 100/100
# 131/131 [==============================] - 39s 300ms/step - loss: 0.0069 - mean_absolute_error: 0.0589

# %%
plt.figure(figsize=(12, 8))
plt.plot(history2.history["loss"])
plt.plot(history2.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 365
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 3

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
x_test.shape , y_test.shape
# Out:
# ((506, 365, 3), (506, 3))

# %%
# Get Prediction
predictions = model2.predict(x_test)
# Out:
# 16/16 [==============================] - 5s 86ms/step

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 37.31

# %%
from datetime import timedelta
def insert_end(Xin, new_input):
    timestep = 365
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 100
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model2.predict(Xin, batch_size=5)
    forcast.append(out[0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 [==============================] - 0s 38ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32)]
# 1/1 [==============================] - 0s 66ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32)]
# 1/1 [==============================] - 0s 60ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32)]
# 1/1 [==============================] - 0s 60ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32)]
# 1/1 [==============================] - 0s 60ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32)]
# 1/1 [==============================] - 0s 60ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32)]
# 1/1 [==============================] - 0s 61ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32)]
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32)]
# 1/1 [==============================] - 0s 60ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32)]
# 1/1 [==============================] - 0s 70ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32)]
# 1/1 [==============================] - 0s 64ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32)]
# 1/1 [==============================] - 0s 62ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32)]
# 1/1 [==============================] - 0s 91ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32)]
# 1/1 [==============================] - 0s 79ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32)]
# 1/1 [==============================] - 0s 64ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32)]
# 1/1 [==============================] - 0s 64ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32)]
# 1/1 [==============================] - 0s 62ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32)]
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32)]
# 1/1 [==============================] - 0s 61ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32)]
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32)]
# 1/1 [==============================] - 0s 59ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32)]
# 1/1 [==============================] - 0s 61ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32)]
# 1/1 [==============================] - 0s 62ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32)]
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32)]
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32)]
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32)]
# 1/1 [==============================] - 0s 61ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32)]
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32)]
# 1/1 [==============================] - 0s 62ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32)]
# 1/1 [==============================] - 0s 64ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32)]
# 1/1 [==============================] - 0s 65ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32)]
# 1/1 [==============================] - 0s 68ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32)]
# 1/1 [==============================] - 0s 66ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32)]
# 1/1 [==============================] - 0s 64ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32)]
# 1/1 [==============================] - 0s 67ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32), array([0.9306479 , 0.70643234, 0.21841359], dtype=float32)]
# 1/1 [==============================] - 0s 68ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32), array([0.9306479 , 0.70643234, 0.21841359], dtype=float32), array([0.9353494 , 0.70870626, 0.2199947 ], dtype=float32)]
# 1/1 [==============================] - 0s 65ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32), array([0.9306479 , 0.70643234, 0.21841359], dtype=float32), array([0.9353494 , 0.70870626, 0.2199947 ], dtype=float32), array([0.93970704, 0.71081954, 0.22146988], dtype=float32)]
# 1/1 [==============================] - 0s 64ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32), array([0.9306479 , 0.70643234, 0.21841359], dtype=float32), array([0.9353494 , 0.70870626, 0.2199947 ], dtype=float32), array([0.93970704, 0.71081954, 0.22146988], dtype=float32), array([0.9437439 , 0.71278083, 0.22284377], dtype=float32)]
# 1/1 [==============================] - 0s 65ms/step
# ...
# 1/1 [==============================] - 0s 63ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32), array([0.9306479 , 0.70643234, 0.21841359], dtype=float32), array([0.9353494 , 0.70870626, 0.2199947 ], dtype=float32), array([0.93970704, 0.71081954, 0.22146988], dtype=float32), array([0.9437439 , 0.71278083, 0.22284377], dtype=float32), array([0.9474822 , 0.7145994 , 0.22412127], dtype=float32), array([0.9509427 , 0.7162833 , 0.22530735], dtype=float32), array([0.95414513, 0.7178417 , 0.22640729], dtype=float32), array([0.9571078 , 0.7192829 , 0.22742653], dtype=float32), array([0.9598479 , 0.72061443, 0.22836986], dtype=float32), array([0.96238184, 0.72184455, 0.22924256], dtype=float32), array([0.9647245 , 0.7229804 , 0.23004946], dtype=float32), array([0.96689016, 0.72402894, 0.23079503], dtype=float32), array([0.9688917 , 0.72499675, 0.23148376], dtype=float32), array([0.97074115, 0.72588956, 0.23211971], dtype=float32), array([0.9724502 , 0.72671354, 0.23270667], dtype=float32), array([0.974029  , 0.7274736 , 0.23324847], dtype=float32), array([0.9754876 , 0.7281748 , 0.23374832], dtype=float32), array([0.97683483, 0.7288218 , 0.23420948], dtype=float32), array([0.9780789 , 0.7294185 , 0.23463461], dtype=float32), array([0.979228 , 0.7299691, 0.2350268], dtype=float32), array([0.9802889 , 0.7304766 , 0.23538831], dtype=float32), array([0.9812687 , 0.73094517, 0.23572168], dtype=float32), array([0.98217297, 0.731377  , 0.23602888], dtype=float32), array([0.98300767, 0.73177534, 0.23631197], dtype=float32), array([0.98377836, 0.7321428 , 0.23657292], dtype=float32), array([0.98448944, 0.7324818 , 0.23681337], dtype=float32), array([0.9851462 , 0.7327945 , 0.23703507], dtype=float32), array([0.98575157, 0.7330827 , 0.23723903], dtype=float32), array([0.9863104 , 0.7333485 , 0.23742712], dtype=float32), array([0.986826  , 0.7335937 , 0.23760015], dtype=float32), array([0.98730135, 0.7338199 , 0.23775965], dtype=float32), array([0.98774016, 0.7340284 , 0.23790652], dtype=float32), array([0.9881444 , 0.73422056, 0.23804179], dtype=floa ...
# 1/1 [==============================] - 0s 58ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32), array([0.9306479 , 0.70643234, 0.21841359], dtype=float32), array([0.9353494 , 0.70870626, 0.2199947 ], dtype=float32), array([0.93970704, 0.71081954, 0.22146988], dtype=float32), array([0.9437439 , 0.71278083, 0.22284377], dtype=float32), array([0.9474822 , 0.7145994 , 0.22412127], dtype=float32), array([0.9509427 , 0.7162833 , 0.22530735], dtype=float32), array([0.95414513, 0.7178417 , 0.22640729], dtype=float32), array([0.9571078 , 0.7192829 , 0.22742653], dtype=float32), array([0.9598479 , 0.72061443, 0.22836986], dtype=float32), array([0.96238184, 0.72184455, 0.22924256], dtype=float32), array([0.9647245 , 0.7229804 , 0.23004946], dtype=float32), array([0.96689016, 0.72402894, 0.23079503], dtype=float32), array([0.9688917 , 0.72499675, 0.23148376], dtype=float32), array([0.97074115, 0.72588956, 0.23211971], dtype=float32), array([0.9724502 , 0.72671354, 0.23270667], dtype=float32), array([0.974029  , 0.7274736 , 0.23324847], dtype=float32), array([0.9754876 , 0.7281748 , 0.23374832], dtype=float32), array([0.97683483, 0.7288218 , 0.23420948], dtype=float32), array([0.9780789 , 0.7294185 , 0.23463461], dtype=float32), array([0.979228 , 0.7299691, 0.2350268], dtype=float32), array([0.9802889 , 0.7304766 , 0.23538831], dtype=float32), array([0.9812687 , 0.73094517, 0.23572168], dtype=float32), array([0.98217297, 0.731377  , 0.23602888], dtype=float32), array([0.98300767, 0.73177534, 0.23631197], dtype=float32), array([0.98377836, 0.7321428 , 0.23657292], dtype=float32), array([0.98448944, 0.7324818 , 0.23681337], dtype=float32), array([0.9851462 , 0.7327945 , 0.23703507], dtype=float32), array([0.98575157, 0.7330827 , 0.23723903], dtype=float32), array([0.9863104 , 0.7333485 , 0.23742712], dtype=float32), array([0.986826  , 0.7335937 , 0.23760015], dtype=float32), array([0.98730135, 0.7338199 , 0.23775965], dtype=float32), array([0.98774016, 0.7340284 , 0.23790652], dtype=float32), array([0.9881444 , 0.73422056, 0.23804179], dtype=floa ...
# 1/1 [==============================] - 0s 66ms/step
# [array([0.51478213, 0.56999797, 0.04062144], dtype=float32), array([0.4603121 , 0.54278356, 0.19808424], dtype=float32), array([0.3923664 , 0.58643407, 0.11796276], dtype=float32), array([0.44376957, 0.55074733, 0.16132519], dtype=float32), array([0.45575526, 0.57042253, 0.156168  ], dtype=float32), array([0.48138076, 0.56233793, 0.16606362], dtype=float32), array([0.5045993 , 0.5569212 , 0.16119033], dtype=float32), array([0.53245234, 0.556208  , 0.16052978], dtype=float32), array([0.5606988 , 0.5588531 , 0.15656722], dtype=float32), array([0.59009445, 0.56507343, 0.15340737], dtype=float32), array([0.61873066, 0.5728836 , 0.1506451 ], dtype=float32), array([0.6460738 , 0.5811379 , 0.14935338], dtype=float32), array([0.6715916 , 0.58911186, 0.14965339], dtype=float32), array([0.6950866, 0.5969355, 0.1515484], dtype=float32), array([0.7166337 , 0.6047571 , 0.15478888], dtype=float32), array([0.73633486, 0.61268485, 0.158948  ], dtype=float32), array([0.7543957 , 0.6206548 , 0.16363043], dtype=float32), array([0.7709996 , 0.62852675, 0.16847262], dtype=float32), array([0.7863404 , 0.6361422 , 0.17323329], dtype=float32), array([0.8005801 , 0.6433729 , 0.17775764], dtype=float32), array([0.8138538, 0.6501417, 0.1819779], dtype=float32), array([0.82626563, 0.656419  , 0.18587822], dtype=float32), array([0.8378944 , 0.66221213, 0.18947667], dtype=float32), array([0.8487989 , 0.66755205, 0.19280565], dtype=float32), array([0.8590243, 0.6724806, 0.195901 ], dtype=float32), array([0.86860687, 0.6770418 , 0.19879545], dtype=float32), array([0.87757736, 0.6812763 , 0.20151499], dtype=float32), array([0.8859648 , 0.6852191 , 0.20407942], dtype=float32), array([0.89379686, 0.6888985 , 0.20650224], dtype=float32), array([0.90110046, 0.6923374 , 0.20879246], dtype=float32), array([0.9079033, 0.6955529, 0.210956 ], dtype=float32), array([0.9142326 , 0.6985593 , 0.21299687], dtype=float32), array([0.9201152 , 0.70136815, 0.2149181 ], dtype=float32), array([0.92557836, 0.7039894 , 0.21672261], dtype=float32), array([0.9306479 , 0.70643234, 0.21841359], dtype=float32), array([0.9353494 , 0.70870626, 0.2199947 ], dtype=float32), array([0.93970704, 0.71081954, 0.22146988], dtype=float32), array([0.9437439 , 0.71278083, 0.22284377], dtype=float32), array([0.9474822 , 0.7145994 , 0.22412127], dtype=float32), array([0.9509427 , 0.7162833 , 0.22530735], dtype=float32), array([0.95414513, 0.7178417 , 0.22640729], dtype=float32), array([0.9571078 , 0.7192829 , 0.22742653], dtype=float32), array([0.9598479 , 0.72061443, 0.22836986], dtype=float32), array([0.96238184, 0.72184455, 0.22924256], dtype=float32), array([0.9647245 , 0.7229804 , 0.23004946], dtype=float32), array([0.96689016, 0.72402894, 0.23079503], dtype=float32), array([0.9688917 , 0.72499675, 0.23148376], dtype=float32), array([0.97074115, 0.72588956, 0.23211971], dtype=float32), array([0.9724502 , 0.72671354, 0.23270667], dtype=float32), array([0.974029  , 0.7274736 , 0.23324847], dtype=float32), array([0.9754876 , 0.7281748 , 0.23374832], dtype=float32), array([0.97683483, 0.7288218 , 0.23420948], dtype=float32), array([0.9780789 , 0.7294185 , 0.23463461], dtype=float32), array([0.979228 , 0.7299691, 0.2350268], dtype=float32), array([0.9802889 , 0.7304766 , 0.23538831], dtype=float32), array([0.9812687 , 0.73094517, 0.23572168], dtype=float32), array([0.98217297, 0.731377  , 0.23602888], dtype=float32), array([0.98300767, 0.73177534, 0.23631197], dtype=float32), array([0.98377836, 0.7321428 , 0.23657292], dtype=float32), array([0.98448944, 0.7324818 , 0.23681337], dtype=float32), array([0.9851462 , 0.7327945 , 0.23703507], dtype=float32), array([0.98575157, 0.7330827 , 0.23723903], dtype=float32), array([0.9863104 , 0.7333485 , 0.23742712], dtype=float32), array([0.986826  , 0.7335937 , 0.23760015], dtype=float32), array([0.98730135, 0.7338199 , 0.23775965], dtype=float32), array([0.98774016, 0.7340284 , 0.23790652], dtype=float32), array([0.9881444 , 0.73422056, 0.23804179], dtype=floa ...

# %%
forcasted_output = np.asanyarray(forcast)   
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", 'Suhu', 'Kelembaban', 'Curah_Hujan'
df_result.head()
# Out:
#         Date       Suhu  Kelembaban  Curah_Hujan
# 0 2024-10-31  27.304258   79.826645     6.057469
# 1 2024-11-01  26.993778   79.056206    29.538321
# 2 2024-11-02  26.606489   80.291954    17.590607
# 3 2024-11-03  26.899487   79.281662    24.056812
# 4 2024-11-04  26.967806   79.838661    23.287771

# %%
plt.figure(figsize=(20, 10))
plt.title('Next 30 Days')

plt.subplot(2, 2, 1)
plt.plot(df['Suhu'])
plt.plot(df_result.set_index('Date')[['Suhu']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Temp' ,fontsize=18)

plt.subplot(2, 2, 2)
plt.plot(df['Kelembaban'])
plt.plot(df_result.set_index('Date')[['Kelembaban']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('humidity' ,fontsize=18)

plt.subplot(2, 2, 3)
plt.plot(df['Curah_Hujan'])
plt.plot(df_result.set_index('Date')[['Curah_Hujan']])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Curah_Hujan' ,fontsize=18)

plt.tight_layout()
plt.show()

# %%
dataset = df["Suhu"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (5053, 1)

# %%
data = df
# Pastikan kolom 'value' ada di data
values = data['Suhu'].values.reshape(-1, 1)

# %%
# 2. Normalize Data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_values = scaler.fit_transform(values)

# %%
# 3. Prepare Data for LSTM
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(data[i + sequence_length])
    return np.array(X), np.array(y)

# %%
sequence_length = 100  # Bisa disesuaikan
X, y = create_sequences(scaled_values, sequence_length)

# Split Data (80% Train, 20% Test)
split = int(0.7 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# 4. Build LSTM Model
model = Sequential([
    LSTM(100, return_sequences=True, input_shape=(sequence_length, 1)),
    Dropout(0.2),
    LSTM(50),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# 5. Train Model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 109/109 [==============================] - 14s 91ms/step - loss: 0.0194 - val_loss: 0.0093
# Epoch 2/100
# 109/109 [==============================] - 9s 86ms/step - loss: 0.0113 - val_loss: 0.0089
# Epoch 3/100
# 109/109 [==============================] - 9s 86ms/step - loss: 0.0109 - val_loss: 0.0088
# Epoch 4/100
# 109/109 [==============================] - 10s 88ms/step - loss: 0.0105 - val_loss: 0.0083
# Epoch 5/100
# 109/109 [==============================] - 10s 88ms/step - loss: 0.0097 - val_loss: 0.0081
# Epoch 6/100
# 109/109 [==============================] - 10s 96ms/step - loss: 0.0095 - val_loss: 0.0078
# Epoch 7/100
# 109/109 [==============================] - 10s 92ms/step - loss: 0.0096 - val_loss: 0.0076
# Epoch 8/100
# 109/109 [==============================] - 10s 90ms/step - loss: 0.0090 - val_loss: 0.0074
# Epoch 9/100
# 109/109 [==============================] - 10s 90ms/step - loss: 0.0084 - val_loss: 0.0070
# Epoch 10/100
# 109/109 [==============================] - 10s 94ms/step - loss: 0.0083 - val_loss: 0.0068
# Epoch 11/100
# 109/109 [==============================] - 10s 92ms/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 12/100
# 109/109 [==============================] - 10s 88ms/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 13/100
# 109/109 [==============================] - 10s 96ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 14/100
# 109/109 [==============================] - 10s 89ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 15/100
# 109/109 [==============================] - 10s 89ms/step - loss: 0.0073 - val_loss: 0.0069
# Epoch 16/100
# 109/109 [==============================] - 10s 92ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 17/100
# 109/109 [==============================] - 10s 95ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 18/100
# 109/109 [==============================] - 10s 89ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 19/100
# 109/109 [==============================] - 10s 89ms/step - loss: 0.0071 - val_loss: 0.0065
# Epoch 20/100
# 109/109 [==============================] - 10s 89ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 21/100
# 109/109 [==============================] - 10s 89ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 22/100
# 109/109 [==============================] - 10s 90ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 23/100
# 109/109 [==============================] - 10s 91ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 24/100
# 109/109 [==============================] - 10s 91ms/step - loss: 0.0069 - val_loss: 0.0060
# Epoch 25/100
# 109/109 [==============================] - 10s 95ms/step - loss: 0.0069 - val_loss: 0.0060
# Epoch 26/100
# 109/109 [==============================] - 11s 101ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 27/100
# 109/109 [==============================] - 11s 99ms/step - loss: 0.0069 - val_loss: 0.0060
# Epoch 28/100
# 109/109 [==============================] - 11s 98ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 29/100
# 109/109 [==============================] - 10s 96ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 30/100
# 109/109 [==============================] - 10s 90ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 31/100
# 109/109 [==============================] - 10s 94ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 32/100
# 109/109 [==============================] - 10s 96ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 33/100
# 109/109 [==============================] - 11s 98ms/step - loss: 0.0066 - val_loss: 0.0061
# Epoch 34/100
# 109/109 [==============================] - 10s 96ms/step - loss: 0.0066 - val_loss: 0.0062

# %%
# 6. Evaluate Model
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
# 7. Predict 365 Days Ahead
def predict_future(model, data, steps):
    future_predictions = []
    input_sequence = data[-sequence_length:].reshape(1, sequence_length, 1)

    for _ in range(steps):
        next_value = model.predict(input_sequence, verbose=0)
        future_predictions.append(next_value[0, 0])
        # Update input sequence
        input_sequence = np.append(input_sequence[:, 1:, :], [[[next_value[0, 0]]]], axis=1)

    return np.array(future_predictions)

future_predictions = predict_future(model, scaled_values, 365)

# Inverse Scale Predictions
future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1))

# %%
future_predictions
# Out:
# array([[27.599237],
#        [27.45372 ],
#        [27.416637],
#        [27.391521],
#        [27.3771  ],
#        [27.370115],
#        [27.367828],
#        [27.368324],
#        [27.370266],
#        [27.37279 ],
#        [27.375347],
#        [27.377625],
#        [27.37948 ],
#        [27.380873],
#        [27.381813],
#        [27.382364],
#        [27.382593],
#        [27.38257 ],
#        [27.382364],
#        [27.382027],
#        [27.381609],
#        [27.381144],
#        [27.380661],
#        [27.38017 ],
#        [27.37969 ],
#        [27.379225],
#        [27.378777],
#        [27.378347],
#        [27.377937],
#        [27.37754 ],
#        [27.377157],
#        [27.376787],
#        [27.376423],
#        [27.37607 ],
#        [27.375721],
#        [27.37538 ],
#        [27.375042],
#        [27.374708],
#        [27.374376],
#        [27.374048],
#        [27.373724],
#        [27.3734  ],
#        [27.373083],
#        [27.372766],
#        [27.372456],
#        [27.372145],
#        [27.371841],
#        [27.371536],
#        [27.371237],
#        [27.370941],
#        [27.370647],
#        [27.370356],
#        [27.370071],
#        [27.369785],
#        [27.369505],
#        [27.369226],
#        [27.368952],
#        [27.36868 ],
#        [27.36841 ],
#        [27.368145],
#        [27.367884],
#        [27.367622],
#        [27.367365],
#        [27.36711 ],
#        [27.36686 ],
#        [27.366608],
#        [27.366362],
#        [27.366116],
#        [27.365877],
#        [27.365639],
#        [27.365402],
#        [27.365168],
#        [27.364937],
#        [27.364708],
#        [27.364483],
#        [27.364258],
#        [27.364037],
#        [27.363817],
#        [27.3636  ],
#        [27.363388],
#        [27.363176],
#        [27.362967],
#        [27.362757],
#        [27.362553],
#        [27.362349],
#        [27.362148],
#        [27.36195 ],
#        [27.361752],
#        [27.361559],
#        [27.361366],
#        [27.361176],
#        [27.360989],
#        [27.3608  ],
#        [27.360619],
#        [27.360434],
#        [27.360254],
#        [27.360075],
#        [27.359901],
#        [27.359726],
#        [27.359552],
#        [27.35938 ],
#        [27.359213],
#        [27.359047],
#        [27.358881],
#        [27.358719],
#        [27.358555],
#        [27.358395],
#        [27.358236],
#        [27.35808 ],
#        [27.357925],
#        [27.357773],
#        [27.35762 ],
#        [27.357471],
#        [27.35732 ],
#        [27.357174],
#        [27.35703 ],
#        [27.356886],
#        [27.356745],
#        [27.356604],
#        [27.356464],
#        [27.356327],
#        [27.35619 ],
#        [27.356058],
#        [27.355925],
#        [27.355791],
#        [27.355661],
#        [27.355534],
#        [27.355406],
#        [27.355278],
#        [27.355152],
#        [27.35503 ],
#        [27.354908],
#        [27.354786],
#        [27.354666],
#        [27.35455 ],
#        [27.354431],
#        [27.354315],
#        [27.3542  ],
#        [27.354086],
#        [27.353975],
#        [27.353867],
#        [27.353756],
#        [27.353647],
#        [27.35354 ],
#        [27.353434],
#        [27.353329],
#        [27.353226],
#        [27.353123],
#        [27.353022],
#        [27.35292 ],
#        [27.35282 ],
#        [27.352722],
#        [27.352625],
#        [27.352526],
#        [27.352432],
#        [27.352339],
#        [27.352243],
#        [27.352154],
#        [27.352062],
#        [27.351973],
#        [27.351883],
#        [27.351793],
#        [27.351706],
#        [27.35162 ],
#        [27.351534],
#        [27.35145 ],
#        [27.351366],
#        [27.351284],
#        [27.3512  ],
#        [27.351122],
#        [27.35104 ],
#        [27.350962],
#        [27.350882],
#        [27.350805],
#        [27.350727],
#        [27.35065 ],
#        [27.350578],
#        [27.350502],
#        [27.350428],
#        [27.350355],
#        [27.350285],
#        [27.350214],
#        [27.350143],
#        [27.350073],
#        [27.350004],
#        [27.349936],
#        [27.349869],
#        [27.3498  ],
#        [27.349735],
#        [27.34967 ],
#        [27.349606],
#        [27.349543],
#        [27.34948 ],
#        [27.349415],
#        [27.349356],
#        [27.349293],
#        [27.349232],
#        [27.349173],
#        [27.349113],
#        [27.349052],
#        [27.348995],
#        [27.348938],
#        [27.348883],
#        [27.348825],
#        [27.34877 ],
#        [27.348717],
#        [27.348661],
#        [27.348608],
#        [27.348553],
#        [27.348501],
#        [27.34845 ],
#        [27.348398],
#        [27.348347],
#        [27.348297],
#        [27.348246],
#        [27.348196],
#        [27.348148],
#        [27.348099],
#        [27.348053],
#        [27.348003],
#        [27.347958],
#        [27.347912],
#        [27.347866],
#        [27.347822],
#        [27.347776],
#        [27.347733],
#        [27.347689],
#        [27.347645],
#        [27.3476  ],
#        [27.34756 ],
#        [27.347517],
#        [27.347477],
#        [27.347433],
#        [27.347395],
#        [27.347355],
#        [27.347313],
#        [27.347275],
#        [27.347235],
#        [27.347197],
#        [27.347158],
#        [27.34712 ],
#        [27.347086],
#        [27.347048],
#        [27.347012],
#        [27.346973],
#        [27.34694 ],
#        [27.346903],
#        [27.34687 ],
#        [27.346836],
#        [27.3468  ],
#        [27.346767],
#        [27.346731],
#        [27.346699],
#        [27.346666],
#        [27.346638],
#        [27.346601],
#        [27.346571],
#        [27.346539],
#        [27.34651 ],
#        [27.346476],
#        [27.346447],
#        [27.346416],
#        [27.346386],
#        [27.346357],
#        [27.346329],
#        [27.3463  ],
#        [27.346273],
#        [27.346243],
#        [27.346216],
#        [27.346188],
#        [27.34616 ],
#        [27.346134],
#        [27.34611 ],
#        [27.346083],
#        [27.346056],
#        [27.346031],
#        [27.346003],
#        [27.34598 ],
#        [27.345955],
#        [27.34593 ],
#        [27.345905],
#        [27.34588 ],
#        [27.345858],
#        [27.345833],
#        [27.34581 ],
#        [27.345785],
#        [27.345764],
#        [27.34574 ],
#        [27.345718],
#        [27.345695],
#        [27.345675],
#        [27.345654],
#        [27.34563 ],
#        [27.34561 ],
#        [27.345587],
#        [27.345568],
#        [27.345547],
#        [27.345528],
#        [27.345507],
#        [27.345488],
#        [27.345469],
#        [27.34545 ],
#        [27.34543 ],
#        [27.345411],
#        [27.345392],
#        [27.345373],
#        [27.345354],
#        [27.345335],
#        [27.345318],
#        [27.345299],
#        [27.34528 ],
#        [27.345264],
#        [27.345247],
#        [27.345228],
#        [27.345213],
#        [27.345196],
#        [27.34518 ],
#        [27.345163],
#        [27.345148],
#        [27.34513 ],
#        [27.345116],
#        [27.345098],
#        [27.345085],
#        [27.345068],
#        [27.345053],
#        [27.34504 ],
#        [27.345022],
#        [27.345009],
#        [27.344995],
#        [27.344978],
#        [27.344965],
#        [27.344952],
#        [27.344938],
#        [27.344925],
#        [27.344912],
#        [27.344898],
#        [27.344883],
#        [27.34487 ],
#        [27.344856],
#        [27.344843],
#        [27.344831],
#        [27.344818],
#        [27.344805],
#        [27.344793],
#        [27.34478 ],
#        [27.34477 ],
#        [27.344755],
#        [27.344746],
#        [27.344734],
#        [27.34472 ],
#        [27.34471 ],
#        [27.344698],
#        [27.344688],
#        [27.344677],
#        [27.344666],
#        [27.344656],
#        [27.344645],
#        [27.344633],
#        [27.344624],
#        [27.344612],
#        [27.3446  ],
#        [27.344593],
#        [27.344582],
#        [27.344572],
#        [27.344563]], dtype=float32)

# %%
# 8. Plot Results
plt.figure(figsize=(10, 6))
plt.plot(range(len(values)), values, label='Historical Data')
plt.plot(range(len(values), len(values) + 365), future_predictions, label='Future Predictions')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %%
# 90% to Train , 10% to Test
train_size = int(len(data)*.9)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 4547 Test Size : 506

# %%
train_data.shape, test_data.shape
# Out:
# ((4547, 1), (566, 1))

# %%
# Creating a Training set with 60 time-steps and 1 output
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape , y_train.shape
# Out:
# ((4487, 60, 1), (4487,))

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the LSTM to the Training set
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/100
# 141/141 [==============================] - 13s 50ms/step - loss: 0.0138 - mean_absolute_error: 0.0890
# Epoch 2/100
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0088 - mean_absolute_error: 0.0745
# Epoch 3/100
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0082 - mean_absolute_error: 0.0719
# Epoch 4/100
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0076 - mean_absolute_error: 0.0689
# Epoch 5/100
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0074 - mean_absolute_error: 0.0676
# Epoch 6/100
# 141/141 [==============================] - 7s 51ms/step - loss: 0.0070 - mean_absolute_error: 0.0662
# Epoch 7/100
# 141/141 [==============================] - 8s 59ms/step - loss: 0.0066 - mean_absolute_error: 0.0641
# Epoch 8/100
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0063 - mean_absolute_error: 0.0627
# Epoch 9/100
# 141/141 [==============================] - 8s 60ms/step - loss: 0.0063 - mean_absolute_error: 0.0628
# Epoch 10/100
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0064 - mean_absolute_error: 0.0630
# Epoch 11/100
# 141/141 [==============================] - 8s 59ms/step - loss: 0.0062 - mean_absolute_error: 0.0619
# Epoch 12/100
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0062 - mean_absolute_error: 0.0620
# Epoch 13/100
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0063 - mean_absolute_error: 0.0626
# Epoch 14/100
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0062 - mean_absolute_error: 0.0618
# Epoch 15/100
# 141/141 [==============================] - 7s 50ms/step - loss: 0.0061 - mean_absolute_error: 0.0619
# Epoch 16/100
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0063 - mean_absolute_error: 0.0623
# Epoch 17/100
# 141/141 [==============================] - 7s 51ms/step - loss: 0.0064 - mean_absolute_error: 0.0631
# Epoch 18/100
# 141/141 [==============================] - 7s 52ms/step - loss: 0.0064 - mean_absolute_error: 0.0628
# Epoch 19/100
# 141/141 [==============================] - 8s 55ms/step - loss: 0.0062 - mean_absolute_error: 0.0622
# Epoch 20/100
# 141/141 [==============================] - 11s 79ms/step - loss: 0.0062 - mean_absolute_error: 0.0622
# Epoch 21/100
# 141/141 [==============================] - 11s 77ms/step - loss: 0.0062 - mean_absolute_error: 0.0618
# Epoch 22/100
# 141/141 [==============================] - 11s 77ms/step - loss: 0.0062 - mean_absolute_error: 0.0624
# Epoch 23/100
# 141/141 [==============================] - 11s 77ms/step - loss: 0.0062 - mean_absolute_error: 0.0619
# Epoch 24/100
# 141/141 [==============================] - 11s 78ms/step - loss: 0.0062 - mean_absolute_error: 0.0621
# Epoch 25/100
# 141/141 [==============================] - 14s 96ms/step - loss: 0.0063 - mean_absolute_error: 0.0626

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((506, 60, 1), (506,))

# %%
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 16/16 [==============================] - 3s 23ms/step
# (506, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.05

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Tesla Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['Suhu'], linewidth= 3)
plt.plot(test['Suhu'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 30
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0, 0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 [==============================] - 0s 30ms/step
# [0.5228413]
# 1/1 [==============================] - 0s 51ms/step
# [0.5228413, 0.5205501]
# 1/1 [==============================] - 0s 52ms/step
# [0.5228413, 0.5205501, 0.5208662]
# 1/1 [==============================] - 0s 53ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745]
# 1/1 [==============================] - 0s 51ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447]
# 1/1 [==============================] - 0s 48ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216]
# 1/1 [==============================] - 0s 50ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186]
# 1/1 [==============================] - 0s 48ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936]
# 1/1 [==============================] - 0s 50ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189]
# 1/1 [==============================] - 0s 48ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586]
# 1/1 [==============================] - 0s 49ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504]
# 1/1 [==============================] - 0s 49ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266]
# 1/1 [==============================] - 0s 48ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547]
# 1/1 [==============================] - 0s 49ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594]
# 1/1 [==============================] - 0s 48ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656]
# 1/1 [==============================] - 0s 49ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926]
# 1/1 [==============================] - 0s 50ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485]
# 1/1 [==============================] - 0s 51ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354]
# 1/1 [==============================] - 0s 52ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624]
# 1/1 [==============================] - 0s 47ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149]
# 1/1 [==============================] - 0s 47ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113]
# 1/1 [==============================] - 0s 49ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685]
# 1/1 [==============================] - 0s 78ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236]
# 1/1 [==============================] - 0s 52ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236, 0.560063]
# 1/1 [==============================] - 0s 52ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236, 0.560063, 0.5620065]
# 1/1 [==============================] - 0s 46ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236, 0.560063, 0.5620065, 0.56395495]
# 1/1 [==============================] - 0s 52ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236, 0.560063, 0.5620065, 0.56395495, 0.5659097]
# 1/1 [==============================] - 0s 49ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236, 0.560063, 0.5620065, 0.56395495, 0.5659097, 0.5678713]
# 1/1 [==============================] - 0s 51ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236, 0.560063, 0.5620065, 0.56395495, 0.5659097, 0.5678713, 0.5698401]
# 1/1 [==============================] - 0s 49ms/step
# [0.5228413, 0.5205501, 0.5208662, 0.5219745, 0.523447, 0.5251216, 0.5269186, 0.5287936, 0.5307189, 0.53267586, 0.5346504, 0.53663266, 0.53861547, 0.540594, 0.5425656, 0.54452926, 0.546485, 0.54843354, 0.55037624, 0.5523149, 0.55425113, 0.55618685, 0.5581236, 0.560063, 0.5620065, 0.56395495, 0.5659097, 0.5678713, 0.5698401, 0.571817]

# %%
time
# Out:
# [Timestamp('2024-10-31 00:00:00'),
#  Timestamp('2024-11-01 00:00:00'),
#  Timestamp('2024-11-02 00:00:00'),
#  Timestamp('2024-11-03 00:00:00'),
#  Timestamp('2024-11-04 00:00:00'),
#  Timestamp('2024-11-05 00:00:00'),
#  Timestamp('2024-11-06 00:00:00'),
#  Timestamp('2024-11-07 00:00:00'),
#  Timestamp('2024-11-08 00:00:00'),
#  Timestamp('2024-11-09 00:00:00'),
#  Timestamp('2024-11-10 00:00:00'),
#  Timestamp('2024-11-11 00:00:00'),
#  Timestamp('2024-11-12 00:00:00'),
#  Timestamp('2024-11-13 00:00:00'),
#  Timestamp('2024-11-14 00:00:00'),
#  Timestamp('2024-11-15 00:00:00'),
#  Timestamp('2024-11-16 00:00:00'),
#  Timestamp('2024-11-17 00:00:00'),
#  Timestamp('2024-11-18 00:00:00'),
#  Timestamp('2024-11-19 00:00:00'),
#  Timestamp('2024-11-20 00:00:00'),
#  Timestamp('2024-11-21 00:00:00'),
#  Timestamp('2024-11-22 00:00:00'),
#  Timestamp('2024-11-23 00:00:00'),
#  Timestamp('2024-11-24 00:00:00'),
#  Timestamp('2024-11-25 00:00:00'),
#  Timestamp('2024-11-26 00:00:00'),
#  Timestamp('2024-11-27 00:00:00'),
#  Timestamp('2024-11-28 00:00:00'),
#  Timestamp('2024-11-29 00:00:00')]

# %%
forcasted_output = np.asanyarray(forcast)   
forcasted_output = forcasted_output.reshape(-1, 1) 
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"

# %%
df_result
# Out:
#          Date  Forecasted
# 0  2024-10-31   27.350195
# 1  2024-11-01   27.337135
# 2  2024-11-02   27.338936
# 3  2024-11-03   27.345253
# 4  2024-11-04   27.353647
# 5  2024-11-05   27.363192
# 6  2024-11-06   27.373436
# 7  2024-11-07   27.384123
# 8  2024-11-08   27.395098
# 9  2024-11-09   27.406252
# 10 2024-11-10   27.417507
# 11 2024-11-11   27.428806
# 12 2024-11-12   27.440107
# 13 2024-11-13   27.451385
# 14 2024-11-14   27.462624
# 15 2024-11-15   27.473816
# 16 2024-11-16   27.484964
# 17 2024-11-17   27.496071
# 18 2024-11-18   27.507143
# 19 2024-11-19   27.518196
# 20 2024-11-20   27.529230
# 21 2024-11-21   27.540266
# 22 2024-11-22   27.551306
# 23 2024-11-23   27.562359
# 24 2024-11-24   27.573439
# 25 2024-11-25   27.584543
# 26 2024-11-26   27.595684
# 27 2024-11-27   27.606867
# 28 2024-11-28   27.618090
# 29 2024-11-29   27.629358

# %%
plt.figure(figsize=(16, 8))
plt.title('Tesla Close Stock Price Forecasting For Next 30 Days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Suhu' ,fontsize=18)
plt.plot(df['Suhu'])
plt.plot(df_result.set_index('Date')[['Forecasted']])

# %%
n_cols = 1
dataset = df["Suhu"]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (5053, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %%
train_size = int(len(data) * 0.9)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 4547 Test Size : 506

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (4547, 1)

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 60
n_cols = 1

for i in range(time_steps, len(scaled_data)):
    x_train.append(scaled_data[i-time_steps:i, :n_cols])
    y_train.append(scaled_data[i, :n_cols])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((4993, 60, 1), (4993, 1))

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model = Sequential([
#       2     LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
#       3     LSTM(64, return_sequences= False),
#       4     Dense(32),
#       5     Dense(16),
#       6     Dense(n_cols)
#       7 ])
#       9 model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")
#
# NameError: name 'Sequential' is not defined

# %%
model.summary()

# %%
# Fitting the LSTM to the Training set
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32)

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
# Get Prediction
predictions = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Get Prediction
# ----> 2 predictions = model.predict(x_test)
#
# NameError: name 'model' is not defined

# %%
predictions.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 predictions.shape
#
# NameError: name 'predictions' is not defined

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (506, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.03

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#      Predictions  Actuals
# 0      28.595097    28.99
# 1      28.731493    28.57
# 2      28.498625    28.45
# 3      28.448935    28.30
# 4      28.333481    28.25
# ..           ...      ...
# 501    27.165743    27.44
# 502    27.363735    27.52
# 503    27.414335    27.20
# 504    27.218435    27.35
# 505    27.348711    27.82
#
# [506 rows x 2 columns]

# %%
plt.figure(figsize = (16, 6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 365
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [array([0.56484777], dtype=float32)]
# 1/1 [==============================] - 0s 24ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32)]
# 1/1 [==============================] - 0s 25ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32)]
# 1/1 [==============================] - 0s 29ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32)]
# 1/1 [==============================] - 0s 30ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32)]
# 1/1 [==============================] - 0s 76ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32)]
# 1/1 [==============================] - 0s 30ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32)]
# 1/1 [==============================] - 0s 30ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32)]
# 1/1 [==============================] - 0s 29ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32)]
# 1/1 [==============================] - 0s 30ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32)]
# 1/1 [==============================] - 0s 29ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32)]
# 1/1 [==============================] - 0s 33ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32)]
# 1/1 [==============================] - 0s 31ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32)]
# 1/1 [==============================] - 0s 26ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32)]
# 1/1 [==============================] - 0s 27ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32)]
# 1/1 [==============================] - 0s 39ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32), array([0.6045207], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32), array([0.6045207], dtype=float32), array([0.6050471], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32), array([0.6045207], dtype=float32), array([0.6050471], dtype=float32), array([0.6055622], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32), array([0.6045207], dtype=float32), array([0.6050471], dtype=float32), array([0.6055622], dtype=float32), array([0.60606635], dtype=float32)]
# 1/1 [==============================] - 0s 28ms/step
# ...
# 1/1 [==============================] - 0s 30ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32), array([0.6045207], dtype=float32), array([0.6050471], dtype=float32), array([0.6055622], dtype=float32), array([0.60606635], dtype=float32), array([0.6065599], dtype=float32), array([0.60704345], dtype=float32), array([0.60751754], dtype=float32), array([0.6079826], dtype=float32), array([0.60843897], dtype=float32), array([0.60888714], dtype=float32), array([0.6093273], dtype=float32), array([0.6097598], dtype=float32), array([0.61018485], dtype=float32), array([0.61060256], dtype=float32), array([0.61101294], dtype=float32), array([0.61141616], dtype=float32), array([0.6118122], dtype=float32), array([0.61220104], dtype=float32), array([0.6125827], dtype=float32), array([0.612957], dtype=float32), array([0.61332387], dtype=float32), array([0.61368304], dtype=float32), array([0.6140344], dtype=float32), array([0.614378], dtype=float32), array([0.61471415], dtype=float32), array([0.6150429], dtype=float32), array([0.6153645], dtype=float32), array([0.61567897], dtype=float32), array([0.6159864], dtype=float32), array([0.6162868], dtype=float32), array([0.61658025], dtype=float32), array([0.61686695], dtype=float32), array([0.6171471], dtype=float32), array([0.6174209], dtype=float32), array([0.61768854], dtype=float32), array([0.6179502], dtype=float32), array([0.6182062], dtype=float32), array([0.6184566], dtype=float32), array([0.61870176], dtype=float32), array([0.6189418], dtype=float32), array([0.6191769], dtype=float32), array([0.619407], dtype=float32), array([0.6196322], dtype=float32), array([0.61985284], dtype=float32), array([0.6200689], dtype=float32), array([0.6202805], dtype=float32), array([0.6204877], dtype=float32), array([0.6206906], dtype=float32), array([0.6208893], dtype=float32), array([0.6210839], dtype=float32), array([0.6212745], dtype=float32), array([0.6214611], dtype=float32), array([0.62164384], dtype=float32), array([0.62182266], dtype=float32), array([0.62199783], dtype=float32), array([0.6221693], dtype=float32), array([0.6223371], dtype=float32), array([0.6225014], dtype=float32), array([0.6226621], dtype=float32), array([0.62281936], dtype=float32), array([0.6229733], dtype=float32), array([0.62312394], dtype=float32), array([0.62327135], dtype=float32), array([0.6234155], dtype=float32), array([0.62355655], dtype=float32), array([0.6236946], dtype=float32), array([0.6238296], dtype=float32), arr ...
# 1/1 [==============================] - 0s 29ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32), array([0.6045207], dtype=float32), array([0.6050471], dtype=float32), array([0.6055622], dtype=float32), array([0.60606635], dtype=float32), array([0.6065599], dtype=float32), array([0.60704345], dtype=float32), array([0.60751754], dtype=float32), array([0.6079826], dtype=float32), array([0.60843897], dtype=float32), array([0.60888714], dtype=float32), array([0.6093273], dtype=float32), array([0.6097598], dtype=float32), array([0.61018485], dtype=float32), array([0.61060256], dtype=float32), array([0.61101294], dtype=float32), array([0.61141616], dtype=float32), array([0.6118122], dtype=float32), array([0.61220104], dtype=float32), array([0.6125827], dtype=float32), array([0.612957], dtype=float32), array([0.61332387], dtype=float32), array([0.61368304], dtype=float32), array([0.6140344], dtype=float32), array([0.614378], dtype=float32), array([0.61471415], dtype=float32), array([0.6150429], dtype=float32), array([0.6153645], dtype=float32), array([0.61567897], dtype=float32), array([0.6159864], dtype=float32), array([0.6162868], dtype=float32), array([0.61658025], dtype=float32), array([0.61686695], dtype=float32), array([0.6171471], dtype=float32), array([0.6174209], dtype=float32), array([0.61768854], dtype=float32), array([0.6179502], dtype=float32), array([0.6182062], dtype=float32), array([0.6184566], dtype=float32), array([0.61870176], dtype=float32), array([0.6189418], dtype=float32), array([0.6191769], dtype=float32), array([0.619407], dtype=float32), array([0.6196322], dtype=float32), array([0.61985284], dtype=float32), array([0.6200689], dtype=float32), array([0.6202805], dtype=float32), array([0.6204877], dtype=float32), array([0.6206906], dtype=float32), array([0.6208893], dtype=float32), array([0.6210839], dtype=float32), array([0.6212745], dtype=float32), array([0.6214611], dtype=float32), array([0.62164384], dtype=float32), array([0.62182266], dtype=float32), array([0.62199783], dtype=float32), array([0.6221693], dtype=float32), array([0.6223371], dtype=float32), array([0.6225014], dtype=float32), array([0.6226621], dtype=float32), array([0.62281936], dtype=float32), array([0.6229733], dtype=float32), array([0.62312394], dtype=float32), array([0.62327135], dtype=float32), array([0.6234155], dtype=float32), array([0.62355655], dtype=float32), array([0.6236946], dtype=float32), array([0.6238296], dtype=float32), arr ...
# 1/1 [==============================] - 0s 31ms/step
# [array([0.56484777], dtype=float32), array([0.56640226], dtype=float32), array([0.5679411], dtype=float32), array([0.56931186], dtype=float32), array([0.57054085], dtype=float32), array([0.57158417], dtype=float32), array([0.57245404], dtype=float32), array([0.57333195], dtype=float32), array([0.5742858], dtype=float32), array([0.5753292], dtype=float32), array([0.5763599], dtype=float32), array([0.57741654], dtype=float32), array([0.5783919], dtype=float32), array([0.57928675], dtype=float32), array([0.5801018], dtype=float32), array([0.580883], dtype=float32), array([0.5817556], dtype=float32), array([0.58269006], dtype=float32), array([0.5835444], dtype=float32), array([0.58439213], dtype=float32), array([0.58531374], dtype=float32), array([0.58624446], dtype=float32), array([0.58721006], dtype=float32), array([0.5882359], dtype=float32), array([0.58919716], dtype=float32), array([0.5900087], dtype=float32), array([0.59080195], dtype=float32), array([0.59164083], dtype=float32), array([0.59250236], dtype=float32), array([0.5933136], dtype=float32), array([0.59411186], dtype=float32), array([0.5948972], dtype=float32), array([0.595662], dtype=float32), array([0.596406], dtype=float32), array([0.59713], dtype=float32), array([0.5978349], dtype=float32), array([0.5985213], dtype=float32), array([0.59919], dtype=float32), array([0.5998417], dtype=float32), array([0.60047716], dtype=float32), array([0.60109687], dtype=float32), array([0.60170156], dtype=float32), array([0.60229194], dtype=float32), array([0.60286856], dtype=float32), array([0.6034319], dtype=float32), array([0.60398245], dtype=float32), array([0.6045207], dtype=float32), array([0.6050471], dtype=float32), array([0.6055622], dtype=float32), array([0.60606635], dtype=float32), array([0.6065599], dtype=float32), array([0.60704345], dtype=float32), array([0.60751754], dtype=float32), array([0.6079826], dtype=float32), array([0.60843897], dtype=float32), array([0.60888714], dtype=float32), array([0.6093273], dtype=float32), array([0.6097598], dtype=float32), array([0.61018485], dtype=float32), array([0.61060256], dtype=float32), array([0.61101294], dtype=float32), array([0.61141616], dtype=float32), array([0.6118122], dtype=float32), array([0.61220104], dtype=float32), array([0.6125827], dtype=float32), array([0.612957], dtype=float32), array([0.61332387], dtype=float32), array([0.61368304], dtype=float32), array([0.6140344], dtype=float32), array([0.614378], dtype=float32), array([0.61471415], dtype=float32), array([0.6150429], dtype=float32), array([0.6153645], dtype=float32), array([0.61567897], dtype=float32), array([0.6159864], dtype=float32), array([0.6162868], dtype=float32), array([0.61658025], dtype=float32), array([0.61686695], dtype=float32), array([0.6171471], dtype=float32), array([0.6174209], dtype=float32), array([0.61768854], dtype=float32), array([0.6179502], dtype=float32), array([0.6182062], dtype=float32), array([0.6184566], dtype=float32), array([0.61870176], dtype=float32), array([0.6189418], dtype=float32), array([0.6191769], dtype=float32), array([0.619407], dtype=float32), array([0.6196322], dtype=float32), array([0.61985284], dtype=float32), array([0.6200689], dtype=float32), array([0.6202805], dtype=float32), array([0.6204877], dtype=float32), array([0.6206906], dtype=float32), array([0.6208893], dtype=float32), array([0.6210839], dtype=float32), array([0.6212745], dtype=float32), array([0.6214611], dtype=float32), array([0.62164384], dtype=float32), array([0.62182266], dtype=float32), array([0.62199783], dtype=float32), array([0.6221693], dtype=float32), array([0.6223371], dtype=float32), array([0.6225014], dtype=float32), array([0.6226621], dtype=float32), array([0.62281936], dtype=float32), array([0.6229733], dtype=float32), array([0.62312394], dtype=float32), array([0.62327135], dtype=float32), array([0.6234155], dtype=float32), array([0.62355655], dtype=float32), array([0.6236946], dtype=float32), array([0.6238296], dtype=float32), arr ...
# 1/1 [==============================] - 0s 32ms/step

# %%
forcasted_output = np.asanyarray(forcast)   
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"
df_result

# %%
plt.figure(figsize=(16, 8))
plt.title('Tesla Close Stock Price Forecasting For Next 30 Days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Suhu' ,fontsize=18)
plt.plot(df['Suhu'])
plt.plot(df_result.set_index('Date')[['Forecasted']])

# %%
# Step 1: Filter data aktual tahun 2024
df_2024 = df[df.index.year == 2024]

# Step 2: Gabungkan data aktual tahun 2024 dan hasil forecast
# Data aktual berhenti di akhir tahun 2023, sehingga prediksi forecast dimulai di tahun 2024
combined_forecast = pd.concat([df_2024, df_result], axis=0)

# Step 3: Visualisasi
plt.figure(figsize=(12, 6))
plt.plot(df_2024.index, df_2024.iloc[:, 0], label="Data Aktual Tahun 2024", color='blue')
plt.plot(forecast_df.index, forecast_df['Forecast'], label="Forecast Tahun 2024", color='red')

# Tambahkan judul dan label
plt.title("Prediksi Tahun 2024 Menggunakan LSTM")
plt.xlabel("Tanggal")
plt.ylabel("Nilai")
plt.legend()

# Tampilkan plot
plt.show()

# %%
df = df.drop(columns=['Kelembaban', 'Curah_Hujan'])

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# Define sequence length and features
SEQ_LENGTH = 60  # Panjang sequence untuk 1 tahun (harian)
num_features = len(df.columns)  # Jumlah fitur dalam dataset

# Create sequences and corresponding labels
def create_sequences(data, seq_length):
    sequences = []
    labels = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]  # Ambil window sepanjang seq_length
        label = data[i + seq_length][0]  # Target adalah nilai fitur pertama
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

# Generate sequences and labels
sequences, labels = create_sequences(scaled_data, SEQ_LENGTH)

# Split into train and test sets
train_size = int(0.9 * len(sequences))
train_x, test_x = sequences[:train_size], sequences[train_size:]
train_y, test_y = labels[:train_size], labels[train_size:]

print("Train X shape:", train_x.shape)
print("Train Y shape:", train_y.shape)
print("Test X shape:", test_x.shape)
print("Test Y shape:", test_y.shape)
# Out:
# Train X shape: (4493, 60, 3)
# Train Y shape: (4493,)
# Test X shape: (500, 60, 3)
# Test Y shape: (500,)

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# Define sequence length and features
sequence_length = 10  # Number of time steps in each sequence
num_features = len(df.columns)

# Create sequences and corresponding labels
def create_sequences(df, seq_length):
    sequences = []
    labels = []
    for i in range(len(scaled_data) - sequence_length):
        seq = scaled_data[i:i+sequence_length]
        label = scaled_data[i+sequence_length][0]  # '_tempm' column index
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

SEQ_LENGTH = 365  # for 24 hours sequence
sequences, labels = create_sequences(scaled_data, SEQ_LENGTH)

# Split into train and test sets
train_size = int(0.9 * len(sequences))
train_x, test_x = sequences[:train_size], sequences[train_size:]
train_y, test_y = labels[:train_size], labels[train_size:]

print("Train X shape:", train_x.shape)
print("Train Y shape:", train_y.shape)
print("Test X shape:", test_x.shape)
print("Test Y shape:", test_y.shape)
# Out:
# Train X shape: (4538, 10, 3)
# Train Y shape: (4538,)
# Test X shape: (505, 10, 3)
# Test Y shape: (505,)

# %%
# Create the LSTM model
model = Sequential()

# Add LSTM layers with dropout
model.add(LSTM(units=128, input_shape=(train_x.shape[1], train_x.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=64, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=32, return_sequences=False))
model.add(Dropout(0.2))

# Add a dense output layer
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(
    train_x, train_y,
    epochs=100,
    batch_size=64,
    validation_split=0.2,  # Use part of the training data as validation
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 24s 215ms/step - loss: 0.0219 - val_loss: 0.0101
# Epoch 2/100
# 57/57 [==============================] - 8s 140ms/step - loss: 0.0132 - val_loss: 0.0097
# Epoch 3/100
# 57/57 [==============================] - 8s 142ms/step - loss: 0.0130 - val_loss: 0.0094
# Epoch 4/100
# 57/57 [==============================] - 8s 132ms/step - loss: 0.0120 - val_loss: 0.0093
# Epoch 5/100
# 57/57 [==============================] - 7s 131ms/step - loss: 0.0117 - val_loss: 0.0097
# Epoch 6/100
# 57/57 [==============================] - 8s 133ms/step - loss: 0.0112 - val_loss: 0.0089
# Epoch 7/100
# 57/57 [==============================] - 7s 130ms/step - loss: 0.0114 - val_loss: 0.0089
# Epoch 8/100
# 57/57 [==============================] - 7s 131ms/step - loss: 0.0110 - val_loss: 0.0101
# Epoch 9/100
# 57/57 [==============================] - 6s 104ms/step - loss: 0.0107 - val_loss: 0.0088
# Epoch 10/100
# 57/57 [==============================] - 6s 99ms/step - loss: 0.0098 - val_loss: 0.0081
# Epoch 11/100
# 57/57 [==============================] - 6s 98ms/step - loss: 0.0100 - val_loss: 0.0078
# Epoch 12/100
# 57/57 [==============================] - 6s 100ms/step - loss: 0.0098 - val_loss: 0.0075
# Epoch 13/100
# 57/57 [==============================] - 6s 97ms/step - loss: 0.0091 - val_loss: 0.0073
# Epoch 14/100
# 57/57 [==============================] - 6s 100ms/step - loss: 0.0090 - val_loss: 0.0071
# Epoch 15/100
# 57/57 [==============================] - 6s 97ms/step - loss: 0.0086 - val_loss: 0.0071
# Epoch 16/100
# 57/57 [==============================] - 6s 99ms/step - loss: 0.0088 - val_loss: 0.0073
# Epoch 17/100
# 57/57 [==============================] - 5s 96ms/step - loss: 0.0082 - val_loss: 0.0067
# Epoch 18/100
# 57/57 [==============================] - 6s 100ms/step - loss: 0.0083 - val_loss: 0.0072
# Epoch 19/100
# 57/57 [==============================] - 6s 97ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 20/100
# 57/57 [==============================] - 6s 101ms/step - loss: 0.0077 - val_loss: 0.0064
# Epoch 21/100
# 57/57 [==============================] - 6s 99ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 22/100
# 57/57 [==============================] - 6s 109ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 23/100
# 57/57 [==============================] - 7s 120ms/step - loss: 0.0075 - val_loss: 0.0061
# Epoch 24/100
# 57/57 [==============================] - 7s 127ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 25/100
# 57/57 [==============================] - 11s 191ms/step - loss: 0.0076 - val_loss: 0.0061
# Epoch 26/100
# 57/57 [==============================] - 12s 203ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 27/100
# 57/57 [==============================] - 12s 204ms/step - loss: 0.0072 - val_loss: 0.0069
# Epoch 28/100
# 57/57 [==============================] - 12s 206ms/step - loss: 0.0074 - val_loss: 0.0062
# Epoch 29/100
# 57/57 [==============================] - 12s 204ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 30/100
# 57/57 [==============================] - 12s 206ms/step - loss: 0.0072 - val_loss: 0.0071
# Epoch 31/100
# 57/57 [==============================] - 12s 205ms/step - loss: 0.0073 - val_loss: 0.0061

# %%
# Simple RNN
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Simple RNN Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
predictions = model.predict(test_x)

# Calculate evaluation metrics 90:10
mae = mean_absolute_error(test_y, predictions)
mse = mean_squared_error(test_y, predictions)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# 16/16 [==============================] - 4s 52ms/step
# Mean Absolute Error (MAE): 0.06309246496010891
# Mean Squared Error (MSE): 0.0062057977271654215
# Root Mean Squared Error (RMSE): 0.07877688574172897

# %%
plt.figure(figsize=(10, 6))
plt.plot(test_y, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title('Suhu Prediction vs Actual 90:10')
plt.xlabel('Time')
plt.ylabel('Suhu')
plt.legend()
plt.show()

# %%
# Forecast 365 hari ke depan
forecast_days = 365
forecast = []

# Ambil input terakhir dari dataset (sequences terakhir yang dipakai)
current_sequence = scaled_data[-SEQ_LENGTH:]  # Ambil sequence terakhir

# Iteratif prediksi hari ke depan
for day in range(forecast_days):
    # Prediksi menggunakan model
    prediction = model.predict(current_sequence.reshape(1, SEQ_LENGTH, num_features), verbose=0)
    
    # Simpan hasil prediksi
    forecast.append(prediction[0][0])
    
    # Update sequence: geser ke depan dan tambahkan prediksi
    next_sequence = np.append(current_sequence[1:], [[prediction[0][0]] * num_features], axis=0)
    current_sequence = next_sequence

# Invers transform untuk mengembalikan ke skala aslinya
forecast = scaler.inverse_transform([[val] + [0] * (num_features - 1) for val in forecast])

# Buat dataframe untuk hasil forecast
forecast_index = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=forecast_days, freq='D')
forecast_df = pd.DataFrame(forecast[:, 0], index=forecast_index, columns=['Forecast'])

# Tampilkan hasil prediksi
print(forecast_df)
# Out:
#              Forecast
# 2024-11-01  27.605730
# 2024-11-02  26.760594
# 2024-11-03  26.865978
# 2024-11-04  26.797409
# 2024-11-05  26.780507
# ...               ...
# 2025-10-27  25.684945
# 2025-10-28  25.684945
# 2025-10-29  25.684945
# 2025-10-30  25.684945
# 2025-10-31  25.684945
#
# [365 rows x 1 columns]

# %%
# Visualisasi hasil prediksi
plt.figure(figsize=(12, 6))
plt.plot(df.index, df.iloc[:, 0], label="Actual Data")
plt.plot(forecast_df.index, forecast_df['Forecast'], label="Forecast (365 Days)", color='red')
plt.title("365 Hari Forecast Menggunakan LSTM")
plt.xlabel("Tanggal")
plt.ylabel("Nilai")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(forecast_df.index, forecast_df['Forecast'], label="Forecast (365 Days)", color='red')

# %%
# Step 1: Filter data aktual tahun 2024
df_2024 = df[df.index.year == 2024]

# Step 2: Gabungkan data aktual tahun 2024 dan hasil forecast
# Data aktual berhenti di akhir tahun 2023, sehingga prediksi forecast dimulai di tahun 2024
combined_forecast = pd.concat([df_2024, forecast_df], axis=0)

# Step 3: Visualisasi
plt.figure(figsize=(12, 6))
plt.plot(df_2024.index, df_2024.iloc[:, 0], label="Data Aktual Tahun 2024", color='blue')
plt.plot(forecast_df.index, forecast_df['Forecast'], label="Forecast Tahun 2024", color='red')

# Tambahkan judul dan label
plt.title("Prediksi Tahun 2024 Menggunakan LSTM")
plt.xlabel("Tanggal")
plt.ylabel("Nilai")
plt.legend()

# Tampilkan plot
plt.show()

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 365
forcast = []
Xin = test_x[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0, 0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 [==============================] - 0s 109ms/step
# [0.5039917]
# 1/1 [==============================] - 0s 131ms/step
# [0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 115ms/step
# [0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 117ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 122ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 100ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166]
# 1/1 [==============================] - 0s 110ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 107ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 113ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 114ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 134ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 126ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 99ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 115ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 120ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 124ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 102ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 121ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 118ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 118ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 124ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 133ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 111ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 109ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 110ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 113ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 105ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 136ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 144ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 100ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 109ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 139ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 107ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 118ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 107ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 122ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 108ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 122ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 133ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 103ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 105ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 108ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 120ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 119ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 115ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 112ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 128ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 104ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 109ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 124ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 117ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 108ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 126ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 125ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 114ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 120ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 116ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 124ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 100ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 132ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 108ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 110ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 103ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 114ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 106ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 101ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 101ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 102ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 107ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 107ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 101ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 114ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 103ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 125ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 119ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 125ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 109ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 127ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917]
# 1/1 [==============================] - 0s 144ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166]
# 1/1 [==============================] - 0s 98ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917]
# 1/1 [==============================] - 0s 108ms/step
# ...
# 1/1 [==============================] - 0s 113ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039 ...
# 1/1 [==============================] - 0s 118ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039 ...
# 1/1 [==============================] - 0s 117ms/step
# [0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.5039917, 0.50399166, 0.5039 ...

# %%
time
# Out:
# [Timestamp('2024-10-31 00:00:00'),
#  Timestamp('2024-11-01 00:00:00'),
#  Timestamp('2024-11-02 00:00:00'),
#  Timestamp('2024-11-03 00:00:00'),
#  Timestamp('2024-11-04 00:00:00'),
#  Timestamp('2024-11-05 00:00:00'),
#  Timestamp('2024-11-06 00:00:00'),
#  Timestamp('2024-11-07 00:00:00'),
#  Timestamp('2024-11-08 00:00:00'),
#  Timestamp('2024-11-09 00:00:00'),
#  Timestamp('2024-11-10 00:00:00'),
#  Timestamp('2024-11-11 00:00:00'),
#  Timestamp('2024-11-12 00:00:00'),
#  Timestamp('2024-11-13 00:00:00'),
#  Timestamp('2024-11-14 00:00:00'),
#  Timestamp('2024-11-15 00:00:00'),
#  Timestamp('2024-11-16 00:00:00'),
#  Timestamp('2024-11-17 00:00:00'),
#  Timestamp('2024-11-18 00:00:00'),
#  Timestamp('2024-11-19 00:00:00'),
#  Timestamp('2024-11-20 00:00:00'),
#  Timestamp('2024-11-21 00:00:00'),
#  Timestamp('2024-11-22 00:00:00'),
#  Timestamp('2024-11-23 00:00:00'),
#  Timestamp('2024-11-24 00:00:00'),
#  Timestamp('2024-11-25 00:00:00'),
#  Timestamp('2024-11-26 00:00:00'),
#  Timestamp('2024-11-27 00:00:00'),
#  Timestamp('2024-11-28 00:00:00'),
#  Timestamp('2024-11-29 00:00:00'),
#  Timestamp('2024-11-30 00:00:00'),
#  Timestamp('2024-12-01 00:00:00'),
#  Timestamp('2024-12-02 00:00:00'),
#  Timestamp('2024-12-03 00:00:00'),
#  Timestamp('2024-12-04 00:00:00'),
#  Timestamp('2024-12-05 00:00:00'),
#  Timestamp('2024-12-06 00:00:00'),
#  Timestamp('2024-12-07 00:00:00'),
#  Timestamp('2024-12-08 00:00:00'),
#  Timestamp('2024-12-09 00:00:00'),
#  Timestamp('2024-12-10 00:00:00'),
#  Timestamp('2024-12-11 00:00:00'),
#  Timestamp('2024-12-12 00:00:00'),
#  Timestamp('2024-12-13 00:00:00'),
#  Timestamp('2024-12-14 00:00:00'),
#  Timestamp('2024-12-15 00:00:00'),
#  Timestamp('2024-12-16 00:00:00'),
#  Timestamp('2024-12-17 00:00:00'),
#  Timestamp('2024-12-18 00:00:00'),
#  Timestamp('2024-12-19 00:00:00'),
#  Timestamp('2024-12-20 00:00:00'),
#  Timestamp('2024-12-21 00:00:00'),
#  Timestamp('2024-12-22 00:00:00'),
#  Timestamp('2024-12-23 00:00:00'),
#  Timestamp('2024-12-24 00:00:00'),
#  Timestamp('2024-12-25 00:00:00'),
#  Timestamp('2024-12-26 00:00:00'),
#  Timestamp('2024-12-27 00:00:00'),
#  Timestamp('2024-12-28 00:00:00'),
#  Timestamp('2024-12-29 00:00:00'),
#  Timestamp('2024-12-30 00:00:00'),
#  Timestamp('2024-12-31 00:00:00'),
#  Timestamp('2025-01-01 00:00:00'),
#  Timestamp('2025-01-02 00:00:00'),
#  Timestamp('2025-01-03 00:00:00'),
#  Timestamp('2025-01-04 00:00:00'),
#  Timestamp('2025-01-05 00:00:00'),
#  Timestamp('2025-01-06 00:00:00'),
#  Timestamp('2025-01-07 00:00:00'),
#  Timestamp('2025-01-08 00:00:00'),
#  Timestamp('2025-01-09 00:00:00'),
#  Timestamp('2025-01-10 00:00:00'),
#  Timestamp('2025-01-11 00:00:00'),
#  Timestamp('2025-01-12 00:00:00'),
#  Timestamp('2025-01-13 00:00:00'),
#  Timestamp('2025-01-14 00:00:00'),
#  Timestamp('2025-01-15 00:00:00'),
#  Timestamp('2025-01-16 00:00:00'),
#  Timestamp('2025-01-17 00:00:00'),
#  Timestamp('2025-01-18 00:00:00'),
#  Timestamp('2025-01-19 00:00:00'),
#  Timestamp('2025-01-20 00:00:00'),
#  Timestamp('2025-01-21 00:00:00'),
#  Timestamp('2025-01-22 00:00:00'),
#  Timestamp('2025-01-23 00:00:00'),
#  Timestamp('2025-01-24 00:00:00'),
#  Timestamp('2025-01-25 00:00:00'),
#  Timestamp('2025-01-26 00:00:00'),
#  Timestamp('2025-01-27 00:00:00'),
#  Timestamp('2025-01-28 00:00:00'),
#  Timestamp('2025-01-29 00:00:00'),
#  Timestamp('2025-01-30 00:00:00'),
#  Timestamp('2025-01-31 00:00:00'),
#  Timestamp('2025-02-01 00:00:00'),
#  Timestamp('2025-02-02 00:00:00'),
#  Timestamp('2025-02-03 00:00:00'),
#  Timestamp('2025-02-04 00:00:00'),
#  Timestamp('2025-02-05 00:00:00'),
#  Timestamp('2025-02-06 00:00:00'),
#  Timestamp('2025-02-07 00:00:00'),
#  Timestamp('2025-02-08 00:00:00'),
#  Timestamp('2025-02-09 00:00:00'),
#  Timestamp('2025-02-10 00:00:00'),
#  Timestamp('2025-02-11 00:00:00'),
#  Timestamp('2025-02-12 00:00:00'),
#  Timestamp('2025-02-13 00:00:00'),
#  Timestamp('2025-02-14 00:00:00'),
#  Timestamp('2025-02-15 00:00:00'),
#  Timestamp('2025-02-16 00:00:00'),
#  Timestamp('2025-02-17 00:00:00'),
#  Timestamp('2025-02-18 00:00:00'),
#  Timestamp('2025-02-19 00:00:00'),
#  Timestamp('2025-02-20 00:00:00'),
#  Timestamp('2025-02-21 00:00:00'),
#  Timestamp('2025-02-22 00:00:00'),
#  Timestamp('2025-02-23 00:00:00'),
#  Timestamp('2025-02-24 00:00:00'),
#  Timestamp('2025-02-25 00:00:00'),
#  Timestamp('2025-02-26 00:00:00'),
#  Timestamp('2025-02-27 00:00:00'),
#  Timestamp('2025-02-28 00:00:00'),
#  Timestamp('2025-03-01 00:00:00'),
#  Timestamp('2025-03-02 00:00:00'),
#  Timestamp('2025-03-03 00:00:00'),
#  Timestamp('2025-03-04 00:00:00'),
#  Timestamp('2025-03-05 00:00:00'),
#  Timestamp('2025-03-06 00:00:00'),
#  Timestamp('2025-03-07 00:00:00'),
#  Timestamp('2025-03-08 00:00:00'),
#  Timestamp('2025-03-09 00:00:00'),
#  Timestamp('2025-03-10 00:00:00'),
#  Timestamp('2025-03-11 00:00:00'),
#  Timestamp('2025-03-12 00:00:00'),
#  Timestamp('2025-03-13 00:00:00'),
#  Timestamp('2025-03-14 00:00:00'),
#  Timestamp('2025-03-15 00:00:00'),
#  Timestamp('2025-03-16 00:00:00'),
#  Timestamp('2025-03-17 00:00:00'),
#  Timestamp('2025-03-18 00:00:00'),
#  Timestamp('2025-03-19 00:00:00'),
#  Timestamp('2025-03-20 00:00:00'),
#  Timestamp('2025-03-21 00:00:00'),
#  Timestamp('2025-03-22 00:00:00'),
#  Timestamp('2025-03-23 00:00:00'),
#  Timestamp('2025-03-24 00:00:00'),
#  Timestamp('2025-03-25 00:00:00'),
#  Timestamp('2025-03-26 00:00:00'),
#  Timestamp('2025-03-27 00:00:00'),
#  Timestamp('2025-03-28 00:00:00'),
#  Timestamp('2025-03-29 00:00:00'),
#  Timestamp('2025-03-30 00:00:00'),
#  Timestamp('2025-03-31 00:00:00'),
#  Timestamp('2025-04-01 00:00:00'),
#  Timestamp('2025-04-02 00:00:00'),
#  Timestamp('2025-04-03 00:00:00'),
#  Timestamp('2025-04-04 00:00:00'),
#  Timestamp('2025-04-05 00:00:00'),
#  Timestamp('2025-04-06 00:00:00'),
#  Timestamp('2025-04-07 00:00:00'),
#  Timestamp('2025-04-08 00:00:00'),
#  Timestamp('2025-04-09 00:00:00'),
#  Timestamp('2025-04-10 00:00:00'),
#  Timestamp('2025-04-11 00:00:00'),
#  Timestamp('2025-04-12 00:00:00'),
#  Timestamp('2025-04-13 00:00:00'),
#  Timestamp('2025-04-14 00:00:00'),
#  Timestamp('2025-04-15 00:00:00'),
#  Timestamp('2025-04-16 00:00:00'),
#  Timestamp('2025-04-17 00:00:00'),
#  Timestamp('2025-04-18 00:00:00'),
#  Timestamp('2025-04-19 00:00:00'),
#  Timestamp('2025-04-20 00:00:00'),
#  Timestamp('2025-04-21 00:00:00'),
#  Timestamp('2025-04-22 00:00:00'),
#  Timestamp('2025-04-23 00:00:00'),
#  Timestamp('2025-04-24 00:00:00'),
#  Timestamp('2025-04-25 00:00:00'),
#  Timestamp('2025-04-26 00:00:00'),
#  Timestamp('2025-04-27 00:00:00'),
#  Timestamp('2025-04-28 00:00:00'),
#  Timestamp('2025-04-29 00:00:00'),
#  Timestamp('2025-04-30 00:00:00'),
#  Timestamp('2025-05-01 00:00:00'),
#  Timestamp('2025-05-02 00:00:00'),
#  Timestamp('2025-05-03 00:00:00'),
#  Timestamp('2025-05-04 00:00:00'),
#  Timestamp('2025-05-05 00:00:00'),
#  Timestamp('2025-05-06 00:00:00'),
#  Timestamp('2025-05-07 00:00:00'),
#  Timestamp('2025-05-08 00:00:00'),
#  Timestamp('2025-05-09 00:00:00'),
#  Timestamp('2025-05-10 00:00:00'),
#  Timestamp('2025-05-11 00:00:00'),
#  Timestamp('2025-05-12 00:00:00'),
#  Timestamp('2025-05-13 00:00:00'),
#  Timestamp('2025-05-14 00:00:00'),
#  Timestamp('2025-05-15 00:00:00'),
#  Timestamp('2025-05-16 00:00:00'),
#  Timestamp('2025-05-17 00:00:00'),
#  Timestamp('2025-05-18 00:00:00'),
#  Timestamp('2025-05-19 00:00:00'),
#  Timestamp('2025-05-20 00:00:00'),
#  Timestamp('2025-05-21 00:00:00'),
#  Timestamp('2025-05-22 00:00:00'),
#  Timestamp('2025-05-23 00:00:00'),
#  Timestamp('2025-05-24 00:00:00'),
#  Timestamp('2025-05-25 00:00:00'),
#  Timestamp('2025-05-26 00:00:00'),
#  Timestamp('2025-05-27 00:00:00'),
#  Timestamp('2025-05-28 00:00:00'),
#  Timestamp('2025-05-29 00:00:00'),
#  Timestamp('2025-05-30 00:00:00'),
#  Timestamp('2025-05-31 00:00:00'),
#  Timestamp('2025-06-01 00:00:00'),
#  Timestamp('2025-06-02 00:00:00'),
#  Timestamp('2025-06-03 00:00:00'),
#  Timestamp('2025-06-04 00:00:00'),
#  Timestamp('2025-06-05 00:00:00'),
#  Timestamp('2025-06-06 00:00:00'),
#  Timestamp('2025-06-07 00:00:00'),
#  Timestamp('2025-06-08 00:00:00'),
#  Timestamp('2025-06-09 00:00:00'),
#  Timestamp('2025-06-10 00:00:00'),
#  Timestamp('2025-06-11 00:00:00'),
#  Timestamp('2025-06-12 00:00:00'),
#  Timestamp('2025-06-13 00:00:00'),
#  Timestamp('2025-06-14 00:00:00'),
#  Timestamp('2025-06-15 00:00:00'),
#  Timestamp('2025-06-16 00:00:00'),
#  Timestamp('2025-06-17 00:00:00'),
#  Timestamp('2025-06-18 00:00:00'),
#  Timestamp('2025-06-19 00:00:00'),
#  Timestamp('2025-06-20 00:00:00'),
#  Timestamp('2025-06-21 00:00:00'),
#  Timestamp('2025-06-22 00:00:00'),
#  Timestamp('2025-06-23 00:00:00'),
#  Timestamp('2025-06-24 00:00:00'),
#  Timestamp('2025-06-25 00:00:00'),
#  Timestamp('2025-06-26 00:00:00'),
#  Timestamp('2025-06-27 00:00:00'),
#  Timestamp('2025-06-28 00:00:00'),
#  Timestamp('2025-06-29 00:00:00'),
#  Timestamp('2025-06-30 00:00:00'),
#  Timestamp('2025-07-01 00:00:00'),
#  Timestamp('2025-07-02 00:00:00'),
#  Timestamp('2025-07-03 00:00:00'),
#  Timestamp('2025-07-04 00:00:00'),
#  Timestamp('2025-07-05 00:00:00'),
#  Timestamp('2025-07-06 00:00:00'),
#  Timestamp('2025-07-07 00:00:00'),
#  Timestamp('2025-07-08 00:00:00'),
#  Timestamp('2025-07-09 00:00:00'),
#  Timestamp('2025-07-10 00:00:00'),
#  Timestamp('2025-07-11 00:00:00'),
#  Timestamp('2025-07-12 00:00:00'),
#  Timestamp('2025-07-13 00:00:00'),
#  Timestamp('2025-07-14 00:00:00'),
#  Timestamp('2025-07-15 00:00:00'),
#  Timestamp('2025-07-16 00:00:00'),
#  Timestamp('2025-07-17 00:00:00'),
#  Timestamp('2025-07-18 00:00:00'),
#  Timestamp('2025-07-19 00:00:00'),
#  Timestamp('2025-07-20 00:00:00'),
#  Timestamp('2025-07-21 00:00:00'),
#  Timestamp('2025-07-22 00:00:00'),
#  Timestamp('2025-07-23 00:00:00'),
#  Timestamp('2025-07-24 00:00:00'),
#  Timestamp('2025-07-25 00:00:00'),
#  Timestamp('2025-07-26 00:00:00'),
#  Timestamp('2025-07-27 00:00:00'),
#  Timestamp('2025-07-28 00:00:00'),
#  Timestamp('2025-07-29 00:00:00'),
#  Timestamp('2025-07-30 00:00:00'),
#  Timestamp('2025-07-31 00:00:00'),
#  Timestamp('2025-08-01 00:00:00'),
#  Timestamp('2025-08-02 00:00:00'),
#  Timestamp('2025-08-03 00:00:00'),
#  Timestamp('2025-08-04 00:00:00'),
#  Timestamp('2025-08-05 00:00:00'),
#  Timestamp('2025-08-06 00:00:00'),
#  Timestamp('2025-08-07 00:00:00'),
#  Timestamp('2025-08-08 00:00:00'),
#  Timestamp('2025-08-09 00:00:00'),
#  Timestamp('2025-08-10 00:00:00'),
#  Timestamp('2025-08-11 00:00:00'),
#  Timestamp('2025-08-12 00:00:00'),
#  Timestamp('2025-08-13 00:00:00'),
#  Timestamp('2025-08-14 00:00:00'),
#  Timestamp('2025-08-15 00:00:00'),
#  Timestamp('2025-08-16 00:00:00'),
#  Timestamp('2025-08-17 00:00:00'),
#  Timestamp('2025-08-18 00:00:00'),
#  Timestamp('2025-08-19 00:00:00'),
#  Timestamp('2025-08-20 00:00:00'),
#  Timestamp('2025-08-21 00:00:00'),
#  Timestamp('2025-08-22 00:00:00'),
#  Timestamp('2025-08-23 00:00:00'),
#  Timestamp('2025-08-24 00:00:00'),
#  Timestamp('2025-08-25 00:00:00'),
#  Timestamp('2025-08-26 00:00:00'),
#  Timestamp('2025-08-27 00:00:00'),
#  Timestamp('2025-08-28 00:00:00'),
#  Timestamp('2025-08-29 00:00:00'),
#  Timestamp('2025-08-30 00:00:00'),
#  Timestamp('2025-08-31 00:00:00'),
#  Timestamp('2025-09-01 00:00:00'),
#  Timestamp('2025-09-02 00:00:00'),
#  Timestamp('2025-09-03 00:00:00'),
#  Timestamp('2025-09-04 00:00:00'),
#  Timestamp('2025-09-05 00:00:00'),
#  Timestamp('2025-09-06 00:00:00'),
#  Timestamp('2025-09-07 00:00:00'),
#  Timestamp('2025-09-08 00:00:00'),
#  Timestamp('2025-09-09 00:00:00'),
#  Timestamp('2025-09-10 00:00:00'),
#  Timestamp('2025-09-11 00:00:00'),
#  Timestamp('2025-09-12 00:00:00'),
#  Timestamp('2025-09-13 00:00:00'),
#  Timestamp('2025-09-14 00:00:00'),
#  Timestamp('2025-09-15 00:00:00'),
#  Timestamp('2025-09-16 00:00:00'),
#  Timestamp('2025-09-17 00:00:00'),
#  Timestamp('2025-09-18 00:00:00'),
#  Timestamp('2025-09-19 00:00:00'),
#  Timestamp('2025-09-20 00:00:00'),
#  Timestamp('2025-09-21 00:00:00'),
#  Timestamp('2025-09-22 00:00:00'),
#  Timestamp('2025-09-23 00:00:00'),
#  Timestamp('2025-09-24 00:00:00'),
#  Timestamp('2025-09-25 00:00:00'),
#  Timestamp('2025-09-26 00:00:00'),
#  Timestamp('2025-09-27 00:00:00'),
#  Timestamp('2025-09-28 00:00:00'),
#  Timestamp('2025-09-29 00:00:00'),
#  Timestamp('2025-09-30 00:00:00'),
#  Timestamp('2025-10-01 00:00:00'),
#  Timestamp('2025-10-02 00:00:00'),
#  Timestamp('2025-10-03 00:00:00'),
#  Timestamp('2025-10-04 00:00:00'),
#  Timestamp('2025-10-05 00:00:00'),
#  Timestamp('2025-10-06 00:00:00'),
#  Timestamp('2025-10-07 00:00:00'),
#  Timestamp('2025-10-08 00:00:00'),
#  Timestamp('2025-10-09 00:00:00'),
#  Timestamp('2025-10-10 00:00:00'),
#  Timestamp('2025-10-11 00:00:00'),
#  Timestamp('2025-10-12 00:00:00'),
#  Timestamp('2025-10-13 00:00:00'),
#  Timestamp('2025-10-14 00:00:00'),
#  Timestamp('2025-10-15 00:00:00'),
#  Timestamp('2025-10-16 00:00:00'),
#  Timestamp('2025-10-17 00:00:00'),
#  Timestamp('2025-10-18 00:00:00'),
#  Timestamp('2025-10-19 00:00:00'),
#  Timestamp('2025-10-20 00:00:00'),
#  Timestamp('2025-10-21 00:00:00'),
#  Timestamp('2025-10-22 00:00:00'),
#  Timestamp('2025-10-23 00:00:00'),
#  Timestamp('2025-10-24 00:00:00'),
#  Timestamp('2025-10-25 00:00:00'),
#  Timestamp('2025-10-26 00:00:00'),
#  Timestamp('2025-10-27 00:00:00'),
#  Timestamp('2025-10-28 00:00:00'),
#  Timestamp('2025-10-29 00:00:00'),
#  Timestamp('2025-10-30 00:00:00')]

# %%
forcasted_output = np.asanyarray(forcast)   
forcasted_output = forcasted_output.reshape(-1, 1) 
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"

# %%
df_result
# Out:
#           Date  Forecasted
# 0   2024-10-31   27.242754
# 1   2024-11-01   27.242754
# 2   2024-11-02   27.242754
# 3   2024-11-03   27.242754
# 4   2024-11-04   27.242754
# ..         ...         ...
# 360 2025-10-26   27.242754
# 361 2025-10-27   27.242754
# 362 2025-10-28   27.242754
# 363 2025-10-29   27.242754
# 364 2025-10-30   27.242754
#
# [365 rows x 2 columns]

# %%
plt.figure(figsize=(16, 8))
plt.title('Tesla Close Stock Price Forecasting For Next 30 Days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Suhu' ,fontsize=18)
plt.plot(df['Suhu'])
plt.plot(df_result.set_index('Date')[['Forecasted']])

# %%
# Pastikan forecasted_output berbentuk array dan memiliki dimensi (n, 1)
forcasted_output = np.asarray(forcasted_output)
forcasted_output = forcasted_output.reshape(-1, 1)

# Tambahkan dua kolom dummy untuk mencocokkan jumlah kolom dengan yang diharapkan scaler
dummy_columns = np.zeros((forcasted_output.shape[0], 2))  # Dua kolom dengan nilai nol
forcasted_output_full = np.hstack([forcasted_output, dummy_columns])

# Inverse transformasi
inversed_output_full = scaler.inverse_transform(forcasted_output_full)

# Ambil hanya kolom pertama (suhu) dari hasil inverse transformasi
inversed_output = inversed_output_full[:, 0]

# Hasil inversed_output akan berisi suhu dalam skala asli
print(inversed_output)
# Out:
# [27.25752908 27.25752908 27.25752908 27.25752908 27.25752908 27.25752908
#  27.25752908 27.25752908 27.25752908 27.25752908 27.25752908 27.25752874
#  27.25752908 27.25752908 27.25752908 27.25752908 27.25752908 27.25752908
#  27.25752908 27.25752908 27.25752908 27.25752908 27.25752908 27.25752908
#  27.25752908 27.25752908 27.25752908 27.25752908 27.25752908 27.25752908]

# %%
# 3. Menyiapkan input untuk prediksi
lookback = 10  # Jumlah hari sebelumnya digunakan untuk prediksi, sesuaikan dengan model Anda
last_sequence = scaled_data[-lookback:]  # Mengambil data terakhir sebagai input

predictions = []

# 4. Prediksi iteratif 365 hari ke depan
for _ in range(365):
    # Tambahkan dimensi batch untuk input ke model
    input_data = last_sequence[-lookback:].reshape(1, lookback, 1)
    
    # Prediksi langkah berikutnya
    next_prediction = model.predict(input_data)
    
    # Simpan prediksi
    predictions.append(next_prediction[0, 0])
    
    # Tambahkan prediksi ke data input untuk prediksi iteratif
    last_sequence = np.append(last_sequence, [[next_prediction[0, 0]]], axis=0)

# 5. Invers transformasi prediksi ke skala asli
predicted_values = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))

# 6. Membuat DataFrame untuk hasil prediksi
future_dates = pd.date_range(df.index[-1] + pd.Timedelta(days=1), periods=365)
predicted_df = pd.DataFrame(data=predicted_values, index=future_dates, columns=['Predicted_Suhu'])

# Menampilkan hasil prediksi
print(predicted_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 10
#       7 # 4. Prediksi iteratif 365 hari ke depan
#       8 for _ in range(365):
#       9     # Tambahkan dimensi batch untuk input ke model
# ---> 10     input_data = last_sequence[-lookback:].reshape(1, lookback, 1)
#      12     # Prediksi langkah berikutnya
#      13     next_prediction = model.predict(input_data)
#
# ValueError: cannot reshape array of size 30 into shape (1,10,1)

# %%
lookback = 30  # Ganti nilai ini sesuai dengan konfigurasi model
last_sequence = scaled_data[-lookback:]  # Ambil data terakhir dengan ukuran lookback

# %%
lookback = 30  # Pastikan nilai ini sama dengan saat model dilatih
last_sequence = scaled_data[-lookback:]  # Ambil data terakhir untuk prediksi

predictions = []

# Prediksi iteratif 365 hari ke depan
for _ in range(365):
    # Tambahkan dimensi batch untuk input ke model
    input_data = last_sequence.reshape(1, lookback, 1)
    
    # Prediksi langkah berikutnya
    next_prediction = model.predict(input_data)
    
    # Simpan prediksi
    predictions.append(next_prediction[0, 0])
    
    # Tambahkan prediksi ke data input untuk prediksi iteratif
    last_sequence = np.append(last_sequence, [[next_prediction[0, 0]]], axis=0)
    last_sequence = last_sequence[-lookback:]  # Hanya simpan data ukuran lookback
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 9
#       6 # Prediksi iteratif 365 hari ke depan
#       7 for _ in range(365):
#       8     # Tambahkan dimensi batch untuk input ke model
# ----> 9     input_data = last_sequence.reshape(1, lookback, 1)
#      11     # Prediksi langkah berikutnya
#      12     next_prediction = model.predict(input_data)
#
# ValueError: cannot reshape array of size 90 into shape (1,30,1)

# %%
lookback = 30  # Sesuaikan dengan model Anda
last_sequence = scaled_data[-lookback:]  # Ambil data terakhir dengan panjang lookback

predictions = []

# Prediksi iteratif 365 hari ke depan
for _ in range(365):
    # Pastikan input memiliki dimensi yang benar
    input_data = last_sequence.reshape(1, lookback, 1)
    
    # Prediksi langkah berikutnya
    next_prediction = model.predict(input_data)
    
    # Simpan prediksi
    predictions.append(next_prediction[0, 0])
    
    # Tambahkan prediksi ke sequence dan potong agar sesuai ukuran lookback
    last_sequence = np.append(last_sequence, next_prediction[0, 0])
    last_sequence = last_sequence[-lookback:]  # Hanya simpan data terakhir sesuai lookback
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 9
#       6 # Prediksi iteratif 365 hari ke depan
#       7 for _ in range(365):
#       8     # Pastikan input memiliki dimensi yang benar
# ----> 9     input_data = last_sequence.reshape(1, lookback, 1)
#      11     # Prediksi langkah berikutnya
#      12     next_prediction = model.predict(input_data)
#
# ValueError: cannot reshape array of size 90 into shape (1,30,1)
