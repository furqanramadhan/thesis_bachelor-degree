# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.api import ExponentialSmoothing as HWES
from scipy import stats
import statsmodels.api as sm

# %%
df = pd.read_csv("bmkg.csv", header=0, infer_datetime_format=True, parse_dates=[0], index_col=[0])
df.index.freq = 'D'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5053 entries, 2011-01-01 to 2024-10-31
# Freq: D
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Suhu         4808 non-null   float64
#  1   Kelembaban   4808 non-null   float64
#  2   Curah_Hujan  3478 non-null   float64
# dtypes: float64(3)
# memory usage: 157.9 KB

# %%
df.describe()
# Out:
#               Suhu   Kelembaban  Curah_Hujan
# count  4808.000000  4808.000000  3478.000000
# mean     27.362230    78.897671  1092.303910
# std       1.231762     7.405878  2905.192928
# min      23.100000    46.000000     0.000000
# 25%      26.500000    75.000000     0.000000
# 50%      27.300000    80.000000     2.800000
# 75%      28.200000    84.000000    20.600000
# max      33.000000    98.000000  8888.000000

# %%
# Menghitung berapa kali angka 2 muncul di kolom tertentu, misalnya kolom 'nilai'
jumlah_angka_dua = (df['Curah_Hujan'] == 8888).sum()

# Menampilkan hasil
print(f'Jumlah null : {jumlah_angka_dua}')
# Out:
# Jumlah null : 424

# %%
# Mengganti nilai spesifik dengan 0 di kolom tertentu
nilai_spesifik = 8888  # Nilai yang ingin diubah
cols_to_replace = ['Curah_Hujan', 'Kelembaban', 'Suhu']  # Kolom target

for col in cols_to_replace:
    df[col] = df[col].replace(nilai_spesifik, 0)  # Mengganti nilai spesifik dengan 0

print(df)
# Out:
#             Suhu  Kelembaban  Curah_Hujan
# Tanggal
# 2011-01-01  25.2        89.0         22.0
# 2011-01-02  26.5        85.0          5.0
# 2011-01-03  26.8        86.0          5.0
# 2011-01-04  25.9        89.0         16.0
# 2011-01-05  26.5        85.0          0.0
# ...          ...         ...          ...
# 2024-10-27  27.5        75.0          0.0
# 2024-10-28  28.8        75.0          4.5
# 2024-10-29  28.3        75.0          0.0
# 2024-10-30  27.3        76.0          0.0
# 2024-10-31  27.7        74.0          0.0
#
# [5053 rows x 3 columns]

# %%
# Mengisi data kosong dengan mean dari masing-masing kolom
cols_to_fill = ['Curah_Hujan', 'Kelembaban', 'Suhu']  # Kolom target

for col in cols_to_fill:
    mean_value = df[col].mean()  # Menghitung mean dari kolom
    df[col] = df[col].fillna(mean_value)  # Mengisi nilai kosong dengan mean

print(df)
# Out:
#             Suhu  Kelembaban  Curah_Hujan
# Tanggal
# 2011-01-01  25.2        89.0         22.0
# 2011-01-02  26.5        85.0          5.0
# 2011-01-03  26.8        86.0          5.0
# 2011-01-04  25.9        89.0         16.0
# 2011-01-05  26.5        85.0          0.0
# ...          ...         ...          ...
# 2024-10-27  27.5        75.0          0.0
# 2024-10-28  28.8        75.0          4.5
# 2024-10-29  28.3        75.0          0.0
# 2024-10-30  27.3        76.0          0.0
# 2024-10-31  27.7        74.0          0.0
#
# [5053 rows x 3 columns]

# %%
df.describe()
#BMKG Setelah Imputasi
# Out:
#               Suhu   Kelembaban  Curah_Hujan
# count  5053.000000  5053.000000  5053.000000
# mean     27.362230    78.897671     8.775446
# std       1.201523     7.224070    15.939607
# min      23.100000    46.000000     0.000000
# 25%      26.600000    75.000000     0.000000
# 50%      27.362230    79.000000     6.500000
# 75%      28.100000    84.000000     8.775446
# max      33.000000    98.000000   200.000000

# %%
plt.figure(figsize=(15, 6), dpi=100)
plt.title('Suhu')
plt.plot(df['Suhu'])

# %%
df = df.drop(columns=['Curah_Hujan', 'Kelembaban'])
df
# Out:
#              Suhu
# Tanggal
# 2021-01-01  26.51
# 2021-01-02  26.40
# 2021-01-03  25.82
# 2021-01-04  25.57
# 2021-01-05  25.65
# ...           ...
# 2024-07-27  28.78
# 2024-07-28  28.01
# 2024-07-29  27.41
# 2024-07-30  28.19
# 2024-07-31  28.07
#
# [1308 rows x 1 columns]

# %%
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
su_decompose = seasonal_decompose(df, model = "additive")
fig = su_decompose.plot()
fig.set_size_inches(16,9)
plt.show()

# %%
# Tentukan proporsi pembagian
train_size = int(len(df) * 0.9)

# Membagi data
train = df.iloc[:train_size]
test = df.iloc[train_size:]

# %%
train.tail()
# Out:
#             Suhu  Kelembaban  Curah_Hujan
# Tanggal
# 2023-06-09  29.1        67.0     0.000000
# 2023-06-10  28.7        70.0     0.000000
# 2023-06-11  30.0        61.0     0.000000
# 2023-06-12  29.4        61.0     0.000000
# 2023-06-13  29.9        56.0     8.775446

# %%
test
# Out:
#             Suhu  Kelembaban  Curah_Hujan
# Tanggal
# 2023-06-14  29.6        66.0     8.775446
# 2023-06-15  28.4        66.0     0.000000
# 2023-06-16  28.2        69.0     0.000000
# 2023-06-17  29.6        54.0     6.500000
# 2023-06-18  29.7        55.0     0.000000
# ...          ...         ...          ...
# 2024-10-27  27.5        75.0     0.000000
# 2024-10-28  28.8        75.0     4.500000
# 2024-10-29  28.3        75.0     0.000000
# 2024-10-30  27.3        76.0     0.000000
# 2024-10-31  27.7        74.0     0.000000
#
# [506 rows x 3 columns]

# %%
hwmodel=ExponentialSmoothing(train.Suhu,trend='add', seasonal='add', seasonal_periods=365, 
                             damped_trend=True).fit()
print(hwmodel.summary())
# Out:
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                     Suhu   No. Observations:                 4547
# Model:             ExponentialSmoothing   SSE                           3437.308
# Optimized:                         True   AIC                           -532.155
# Trend:                         Additive   BIC                           1844.067
# Seasonal:                      Additive   AICC                          -465.670
# Seasonal Periods:                   365   Date:                 Sun, 22 Dec 2024
# Box-Cox:                          False   Time:                         14:06:47
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.2948718                alpha                 True
# smoothing_trend               4.2618e-09                 beta                 True
# smoothing_seasonal            1.0087e-07                gamma                 True
# initial_level                  26.484104                  l.0                 True
# initial_trend                  0.0106079                  b.0                 True
# damping_trend                  0.9491519                  phi                 True
# initial_seasons.0             -0.7116861                  s.0                 True
# initial_seasons.1             -0.3820866                  s.1                 True
# initial_seasons.2             -0.4754402                  s.2                 True
# initial_seasons.3             -0.5486652                  s.3                 True
# initial_seasons.4             -0.6083310                  s.4                 True
# initial_seasons.5             -0.6398253                  s.5                 True
# initial_seasons.6             -0.8023689                  s.6                 True
# initial_seasons.7             -0.5109961                  s.7                 True
# initial_seasons.8             -0.4117404                  s.8                 True
# initial_seasons.9             -0.4895706                  s.9                 True
# initial_seasons.10            -0.5237870                 s.10                 True
# initial_seasons.11            -0.7755526                 s.11                 True
# initial_seasons.12            -0.6715858                 s.12                 True
# initial_seasons.13            -0.2771331                 s.13                 True
# initial_seasons.14            -0.5192332                 s.14                 True
# initial_seasons.15            -0.4813946                 s.15                 True
# initial_seasons.16            -0.4175899                 s.16                 True
# initial_seasons.17            -0.8643316                 s.17                 True
# initial_seasons.18            -0.9112054                 s.18                 True
# initial_seasons.19            -0.6193907                 s.19                 True
# initial_seasons.20            -0.7354931                 s.20                 True
# initial_seasons.21            -0.6082499                 s.21                 True
# initial_seasons.22            -0.5287718                 s.22                 True
# initial_seasons.23            -0.6248298                 s.23                 True
# initial_seasons.24            -0.6378726                 s.24                 True
# initial_seasons.25            -0.6151264                 s.25                 True
# initial_seasons.26            -0.5313025                 s.26                 True
# initial_seasons.27            -1.1009633                 s.27                 True
# initial_seasons.28            -0.6244267                 s.28                 True
# initial_seasons.29            -0.7404084                 s.29                 True
# initial_seasons.30            -0.4794063                 s.30                 True
# initial_seasons.31            -0.4491195                 s.31                 True
# initial_seasons.32            -0.8112580                 s.32                 True
# initial_seasons.33            -0.5422565                 s.33                 True
# initial_seasons.34            -0.4890902                 s.34                 True
# initial_seasons.35            -0.3106974                 s.35                 True
# initial_seasons.36            -0.3205471                 s.36                 True
# initial_seasons.37            -0.6163890                 s.37                 True
# initial_seasons.38            -0.5213714                 s.38                 True
# initial_seasons.39            -0.6372250                 s.39                 True
# initial_seasons.40            -0.6531287                 s.40                 True
# initial_seasons.41            -0.4719060                 s.41                 True
# initial_seasons.42            -0.7982365                 s.42                 True
# initial_seasons.43            -0.8619912                 s.43                 True
# initial_seasons.44            -0.5807855                 s.44                 True
# initial_seasons.45            -0.3474513                 s.45                 True
# initial_seasons.46            -0.1788619                 s.46                 True
# initial_seasons.47            -0.4868519                 s.47                 True
# initial_seasons.48            -0.5642820                 s.48                 True
# initial_seasons.49            -0.4134732                 s.49                 True
# initial_seasons.50            -0.3649547                 s.50                 True
# initial_seasons.51            -0.7758869                 s.51                 True
# initial_seasons.52            -0.1376845                 s.52                 True
# initial_seasons.53            -0.1583619                 s.53                 True
# initial_seasons.54             0.0308265                 s.54                 True
# initial_seasons.55            -0.7619821                 s.55                 True
# initial_seasons.56            -0.2621896                 s.56                 True
# initial_seasons.57            -0.3703402                 s.57                 True
# initial_seasons.58            -0.3428074                 s.58                 True
# initial_seasons.59            -0.6709760                 s.59                 True
# initial_seasons.60            -0.6454056                 s.60                 True
# initial_seasons.61            -0.3765325                 s.61                 True
# initial_seasons.62            -0.1520625                 s.62                 True
# initial_seasons.63            -0.3570660                 s.63                 True
# initial_seasons.64            -0.1806681                 s.64                 True
# initial_seasons.65             0.0219899                 s.65                 True
# initial_seasons.66            -0.3966053                 s.66                 True
# initial_seasons.67            -0.7815536                 s.67                 True
# initial_seasons.68            -0.2510190                 s.68                 True
# initial_seasons.69            -0.1850455                 s.69                 True
# initial_seasons.70            -0.4333842                 s.70                 True
# initial_seasons.71            -0.5367013                 s.71                 True
# initial_seasons.72            -0.2416747                 s.72                 True
# initial_seasons.73            -0.2652814                 s.73                 True
# initial_seasons.74             0.0421439                 s.74                 True
# initial_seasons.75            -0.1812630                 s.75                 True
# initial_seasons.76            -0.0200333                 s.76                 True
# initial_seasons.77             0.2614759                 s.77                 True
# initial_seasons.78             0.1642609                 s.78                 True
# initial_seasons.79            -0.0189435                 s.79                 True
# initial_seasons.80            -0.3084660                 s.80                 True
# initial_seasons.81            -0.7212338                 s.81                 True
# initial_seasons.82             0.0139353                 s.82                 True
# initial_seasons.83            -0.0046566                 s.83                 True
# initial_seasons.84             0.1517392                 s.84                 True
# initial_seasons.85             0.1205616                 s.85                 True
# initial_seasons.86             0.3971043                 s.86                 True
# initial_seasons.87            -0.5061085                 s.87                 True
# initial_seasons.88            -0.0988315                 s.88                 True
# initial_seasons.89            -0.0452476                 s.89                 True
# initial_seasons.90            -0.0965717                 s.90                 True
# initial_seasons.91             0.0292705                 s.91                 True
# initial_seasons.92            -0.1356370                 s.92                 True
# initial_seasons.93             0.0715076                 s.93                 True
# initial_seasons.94             0.1251112                 s.94                 True
# initial_seasons.95            -0.1860128                 s.95                 True
# initial_seasons.96            -0.0652441                 s.96                 True
# initial_seasons.97             0.3114346                 s.97                 True
# initial_seasons.98             0.0004049                 s.98                 True
# initial_seasons.99            -0.0335410                 s.99                 True
# initial_seasons.100           -0.3108959                s.100                 True
# initial_seasons.101            0.1398332                s.101                 True
# initial_seasons.102            0.1606080                s.102                 True
# initial_seasons.103           -0.0269407                s.103                 True
# initial_seasons.104           -0.1504768                s.104                 True
# initial_seasons.105            0.1185050                s.105                 True
# initial_seasons.106            0.3131752                s.106                 True
# initial_seasons.107            0.6896511                s.107                 True
# initial_seasons.108            0.3787742                s.108                 True
# initial_seasons.109            0.2457347                s.109                 True
# initial_seasons.110            0.6809621                s.110                 True
# initial_seasons.111            0.5730017                s.111                 True
# initial_seasons.112            0.4727279                s.112                 True
# initial_seasons.113            0.5569323                s.113                 True
# initial_seasons.114            0.1904407                s.114                 True
# initial_seasons.115            0.3179412                s.115                 True
# initial_seasons.116            0.0358773                s.116                 True
# initial_seasons.117            0.0095547                s.117                 True
# initial_seasons.118            0.1705660                s.118                 True
# initial_seasons.119            0.4011836                s.119                 True
# initial_seasons.120            0.2205820                s.120                 True
# initial_seasons.121            0.5542127                s.121                 True
# initial_seasons.122            0.6949626                s.122                 True
# initial_seasons.123            0.8995523                s.123                 True
# initial_seasons.124            0.7221588                s.124                 True
# initial_seasons.125            0.5804233                s.125                 True
# initial_seasons.126            0.2598217                s.126                 True
# initial_seasons.127            0.0748951                s.127                 True
# initial_seasons.128            0.3868621                s.128                 True
# initial_seasons.129            0.2326075                s.129                 True
# initial_seasons.130            0.1706837                s.130                 True
# initial_seasons.131            0.2442871                s.131                 True
# initial_seasons.132            0.2143583                s.132                 True
# initial_seasons.133            0.4802840                s.133                 True
# initial_seasons.134            0.6693586                s.134                 True
# initial_seasons.135            0.7046385                s.135                 True
# initial_seasons.136            0.5147819                s.136                 True
# initial_seasons.137            0.8222302                s.137                 True
# initial_seasons.138            0.5313495                s.138                 True
# initial_seasons.139            0.4629300                s.139                 True
# initial_seasons.140            1.1597136                s.140                 True
# initial_seasons.141            0.4748047                s.141                 True
# initial_seasons.142            0.7234124                s.142                 True
# initial_seasons.143            0.8559864                s.143                 True
# initial_seasons.144            0.4816592                s.144                 True
# initial_seasons.145            0.6533175                s.145                 True
# initial_seasons.146            0.1221769                s.146                 True
# initial_seasons.147            0.8342371                s.147                 True
# initial_seasons.148            0.3983780                s.148                 True
# initial_seasons.149            0.6643768                s.149                 True
# initial_seasons.150            0.3563752                s.150                 True
# initial_seasons.151            0.0869473                s.151                 True
# initial_seasons.152            0.7507597                s.152                 True
# initial_seasons.153            0.1707551                s.153                 True
# initial_seasons.154            0.8038600                s.154                 True
# initial_seasons.155            0.4900547                s.155                 True
# initial_seasons.156            0.8233500                s.156                 True
# initial_seasons.157            0.8797153                s.157                 True
# initial_seasons.158            0.5715280                s.158                 True
# initial_seasons.159            0.7251271                s.159                 True
# initial_seasons.160            1.0276267                s.160                 True
# initial_seasons.161            1.0982441                s.161                 True
# initial_seasons.162            1.2470997                s.162                 True
# initial_seasons.163            1.0851029                s.163                 True
# initial_seasons.164            0.9788301                s.164                 True
# initial_seasons.165            0.9224297                s.165                 True
# initial_seasons.166            1.0964104                s.166                 True
# initial_seasons.167            1.0198468                s.167                 True
# initial_seasons.168            0.7642374                s.168                 True
# initial_seasons.169            0.6972659                s.169                 True
# initial_seasons.170            0.9384683                s.170                 True
# initial_seasons.171            1.1713600                s.171                 True
# initial_seasons.172            1.2094623                s.172                 True
# initial_seasons.173            1.1756060                s.173                 True
# initial_seasons.174            1.1115676                s.174                 True
# initial_seasons.175            0.7278939                s.175                 True
# initial_seasons.176            0.3909497                s.176                 True
# initial_seasons.177            0.4521188                s.177                 True
# initial_seasons.178            0.5599459                s.178                 True
# initial_seasons.179            0.9595608                s.179                 True
# initial_seasons.180            0.7257965                s.180                 True
# initial_seasons.181            0.6837177                s.181                 True
# initial_seasons.182            0.8530017                s.182                 True
# initial_seasons.183            1.1441745                s.183                 True
# initial_seasons.184            0.7104074                s.184                 True
# initial_seasons.185            0.7453776                s.185                 True
# initial_seasons.186            1.2313572                s.186                 True
# initial_seasons.187            0.6840931                s.187                 True
# initial_seasons.188            0.6420012                s.188                 True
# initial_seasons.189            0.5332518                s.189                 True
# initial_seasons.190            1.2244309                s.190                 True
# initial_seasons.191            0.5292621                s.191                 True
# initial_seasons.192            0.7956018                s.192                 True
# initial_seasons.193            0.6733347                s.193                 True
# initial_seasons.194            1.0728415                s.194                 True
# initial_seasons.195            1.1641598                s.195                 True
# initial_seasons.196            1.1471424                s.196                 True
# initial_seasons.197            0.7519131                s.197                 True
# initial_seasons.198            0.9880093                s.198                 True
# initial_seasons.199            1.0375766                s.199                 True
# initial_seasons.200            1.2289911                s.200                 True
# initial_seasons.201            0.8254839                s.201                 True
# initial_seasons.202            0.3782435                s.202                 True
# initial_seasons.203            1.1246739                s.203                 True
# initial_seasons.204            1.0990681                s.204                 True
# initial_seasons.205            0.8652847                s.205                 True
# initial_seasons.206            0.7513571                s.206                 True
# initial_seasons.207            0.6613920                s.207                 True
# initial_seasons.208            0.5339941                s.208                 True
# initial_seasons.209            0.7054271                s.209                 True
# initial_seasons.210            0.4967577                s.210                 True
# initial_seasons.211            0.5993611                s.211                 True
# initial_seasons.212            0.7322629                s.212                 True
# initial_seasons.213            0.5702892                s.213                 True
# initial_seasons.214            0.8811903                s.214                 True
# initial_seasons.215            1.3024390                s.215                 True
# initial_seasons.216            0.9719512                s.216                 True
# initial_seasons.217            0.8631993                s.217                 True
# initial_seasons.218            0.9513796                s.218                 True
# initial_seasons.219            1.3125157                s.219                 True
# initial_seasons.220            0.7036114                s.220                 True
# initial_seasons.221            1.1415638                s.221                 True
# initial_seasons.222            0.5858553                s.222                 True
# initial_seasons.223            0.4186607                s.223                 True
# initial_seasons.224            0.0348614                s.224                 True
# initial_seasons.225            0.6179260                s.225                 True
# initial_seasons.226            0.6676533                s.226                 True
# initial_seasons.227            0.7505669                s.227                 True
# initial_seasons.228            0.7750597                s.228                 True
# initial_seasons.229            1.0078820                s.229                 True
# initial_seasons.230            0.8575142                s.230                 True
# initial_seasons.231            0.7821069                s.231                 True
# initial_seasons.232            0.5566298                s.232                 True
# initial_seasons.233            0.2332736                s.233                 True
# initial_seasons.234            0.3723598                s.234                 True
# initial_seasons.235            0.2969409                s.235                 True
# initial_seasons.236           -0.1701832                s.236                 True
# initial_seasons.237            0.1042536                s.237                 True
# initial_seasons.238            0.0038486                s.238                 True
# initial_seasons.239           -0.3747485                s.239                 True
# initial_seasons.240            0.0029698                s.240                 True
# initial_seasons.241            0.3328050                s.241                 True
# initial_seasons.242            0.5603874                s.242                 True
# initial_seasons.243            0.3703598                s.243                 True
# initial_seasons.244           -0.2319820                s.244                 True
# initial_seasons.245            0.0978707                s.245                 True
# initial_seasons.246            0.6505989                s.246                 True
# initial_seasons.247            0.4918364                s.247                 True
# initial_seasons.248            0.2798087                s.248                 True
# initial_seasons.249            0.5156515                s.249                 True
# initial_seasons.250            0.1154002                s.250                 True
# initial_seasons.251            0.5451948                s.251                 True
# initial_seasons.252            0.0061854                s.252                 True
# initial_seasons.253           -0.5109139                s.253                 True
# initial_seasons.254           -0.5029631                s.254                 True
# initial_seasons.255           -0.1263080                s.255                 True
# initial_seasons.256           -0.3620742                s.256                 True
# initial_seasons.257            0.1041571                s.257                 True
# initial_seasons.258            0.3140919                s.258                 True
# initial_seasons.259            0.7366076                s.259                 True
# initial_seasons.260            0.4027477                s.260                 True
# initial_seasons.261            0.2407667                s.261                 True
# initial_seasons.262            0.5685039                s.262                 True
# initial_seasons.263            0.2784691                s.263                 True
# initial_seasons.264            0.3979331                s.264                 True
# initial_seasons.265            0.2724299                s.265                 True
# initial_seasons.266            0.4720189                s.266                 True
# initial_seasons.267            0.2413315                s.267                 True
# initial_seasons.268           -0.2590943                s.268                 True
# initial_seasons.269           -0.1542582                s.269                 True
# initial_seasons.270           -0.0765598                s.270                 True
# initial_seasons.271            0.1065352                s.271                 True
# initial_seasons.272           -0.5021136                s.272                 True
# initial_seasons.273            0.1693615                s.273                 True
# initial_seasons.274           -0.3528725                s.274                 True
# initial_seasons.275           -0.0948599                s.275                 True
# initial_seasons.276            0.0046209                s.276                 True
# initial_seasons.277            0.1958837                s.277                 True
# initial_seasons.278           -0.5043804                s.278                 True
# initial_seasons.279           -0.5880821                s.279                 True
# initial_seasons.280           -0.7969108                s.280                 True
# initial_seasons.281           -0.3753952                s.281                 True
# initial_seasons.282           -0.3925434                s.282                 True
# initial_seasons.283           -0.2512917                s.283                 True
# initial_seasons.284           -0.2652421                s.284                 True
# initial_seasons.285           -0.2938629                s.285                 True
# initial_seasons.286            0.2587778                s.286                 True
# initial_seasons.287            0.1916512                s.287                 True
# initial_seasons.288           -0.0785857                s.288                 True
# initial_seasons.289           -0.1091773                s.289                 True
# initial_seasons.290           -0.2014057                s.290                 True
# initial_seasons.291           -0.5185831                s.291                 True
# initial_seasons.292           -0.3606300                s.292                 True
# initial_seasons.293           -0.3444280                s.293                 True
# initial_seasons.294           -0.5896056                s.294                 True
# initial_seasons.295           -0.5785054                s.295                 True
# initial_seasons.296           -0.5404742                s.296                 True
# initial_seasons.297           -0.4960830                s.297                 True
# initial_seasons.298           -0.5662464                s.298                 True
# initial_seasons.299           -1.1082918                s.299                 True
# initial_seasons.300           -0.6169908                s.300                 True
# initial_seasons.301           -0.6038632                s.301                 True
# initial_seasons.302           -0.9979791                s.302                 True
# initial_seasons.303           -0.6734356                s.303                 True
# initial_seasons.304           -0.3633243                s.304                 True
# initial_seasons.305           -0.6722268                s.305                 True
# initial_seasons.306           -0.8694859                s.306                 True
# initial_seasons.307           -0.9833594                s.307                 True
# initial_seasons.308           -1.0003008                s.308                 True
# initial_seasons.309           -1.0173081                s.309                 True
# initial_seasons.310           -0.6594867                s.310                 True
# initial_seasons.311           -0.6882042                s.311                 True
# initial_seasons.312           -0.8187941                s.312                 True
# initial_seasons.313           -1.1107848                s.313                 True
# initial_seasons.314           -1.0695972                s.314                 True
# initial_seasons.315           -0.6030697                s.315                 True
# initial_seasons.316           -0.6617055                s.316                 True
# initial_seasons.317           -0.6486365                s.317                 True
# initial_seasons.318           -0.7355252                s.318                 True
# initial_seasons.319           -0.8463195                s.319                 True
# initial_seasons.320           -0.5967175                s.320                 True
# initial_seasons.321           -0.4887888                s.321                 True
# initial_seasons.322           -0.3225169                s.322                 True
# initial_seasons.323           -0.7229756                s.323                 True
# initial_seasons.324           -0.5650967                s.324                 True
# initial_seasons.325           -0.3154205                s.325                 True
# initial_seasons.326           -0.1825133                s.326                 True
# initial_seasons.327           -0.4777096                s.327                 True
# initial_seasons.328           -0.7415716                s.328                 True
# initial_seasons.329           -0.6418282                s.329                 True
# initial_seasons.330           -0.6255192                s.330                 True
# initial_seasons.331           -0.6122983                s.331                 True
# initial_seasons.332           -0.7677561                s.332                 True
# initial_seasons.333           -0.7764320                s.333                 True
# initial_seasons.334           -0.6852307                s.334                 True
# initial_seasons.335           -0.9772545                s.335                 True
# initial_seasons.336           -1.2110079                s.336                 True
# initial_seasons.337           -0.7280355                s.337                 True
# initial_seasons.338           -0.8565086                s.338                 True
# initial_seasons.339           -0.8287203                s.339                 True
# initial_seasons.340           -0.8207607                s.340                 True
# initial_seasons.341           -0.8459742                s.341                 True
# initial_seasons.342           -0.4879455                s.342                 True
# initial_seasons.343           -0.6050357                s.343                 True
# initial_seasons.344           -0.8306610                s.344                 True
# initial_seasons.345           -0.7560712                s.345                 True
# initial_seasons.346           -0.9815187                s.346                 True
# initial_seasons.347           -0.7069226                s.347                 True
# initial_seasons.348           -0.7905743                s.348                 True
# initial_seasons.349           -0.7742575                s.349                 True
# initial_seasons.350           -0.5912064                s.350                 True
# initial_seasons.351           -0.7415152                s.351                 True
# initial_seasons.352           -0.5836037                s.352                 True
# initial_seasons.353           -0.9089560                s.353                 True
# initial_seasons.354           -1.2176441                s.354                 True
# initial_seasons.355           -1.1680906                s.355                 True
# initial_seasons.356           -1.4215480                s.356                 True
# initial_seasons.357           -0.9270832                s.357                 True
# initial_seasons.358           -0.7024375                s.358                 True
# initial_seasons.359           -0.4444805                s.359                 True
# initial_seasons.360           -0.3396433                s.360                 True
# initial_seasons.361           -0.2899346                s.361                 True
# initial_seasons.362           -0.5287326                s.362                 True
# initial_seasons.363           -0.6072622                s.363                 True
# initial_seasons.364           -0.6878466                s.364                 True
# ----------------------------------------------------------------------------------

# %%
test_pred=hwmodel.forecast(506)

# %%
test_pred
# Out:
# 2023-06-14    29.411733
# 2023-06-15    29.156124
# 2023-06-16    29.089152
# 2023-06-17    29.330355
# 2023-06-18    29.563246
#                 ...
# 2024-10-27    27.718451
# 2024-10-28    28.028562
# 2024-10-29    27.719660
# 2024-10-30    27.522401
# 2024-10-31    27.408527
# Freq: D, Length: 506, dtype: float64

# %%
train['Suhu'].plot(legend=True, label='Train', figsize=(10,6))
test['Suhu'].plot(legend=True, label='Test')
plt.title('Suhu Spliting 80 : 20')
test_pred.plot(legend=True, label='predicted_test')
# Out:
# <AxesSubplot:title={'center':'Suhu Spliting 80 : 20'}, xlabel='Tanggal'>

# %%
#Spliting data 90:10
# Calculate errors
errors = abs(test['Suhu'] - test_pred)
mae = np.mean(np.abs(errors))
mse = np.mean(errors**2)
rmse = np.sqrt(mse)

print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')
# Out:
# MAE: 0.92
# RMSE: 1.20

# %%
# Buat model Holt-Winters dengan parameter manual
hw_model = ExponentialSmoothing(
    df['Suhu'], 
    trend="add",            # Trend aditif
    seasonal="add",         # Seasonal aditif
    seasonal_periods=365     # Jumlah periode musiman (contoh: data bulanan)
)

# Fit model dengan parameter manual
fitted_model = hw_model.fit(
    smoothing_level=0.2948718,  # alpha
    smoothing_slope=4.2618e-09,  # beta
    smoothing_seasonal=1.0087e-07,  # gamma
    optimized=False  # Jangan optimalkan, gunakan parameter manual
)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23920\786571064.py:10: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead.
#   fitted_model = hw_model.fit(

# %%
# Hasil
print(fitted_model.summary())
# Out:
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                     Suhu   No. Observations:                 5053
# Model:             ExponentialSmoothing   SSE                           4524.248
# Optimized:                        False   AIC                            179.488
# Trend:                         Additive   BIC                           2588.223
# Seasonal:                      Additive   AICC                           238.455
# Seasonal Periods:                   365   Date:                 Sun, 22 Dec 2024
# Box-Cox:                          False   Time:                         14:08:18
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.2948718                alpha                False
# smoothing_trend               4.2618e-09                 beta                False
# smoothing_seasonal            1.0087e-07                gamma                False
# initial_level                  26.893114                  l.0                False
# initial_trend                 2.1586e-05                  b.0                False
# initial_seasons.0             -0.4947340                  s.0                False
# initial_seasons.1              0.0043071                  s.1                False
# initial_seasons.2             -0.2463094                  s.2                False
# initial_seasons.3             -0.3717888                  s.3                False
# initial_seasons.4             -0.4227477                  s.4                False
# initial_seasons.5             -0.6472683                  s.5                False
# initial_seasons.6             -0.5962409                  s.6                False
# initial_seasons.7             -0.1972683                  s.7                False
# initial_seasons.8             -0.0496655                  s.8                False
# initial_seasons.9             -0.7518573                  s.9                False
# initial_seasons.10            -0.8045970                 s.10                False
# initial_seasons.11            -1.1803505                 s.11                False
# initial_seasons.12            -0.4908890                 s.12                False
# initial_seasons.13            -0.4309669                 s.13                False
# initial_seasons.14            -0.4656835                 s.14                False
# initial_seasons.15            -0.1171903                 s.15                False
# initial_seasons.16            -0.2842546                 s.16                False
# initial_seasons.17            -0.8585012                 s.17                False
# initial_seasons.18            -0.9850765                 s.18                False
# initial_seasons.19            -0.7103505                 s.19                False
# initial_seasons.20            -1.0105560                 s.20                False
# initial_seasons.21            -0.5602820                 s.21                False
# initial_seasons.22            -0.5356929                 s.22                False
# initial_seasons.23            -0.6867203                 s.23                False
# initial_seasons.24            -0.7861724                 s.24                False
# initial_seasons.25            -0.7359410                 s.25                False
# initial_seasons.26             0.0150864                 s.26                False
# initial_seasons.27            -0.9342972                 s.27                False
# initial_seasons.28            -0.4328589                 s.28                False
# initial_seasons.29            -0.6074479                 s.29                False
# initial_seasons.30            -0.5068999                 s.30                False
# initial_seasons.31            -0.1306671                 s.31                False
# initial_seasons.32            -0.7051876                 s.32                False
# initial_seasons.33            -0.6295027                 s.33                False
# initial_seasons.34            -0.6558041                 s.34                False
# initial_seasons.35            -0.7159316                 s.35                False
# initial_seasons.36            -0.8078589                 s.36                False
# initial_seasons.37            -0.6834068                 s.37                False
# initial_seasons.38            -0.7577219                 s.38                False
# initial_seasons.39            -0.5336123                 s.39                False
# initial_seasons.40            -0.7092972                 s.40                False
# initial_seasons.41            -0.1696302                 s.41                False
# initial_seasons.42            -0.6727809                 s.42                False
# initial_seasons.43            -0.5892287                 s.43                False
# initial_seasons.44            -1.0150506                 s.44                False
# initial_seasons.45            -0.5658041                 s.45                False
# initial_seasons.46            -0.1415575                 s.46                False
# initial_seasons.47            -0.5682698                 s.47                False
# initial_seasons.48            -0.6202561                 s.48                False
# initial_seasons.49            -0.5311371                 s.49                False
# initial_seasons.50            -0.6477219                 s.50                False
# initial_seasons.51            -1.3732013                 s.51                False
# initial_seasons.52            -0.5088083                 s.52                False
# initial_seasons.53            -0.4510095                 s.53                False
# initial_seasons.54            -0.0625069                 s.54                False
# initial_seasons.55            -0.4631919                 s.55                False
# initial_seasons.56            -0.4147672                 s.56                False
# initial_seasons.57            -1.0673014                 s.57                False
# initial_seasons.58            -0.5199727                 s.58                False
# initial_seasons.59            -0.8956576                 s.59                False
# initial_seasons.60            -0.9620369                 s.60                False
# initial_seasons.61            -0.6370369                 s.61                False
# initial_seasons.62            -0.3876534                 s.62                False
# initial_seasons.63            -0.8131328                 s.63                False
# initial_seasons.64            -0.0882698                 s.64                False
# initial_seasons.65            -0.2141602                 s.65                False
# initial_seasons.66            -0.5494932                 s.66                False
# initial_seasons.67            -0.8912150                 s.67                False
# initial_seasons.68            -0.2003836                 s.68                False
# initial_seasons.69            -0.4010001                 s.69                False
# initial_seasons.70            -0.6186808                 s.70                False
# initial_seasons.71            -0.3555206                 s.71                False
# initial_seasons.72            -0.2208725                 s.72                False
# initial_seasons.73            -0.3960095                 s.73                False
# initial_seasons.74             0.3294699                 s.74                False
# initial_seasons.75             0.0034425                 s.75                False
# initial_seasons.76             0.2039478                 s.76                False
# initial_seasons.77             0.1777150                 s.77                False
# initial_seasons.78             0.2279204                 s.78                False
# initial_seasons.79             0.2430669                 s.79                False
# initial_seasons.80             0.0668340                 s.80                False
# initial_seasons.81             0.0009600                 s.81                False
# initial_seasons.82             0.0502066                 s.82                False
# initial_seasons.83            -0.4502470                 s.83                False
# initial_seasons.84             0.7749159                 s.84                False
# initial_seasons.85             0.7146513                 s.85                False
# initial_seasons.86             0.3129390                 s.86                False
# initial_seasons.87            -0.0392528                 s.87                False
# initial_seasons.88             0.2851308                 s.88                False
# initial_seasons.89             0.3327335                 s.89                False
# initial_seasons.90             0.5812267                 s.90                False
# initial_seasons.91            -0.2340994                 s.91                False
# initial_seasons.92             0.2407637                 s.92                False
# initial_seasons.93             0.1409691                 s.93                False
# initial_seasons.94             0.3908321                 s.94                False
# initial_seasons.95             0.0377500                 s.95                False
# initial_seasons.96             0.1880239                 s.96                False
# initial_seasons.97             0.5378184                 s.97                False
# initial_seasons.98             0.5121335                 s.98                False
# initial_seasons.99             0.1265265                 s.99                False
# initial_seasons.100           -1.1238844                s.100                False
# initial_seasons.101           -0.2990214                s.101                False
# initial_seasons.102           -0.0492954                s.102                False
# initial_seasons.103           -0.4986105                s.103                False
# initial_seasons.104           -0.7490899                s.104                False
# initial_seasons.105           -0.1492269                s.105                False
# initial_seasons.106            0.2359691                s.106                False
# initial_seasons.107            0.4612431                s.107                False
# initial_seasons.108            0.3363801                s.108                False
# initial_seasons.109            0.3606267                s.109                False
# initial_seasons.110            0.2843938                s.110                False
# initial_seasons.111            0.4841883                s.111                False
# initial_seasons.112           -0.0416336                s.112                False
# initial_seasons.113            0.5828869                s.113                False
# initial_seasons.114            0.0321335                s.114                False
# initial_seasons.115            0.0815856                s.115                False
# initial_seasons.116           -0.2936199                s.116                False
# initial_seasons.117           -0.4433459                s.117                False
# initial_seasons.118           -0.1673870                s.118                False
# initial_seasons.119            0.2072964                s.119                False
# initial_seasons.120           -0.0687995                s.120                False
# initial_seasons.121            0.2048306                s.121                False
# initial_seasons.122            0.0290772                s.122                False
# initial_seasons.123            0.7043512                s.123                False
# initial_seasons.124            0.5789402                s.124                False
# initial_seasons.125            0.9527073                s.125                False
# initial_seasons.126            0.2506525                s.126                False
# initial_seasons.127            0.2661414                s.127                False
# initial_seasons.128            0.5407305                s.128                False
# initial_seasons.129            0.3900456                s.129                False
# initial_seasons.130            0.1144976                s.130                False
# initial_seasons.131            0.4639497                s.131                False
# initial_seasons.132            0.3978443                s.132                False
# initial_seasons.133            0.2971594                s.133                False
# initial_seasons.134            0.9623058                s.134                False
# initial_seasons.135            0.8866894                s.135                False
# initial_seasons.136            0.5611673                s.136                False
# initial_seasons.137            1.0359618                s.137                False
# initial_seasons.138            0.8856194                s.138                False
# initial_seasons.139            1.0589070                s.139                False
# initial_seasons.140            1.0332906                s.140                False
# initial_seasons.141            0.7343865                s.141                False
# initial_seasons.142            0.4336331                s.142                False
# initial_seasons.143            0.9076057                s.143                False
# initial_seasons.144            0.3321262                s.144                False
# initial_seasons.145            0.1802769                s.145                False
# initial_seasons.146           -0.3198601                s.146                False
# initial_seasons.147            0.3054139                s.147                False
# initial_seasons.148           -0.4474628                s.148                False
# initial_seasons.149            0.6016726                s.149                False
# initial_seasons.150            0.1513987                s.150                False
# initial_seasons.151            0.5261247                s.151                False
# initial_seasons.152            0.8592659                s.152                False
# initial_seasons.153            1.3262617                s.153                False
# initial_seasons.154            1.4516726                s.154                False
# initial_seasons.155            1.0257137                s.155                False
# initial_seasons.156            1.2998492                s.156                False
# initial_seasons.157            1.3997122                s.157                False
# initial_seasons.158            1.4996437                s.158                False
# initial_seasons.159            0.8490958                s.159                False
# initial_seasons.160            1.3820315                s.160                False
# initial_seasons.161            1.3218355                s.161                False
# initial_seasons.162            0.5209451                s.162                False
# initial_seasons.163            0.9693012                s.163                False
# initial_seasons.164            1.3431369                s.164                False
# initial_seasons.165            0.9175204                s.165                False
# initial_seasons.166            1.0412875                s.166                False
# initial_seasons.167            0.6406026                s.167                False
# initial_seasons.168            1.1143012                s.168                False
# initial_seasons.169            0.9632054                s.169                False
# initial_seasons.170            1.0624519                s.170                False
# initial_seasons.171            1.3378629                s.171                False
# initial_seasons.172            1.8621780                s.172                False
# initial_seasons.173            1.7112191                s.173                False
# initial_seasons.174            1.5856026                s.174                False
# initial_seasons.175            1.5343697                s.175                False
# initial_seasons.176            0.7088903                s.176                False
# initial_seasons.177            0.6084793                s.177                False
# initial_seasons.178            0.4829314                s.178                False
# initial_seasons.179            0.6085478                s.179                False
# initial_seasons.180            0.5832054                s.180                False
# initial_seasons.181            0.9582739                s.181                False
# initial_seasons.182            1.2821290                s.182                False
# initial_seasons.183            0.6123394                s.183                False
# initial_seasons.184           -0.0132770                s.184                False
# initial_seasons.185            0.3602847                s.185                False
# initial_seasons.186            1.4843258                s.186                False
# initial_seasons.187            0.3326819                s.187                False
# initial_seasons.188            0.8808326                s.188                False
# initial_seasons.189            0.4554216                s.189                False
# initial_seasons.190            0.9293258                s.190                False
# initial_seasons.191           -0.3980030                s.191                False
# initial_seasons.192            0.6515860                s.192                False
# initial_seasons.193            0.9760381                s.193                False
# initial_seasons.194            1.6015860                s.194                False
# initial_seasons.195            1.4007900                s.195                False
# initial_seasons.196            1.5494201                s.196                False
# initial_seasons.197           -0.0015129                s.197                False
# initial_seasons.198            0.7476225                s.198                False
# initial_seasons.199            0.8226910                s.199                False
# initial_seasons.200            1.1468691                s.200                False
# initial_seasons.201            1.5709102                s.201                False
# initial_seasons.202            1.1202938                s.202                False
# initial_seasons.203            1.7444719                s.203                False
# initial_seasons.204            1.7686499                s.204                False
# initial_seasons.205            0.7187869                s.205                False
# initial_seasons.206            1.7435130                s.206                False
# initial_seasons.207            1.1929650                s.207                False
# initial_seasons.208            1.5431705                s.208                False
# initial_seasons.209            1.4157732                s.209                False
# initial_seasons.210            1.5646773                s.210                False
# initial_seasons.211            1.6633760                s.211                False
# initial_seasons.212            1.4369376                s.212                False
# initial_seasons.213            1.3113897                s.213                False
# initial_seasons.214            1.2104308                s.214                False
# initial_seasons.215            1.5088554                s.215                False
# initial_seasons.216            0.8343349                s.216                False
# initial_seasons.217            0.7338554                s.217                False
# initial_seasons.218           -0.0168036                s.218                False
# initial_seasons.219            0.6338813                s.219                False
# initial_seasons.220            0.4334018                s.220                False
# initial_seasons.221            0.6331964                s.221                False
# initial_seasons.222            0.4584018                s.222                False
# initial_seasons.223            0.0088128                s.223                False
# initial_seasons.224           -0.7925997                s.224                False
# initial_seasons.225            0.5064673                s.225                False
# initial_seasons.226            0.8566043                s.226                False
# initial_seasons.227            0.5822207                s.227                False
# initial_seasons.228            0.3324262                s.228                False
# initial_seasons.229            0.3070152                s.229                False
# initial_seasons.230            0.0317412                s.230                False
# initial_seasons.231            0.2560563                s.231                False
# initial_seasons.232            0.0805342                s.232                False
# initial_seasons.233            0.0062192                s.233                False
# initial_seasons.234            0.1801918                s.234                False
# initial_seasons.235           -0.3697824                s.235                False
# initial_seasons.236           -0.1201248                s.236                False
# initial_seasons.237           -0.1460579                s.237                False
# initial_seasons.238           -0.4980183                s.238                False
# initial_seasons.239           -0.4734719                s.239                False
# initial_seasons.240            0.0257321                s.240                False
# initial_seasons.241            0.4254155                s.241                False
# initial_seasons.242            0.4249619                s.242                False
# initial_seasons.243            0.1502359                s.243                False
# initial_seasons.244            0.3747564                s.244                False
# initial_seasons.245            0.1496879                s.245                False
# initial_seasons.246            0.7000304                s.246                False
# initial_seasons.247            0.0996194                s.247                False
# initial_seasons.248            0.5246194                s.248                False
# initial_seasons.249            0.1734124                s.249                False
# initial_seasons.250            0.1732070                s.250                False
# initial_seasons.251            0.8222054                s.251                False
# initial_seasons.252           -0.2791386                s.252                False
# initial_seasons.253           -0.4542756                s.253                False
# initial_seasons.254           -0.6552086                s.254                False
# initial_seasons.255           -0.6555511                s.255                False
# initial_seasons.256           -0.3817839                s.256                False
# initial_seasons.257           -0.3324004                s.257                False
# initial_seasons.258            0.0921887                s.258                False
# initial_seasons.259            0.7917777                s.259                False
# initial_seasons.260            0.6913668                s.260                False
# initial_seasons.261            0.2150654                s.261                False
# initial_seasons.262            0.7899543                s.262                False
# initial_seasons.263            0.9639527                s.263                False
# initial_seasons.264            0.7881308                s.264                False
# initial_seasons.265            0.6121034                s.265                False
# initial_seasons.266            0.4609390                s.266                False
# initial_seasons.267           -0.0668692                s.267                False
# initial_seasons.268           -0.8680077                s.268                False
# initial_seasons.269           -0.9938722                s.269                False
# initial_seasons.270           -0.6196683                s.270                False
# initial_seasons.271           -0.3199164                s.271                False
# initial_seasons.272            0.0788081                s.272                False
# initial_seasons.273            0.8781491                s.273                False
# initial_seasons.274           -0.2458920                s.274                False
# initial_seasons.275            0.1545874                s.275                False
# initial_seasons.276           -0.0454126                s.276                False
# initial_seasons.277           -0.7454811                s.277                False
# initial_seasons.278           -0.2202756                s.278                False
# initial_seasons.279           -0.6456866                s.279                False
# initial_seasons.280           -1.2217140                s.280                False
# initial_seasons.281           -0.6975359                s.281                False
# initial_seasons.282            0.0521475                s.282                False
# initial_seasons.283           -0.1733745                s.283                False
# initial_seasons.284           -0.0749925                s.284                False
# initial_seasons.285            0.0981840                s.285                False
# initial_seasons.286           -0.1019956                s.286                False
# initial_seasons.287           -0.1025176                s.287                False
# initial_seasons.288           -1.0029027                s.288                False
# initial_seasons.289           -0.8529027                s.289                False
# initial_seasons.290           -0.5285192                s.290                False
# initial_seasons.291           -1.1789301                s.291                False
# initial_seasons.292           -0.9544781                s.292                False
# initial_seasons.293           -0.7044096                s.293                False
# initial_seasons.294           -0.8541356                s.294                False
# initial_seasons.295           -0.4781082                s.295                False
# initial_seasons.296           -0.9272178                s.296                False
# initial_seasons.297           -0.8763959                s.297                False
# initial_seasons.298           -0.3770808                s.298                False
# initial_seasons.299           -0.8260534                s.299                False
# initial_seasons.300           -0.3503685                s.300                False
# initial_seasons.301           -0.4498890                s.301                False
# initial_seasons.302           -1.0996835                s.302                False
# initial_seasons.303           -1.1479027                s.303                False
# initial_seasons.304           -0.6316604                s.304                False
# initial_seasons.305           -0.5222178                s.305                False
# initial_seasons.306           -1.7229027                s.306                False
# initial_seasons.307           -1.5726288                s.307                False
# initial_seasons.308           -1.6985192                s.308                False
# initial_seasons.309           -0.5985192                s.309                False
# initial_seasons.310           -0.6477399                s.310                False
# initial_seasons.311           -0.6981935                s.311                False
# initial_seasons.312           -0.4734416                s.312                False
# initial_seasons.313           -0.9483472                s.313                False
# initial_seasons.314           -1.0735268                s.314                False
# initial_seasons.315           -1.0731158                s.315                False
# initial_seasons.316           -0.5472254                s.316                False
# initial_seasons.317           -0.8223365                s.317                False
# initial_seasons.318           -0.4718997                s.318                False
# initial_seasons.319           -0.8468738                s.319                False
# initial_seasons.320           -0.3472589                s.320                False
# initial_seasons.321           -0.5479180                s.321                False
# initial_seasons.322            0.0272449                s.322                False
# initial_seasons.323           -0.3972498                s.323                False
# initial_seasons.324           -1.1722924                s.324                False
# initial_seasons.325           -0.5223351                s.325                False
# initial_seasons.326           -0.2968982                s.326                False
# initial_seasons.327           -0.6965984                s.327                False
# initial_seasons.328           -0.4212301                s.328                False
# initial_seasons.329           -0.3464097                s.329                False
# initial_seasons.330           -0.7950824                s.330                False
# initial_seasons.331           -0.4699196                s.331                False
# initial_seasons.332           -0.1698937                s.332                False
# initial_seasons.333           -0.5941144                s.333                False
# initial_seasons.334           -0.4945680                s.334                False
# initial_seasons.335           -0.2949105                s.335                False
# initial_seasons.336           -0.1448161                s.336                False
# initial_seasons.337           -0.5446532                s.337                False
# initial_seasons.338           -0.4940794                s.338                False
# initial_seasons.339           -0.2429577                s.339                False
# initial_seasons.340           -0.7923153                s.340                False
# initial_seasons.341           -0.4420840                s.341                False
# initial_seasons.342           -0.5915787                s.342                False
# initial_seasons.343           -0.6908937                s.343                False
# initial_seasons.344           -1.0144980                s.344                False
# initial_seasons.345           -1.0883078                s.345                False
# initial_seasons.346           -0.9124600                s.346                False
# initial_seasons.347           -0.3112697                s.347                False
# initial_seasons.348           -0.1107644                s.348                False
# initial_seasons.349           -0.4832728                s.349                False
# initial_seasons.350           -0.4563976                s.350                False
# initial_seasons.351           -0.6806868                s.351                False
# initial_seasons.352           -0.4044280                s.352                False
# initial_seasons.353           -0.5779638                s.353                False
# initial_seasons.354           -0.6524585                s.354                False
# initial_seasons.355           -1.2512682                s.355                False
# initial_seasons.356           -1.4497355                s.356                False
# initial_seasons.357           -1.3243672                s.357                False
# initial_seasons.358           -0.7484509                s.358                False
# initial_seasons.359           -0.8980141                s.359                False
# initial_seasons.360           -0.3964129                s.360                False
# initial_seasons.361            0.0291610                s.361                False
# initial_seasons.362           -0.8451282                s.362                False
# initial_seasons.363           -0.5946914                s.363                False
# initial_seasons.364           -0.6943916                s.364                False
# ----------------------------------------------------------------------------------

# %%
# Prediksi ke depan
pred = fitted_model.forecast(steps=365)
print(pred)
# Out:
# 2024-11-01    27.300895
# 2024-11-02    28.400915
# 2024-11-03    28.351717
# 2024-11-04    28.301285
# 2024-11-05    28.526058
#                 ...
# 2025-10-27    27.859286
# 2025-10-28    28.375549
# 2025-10-29    28.485013
# 2025-10-30    27.284351
# 2025-10-31    27.434646
# Freq: D, Length: 365, dtype: float64

# %%
# Simpan hasil prediksi ke dalam DataFrame (jika belum dalam DataFrame)
pred_df = pd.DataFrame({'Date': pred.index, 'Suhu': pred.values})

# Simpan ke file CSV
pred_df.to_csv('D:/cool/TA/data/HW suhu BMKG.csv', index=False)

# %%
historical_data = df['Suhu']

# %%
# Visualisasi
plt.figure(figsize=(12, 6))

# Plot data historis
plt.plot(historical_data.index, historical_data, label='Data Historis', color='blue')

# Plot prediksi
plt.plot(pred.index, pred.values, label='Prediksi', color='Red', linestyle='--')

# Tambahkan label dan judul
plt.xlabel('Tanggal')
plt.ylabel('Suhu')
plt.title('Data Historis and 365-hari Peramalan Suhu Udara Relatif')
plt.legend()
plt.grid(True)

# Tampilkan plot
plt.show()

# %%
residual = (test['Suhu'] - test_pred)
stats.probplot(residual, dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

# Uji Shapiro-Wilk
stat, p_value = stats.shapiro(residual)
print('Statistik Shapiro-Wilk:', stat)
print('P-value:', p_value)

# Interpretasi
alpha = 0.05
if p_value > alpha:
    print("Tidak ada cukup bukti untuk menolak hipotesis nol (data terdistribusi normal)")
else:
    print("Ada cukup bukti untuk menolak hipotesis nol (data tidak terdistribusi normal)")
# Out:
# Statistik Shapiro-Wilk: 0.9956057071685791
# P-value: 0.33903270959854126
# Tidak ada cukup bukti untuk menolak hipotesis nol (data terdistribusi normal)

# %%
final_model=ExponentialSmoothing(df.Kelembaban,trend='add', seasonal='add', seasonal_periods=365).fit()

# %%
pred=final_model.forecast(365)

# %%
pred
# Out:
# 2024-08-01    76.719967
# 2024-08-02    74.864042
# 2024-08-03    72.178651
# 2024-08-04    74.803549
# 2024-08-05    74.931971
#                 ...
# 2025-07-27    74.854414
# 2025-07-28    77.148334
# 2025-07-29    76.164164
# 2025-07-30    74.664073
# 2025-07-31    76.069120
# Freq: D, Length: 365, dtype: float64

# %%
df['Kelembaban'].plot(legend=True, label='Kelembaban', figsize=(10,6))
pred.plot(legend=True, label='prediction')
# Out:
# <AxesSubplot:xlabel='Tanggal'>

# %%
test_kl.plot(legend=True, label='Test')
test_kl.plot(legend=True, label='predicted_test')

# %%
model = HWES(train_kl, seasonal_periods = 365, trend = 'add', seasonal = "add")
fitted = model.fit()
print(fitted.summary())
# Out:
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:               Kelembaban   No. Observations:                 1045
# Model:             ExponentialSmoothing   SSE                           8028.560
# Optimized:                         True   AIC                           2868.743
# Trend:                         Additive   BIC                           4695.947
# Seasonal:                      Additive   AICC                          3278.883
# Seasonal Periods:                   365   Date:                 Tue, 13 Aug 2024
# Box-Cox:                          False   Time:                         20:36:02
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.5524601                alpha                 True
# smoothing_trend                 0.000000                 beta                 True
# smoothing_seasonal              0.000000                gamma                 True
# initial_level                  81.320779                  l.0                 True
# initial_trend                  0.0015752                  b.0                 True
# initial_seasons.0              3.3564088                  s.0                 True
# initial_seasons.1              3.8614331                  s.1                 True
# initial_seasons.2              5.4653592                  s.2                 True
# initial_seasons.3              6.6096368                  s.3                 True
# initial_seasons.4              6.8643284                  s.4                 True
# initial_seasons.5              6.5111813                  s.5                 True
# initial_seasons.6              3.3013265                  s.6                 True
# initial_seasons.7              4.0507433                  s.7                 True
# initial_seasons.8              3.3643570                  s.8                 True
# initial_seasons.9              2.4645196                  s.9                 True
# initial_seasons.10             0.1332404                 s.10                 True
# initial_seasons.11            -1.7018066                 s.11                 True
# initial_seasons.12             1.5501159                 s.12                 True
# initial_seasons.13             2.4195451                 s.13                 True
# initial_seasons.14             2.8604309                 s.14                 True
# initial_seasons.15             1.1065803                 s.15                 True
# initial_seasons.16             0.5892351                 s.16                 True
# initial_seasons.17             0.3773385                 s.17                 True
# initial_seasons.18             0.0824041                 s.18                 True
# initial_seasons.19             0.5173077                 s.19                 True
# initial_seasons.20             2.3125598                 s.20                 True
# initial_seasons.21            -0.9858297                 s.21                 True
# initial_seasons.22             0.6821647                 s.22                 True
# initial_seasons.23             3.5347336                 s.23                 True
# initial_seasons.24             1.9688456                 s.24                 True
# initial_seasons.25             1.6784459                 s.25                 True
# initial_seasons.26            -1.6182130                 s.26                 True
# initial_seasons.27             3.7778333                 s.27                 True
# initial_seasons.28             3.0054681                 s.28                 True
# initial_seasons.29             3.4014317                 s.29                 True
# initial_seasons.30             1.5864378                 s.30                 True
# initial_seasons.31            -3.8946562                 s.31                 True
# initial_seasons.32            -0.1053590                 s.32                 True
# initial_seasons.33             3.4775206                 s.33                 True
# initial_seasons.34             2.2904017                 s.34                 True
# initial_seasons.35             1.3955155                 s.35                 True
# initial_seasons.36             2.0186477                 s.36                 True
# initial_seasons.37             0.3305881                 s.37                 True
# initial_seasons.38             3.2892236                 s.38                 True
# initial_seasons.39             2.9348124                 s.39                 True
# initial_seasons.40             1.4365318                 s.40                 True
# initial_seasons.41            -2.7708098                 s.41                 True
# initial_seasons.42             1.8545135                 s.42                 True
# initial_seasons.43             0.7917200                 s.43                 True
# initial_seasons.44             2.5871096                 s.44                 True
# initial_seasons.45             2.3349794                 s.45                 True
# initial_seasons.46             0.3000648                 s.46                 True
# initial_seasons.47            -1.8044519                 s.47                 True
# initial_seasons.48            -0.7195476                 s.48                 True
# initial_seasons.49            -4.9257922                 s.49                 True
# initial_seasons.50            -1.1294148                 s.50                 True
# initial_seasons.51             0.1691617                 s.51                 True
# initial_seasons.52             1.8991851                 s.52                 True
# initial_seasons.53             0.0460723                 s.53                 True
# initial_seasons.54            -0.3650580                 s.54                 True
# initial_seasons.55             1.0308668                 s.55                 True
# initial_seasons.56             0.9319977                 s.56                 True
# initial_seasons.57             0.2306452                 s.57                 True
# initial_seasons.58            -0.9053964                 s.58                 True
# initial_seasons.59             1.0129249                 s.59                 True
# initial_seasons.60            -2.7956695                 s.60                 True
# initial_seasons.61            -3.8521507                 s.61                 True
# initial_seasons.62            -1.3903676                 s.62                 True
# initial_seasons.63             1.0998237                 s.63                 True
# initial_seasons.64             0.5354066                 s.64                 True
# initial_seasons.65            -1.9958626                 s.65                 True
# initial_seasons.66            -1.1815909                 s.66                 True
# initial_seasons.67            -0.2389066                 s.67                 True
# initial_seasons.68             1.9380482                 s.68                 True
# initial_seasons.69            -2.1419504                 s.69                 True
# initial_seasons.70            -1.9470465                 s.70                 True
# initial_seasons.71            -1.2755741                 s.71                 True
# initial_seasons.72            -1.0437466                 s.72                 True
# initial_seasons.73            -2.6793322                 s.73                 True
# initial_seasons.74            -0.2949720                 s.74                 True
# initial_seasons.75            -1.6239608                 s.75                 True
# initial_seasons.76             0.9263398                 s.76                 True
# initial_seasons.77            -0.2756059                 s.77                 True
# initial_seasons.78             3.6476258                 s.78                 True
# initial_seasons.79             0.2755129                 s.79                 True
# initial_seasons.80            -2.9661343                 s.80                 True
# initial_seasons.81            -1.4162119                 s.81                 True
# initial_seasons.82             2.6732576                 s.82                 True
# initial_seasons.83             3.2856414                 s.83                 True
# initial_seasons.84             0.9165189                 s.84                 True
# initial_seasons.85             0.7986159                 s.85                 True
# initial_seasons.86             2.1995529                 s.86                 True
# initial_seasons.87             0.5647415                 s.87                 True
# initial_seasons.88            -1.6535656                 s.88                 True
# initial_seasons.89            -1.0654116                 s.89                 True
# initial_seasons.90            -2.8473658                 s.90                 True
# initial_seasons.91             0.3038125                 s.91                 True
# initial_seasons.92            -3.5595459                 s.92                 True
# initial_seasons.93            -3.3873665                 s.93                 True
# initial_seasons.94            -3.2072974                 s.94                 True
# initial_seasons.95            -4.6550943                 s.95                 True
# initial_seasons.96            -1.3319990                 s.96                 True
# initial_seasons.97            -1.3856504                 s.97                 True
# initial_seasons.98             0.9146564                 s.98                 True
# initial_seasons.99            -2.3480629                 s.99                 True
# initial_seasons.100           -1.7317971                s.100                 True
# initial_seasons.101           -3.7812658                s.101                 True
# initial_seasons.102           -2.6291165                s.102                 True
# initial_seasons.103           -0.0340572                s.103                 True
# initial_seasons.104           -0.7929036                s.104                 True
# initial_seasons.105           -2.1970690                s.105                 True
# initial_seasons.106           -1.9586369                s.106                 True
# initial_seasons.107           -1.6338580                s.107                 True
# initial_seasons.108            0.0641155                s.108                 True
# initial_seasons.109           -3.1740479                s.109                 True
# initial_seasons.110            0.2744168                s.110                 True
# initial_seasons.111            3.4335423                s.111                 True
# initial_seasons.112           -0.0978747                s.112                 True
# initial_seasons.113            0.1245545                s.113                 True
# initial_seasons.114           -0.6339968                s.114                 True
# initial_seasons.115           -0.1217875                s.115                 True
# initial_seasons.116           -2.0519159                s.116                 True
# initial_seasons.117           -0.9338402                s.117                 True
# initial_seasons.118           -1.0285264                s.118                 True
# initial_seasons.119           -2.4335307                s.119                 True
# initial_seasons.120           -2.5925059                s.120                 True
# initial_seasons.121            1.6947506                s.121                 True
# initial_seasons.122            1.3087505                s.122                 True
# initial_seasons.123           -1.0812037                s.123                 True
# initial_seasons.124           -0.8253679                s.124                 True
# initial_seasons.125            2.9554389                s.125                 True
# initial_seasons.126            1.9613677                s.126                 True
# initial_seasons.127            0.8658738                s.127                 True
# initial_seasons.128            1.6871516                s.128                 True
# initial_seasons.129            0.9008459                s.129                 True
# initial_seasons.130           -1.8167447                s.130                 True
# initial_seasons.131           -3.8573154                s.131                 True
# initial_seasons.132           -3.4137238                s.132                 True
# initial_seasons.133           -3.9288155                s.133                 True
# initial_seasons.134           -2.3064489                s.134                 True
# initial_seasons.135           -4.8823960                s.135                 True
# initial_seasons.136           -1.3570874                s.136                 True
# initial_seasons.137           -2.1662223                s.137                 True
# initial_seasons.138           -2.4380553                s.138                 True
# initial_seasons.139           -2.4554805                s.139                 True
# initial_seasons.140           -1.6003004                s.140                 True
# initial_seasons.141           -0.9772107                s.141                 True
# initial_seasons.142           -1.1679949                s.142                 True
# initial_seasons.143           -0.7274835                s.143                 True
# initial_seasons.144           -3.6459835                s.144                 True
# initial_seasons.145           -2.0195846                s.145                 True
# initial_seasons.146            1.2967055                s.146                 True
# initial_seasons.147           -0.4590911                s.147                 True
# initial_seasons.148            0.1012793                s.148                 True
# initial_seasons.149           -0.0667200                s.149                 True
# initial_seasons.150            0.3444136                s.150                 True
# initial_seasons.151           -0.0061101                s.151                 True
# initial_seasons.152           -2.9295761                s.152                 True
# initial_seasons.153           -1.2050572                s.153                 True
# initial_seasons.154           -0.6823598                s.154                 True
# initial_seasons.155           -3.4979867                s.155                 True
# initial_seasons.156           -3.1054729                s.156                 True
# initial_seasons.157           -2.6717830                s.157                 True
# initial_seasons.158           -1.4454715                s.158                 True
# initial_seasons.159           -2.1175972                s.159                 True
# initial_seasons.160           -0.1836869                s.160                 True
# initial_seasons.161           -3.8924153                s.161                 True
# initial_seasons.162           -1.7717303                s.162                 True
# initial_seasons.163           -2.2729299                s.163                 True
# initial_seasons.164           -3.6894021                s.164                 True
# initial_seasons.165           -3.1279879                s.165                 True
# initial_seasons.166           -4.8414897                s.166                 True
# initial_seasons.167           -5.8814280                s.167                 True
# initial_seasons.168           -4.5300378                s.168                 True
# initial_seasons.169           -3.4901527                s.169                 True
# initial_seasons.170           -5.0729747                s.170                 True
# initial_seasons.171           -1.3876630                s.171                 True
# initial_seasons.172           -0.6174481                s.172                 True
# initial_seasons.173           -0.6426484                s.173                 True
# initial_seasons.174           -2.2224284                s.174                 True
# initial_seasons.175           -1.8318007                s.175                 True
# initial_seasons.176            0.7122621                s.176                 True
# initial_seasons.177           -0.3904216                s.177                 True
# initial_seasons.178            0.1307292                s.178                 True
# initial_seasons.179            1.2548428                s.179                 True
# initial_seasons.180           -1.1419365                s.180                 True
# initial_seasons.181           -0.4339970                s.181                 True
# initial_seasons.182            0.0503392                s.182                 True
# initial_seasons.183           -2.4509753                s.183                 True
# initial_seasons.184           -0.9035731                s.184                 True
# initial_seasons.185           -0.4886964                s.185                 True
# initial_seasons.186           -0.6313017                s.186                 True
# initial_seasons.187           -1.6735640                s.187                 True
# initial_seasons.188            0.9115368                s.188                 True
# initial_seasons.189            3.4910397                s.189                 True
# initial_seasons.190            1.7256833                s.190                 True
# initial_seasons.191            0.4711149                s.191                 True
# initial_seasons.192           -1.1283993                s.192                 True
# initial_seasons.193           -1.0234213                s.193                 True
# initial_seasons.194           -3.1063675                s.194                 True
# initial_seasons.195           -0.8784435                s.195                 True
# initial_seasons.196           -3.8557641                s.196                 True
# initial_seasons.197           -3.3354927                s.197                 True
# initial_seasons.198           -2.2085576                s.198                 True
# initial_seasons.199            0.5017115                s.199                 True
# initial_seasons.200           -0.6725488                s.200                 True
# initial_seasons.201            0.3301010                s.201                 True
# initial_seasons.202           -1.5447328                s.202                 True
# initial_seasons.203           -1.9688282                s.203                 True
# initial_seasons.204           -1.5300186                s.204                 True
# initial_seasons.205           -1.1519748                s.205                 True
# initial_seasons.206           -0.2806518                s.206                 True
# initial_seasons.207            1.3393370                s.207                 True
# initial_seasons.208           -0.7867981                s.208                 True
# initial_seasons.209            1.4803276                s.209                 True
# initial_seasons.210            1.2475435                s.210                 True
# initial_seasons.211            0.6410174                s.211                 True
# initial_seasons.212            1.1137069                s.212                 True
# initial_seasons.213            0.6761955                s.213                 True
# initial_seasons.214           -1.1840958                s.214                 True
# initial_seasons.215           -3.8754058                s.215                 True
# initial_seasons.216           -1.2566102                s.216                 True
# initial_seasons.217           -1.1358792                s.217                 True
# initial_seasons.218           -1.3910657                s.218                 True
# initial_seasons.219            0.2093434                s.219                 True
# initial_seasons.220            0.8861501                s.220                 True
# initial_seasons.221            2.1916347                s.221                 True
# initial_seasons.222            0.2083186                s.222                 True
# initial_seasons.223            0.3010870                s.223                 True
# initial_seasons.224           -0.0752646                s.224                 True
# initial_seasons.225           -0.7534290                s.225                 True
# initial_seasons.226           -3.4453871                s.226                 True
# initial_seasons.227           -3.7275290                s.227                 True
# initial_seasons.228           -3.8860743                s.228                 True
# initial_seasons.229           -2.3913318                s.229                 True
# initial_seasons.230            0.5193882                s.230                 True
# initial_seasons.231           -0.0369686                s.231                 True
# initial_seasons.232           -2.4396129                s.232                 True
# initial_seasons.233           -4.0129441                s.233                 True
# initial_seasons.234           -5.2719317                s.234                 True
# initial_seasons.235           -2.8428920                s.235                 True
# initial_seasons.236           -2.1066420                s.236                 True
# initial_seasons.237           -3.2620860                s.237                 True
# initial_seasons.238           -3.0706631                s.238                 True
# initial_seasons.239           -1.8719600                s.239                 True
# initial_seasons.240           -1.2795464                s.240                 True
# initial_seasons.241           -1.0999723                s.241                 True
# initial_seasons.242           -0.4456350                s.242                 True
# initial_seasons.243           -0.0229371                s.243                 True
# initial_seasons.244           -4.0795597                s.244                 True
# initial_seasons.245           -3.2571293                s.245                 True
# initial_seasons.246           -1.0216260                s.246                 True
# initial_seasons.247           -4.9917862                s.247                 True
# initial_seasons.248           -5.8810603                s.248                 True
# initial_seasons.249           -3.1415966                s.249                 True
# initial_seasons.250           -3.3431729                s.250                 True
# initial_seasons.251           -1.9833823                s.251                 True
# initial_seasons.252           -2.3758248                s.252                 True
# initial_seasons.253           -5.5992575                s.253                 True
# initial_seasons.254           -3.0708897                s.254                 True
# initial_seasons.255           -4.8118932                s.255                 True
# initial_seasons.256           -6.4739809                s.256                 True
# initial_seasons.257           -8.3028204                s.257                 True
# initial_seasons.258           -4.4652853                s.258                 True
# initial_seasons.259           -5.3732475                s.259                 True
# initial_seasons.260           -3.8286281                s.260                 True
# initial_seasons.261           -4.4886073                s.261                 True
# initial_seasons.262           -4.1119976                s.262                 True
# initial_seasons.263           -1.3553828                s.263                 True
# initial_seasons.264           -4.8307141                s.264                 True
# initial_seasons.265            0.0316258                s.265                 True
# initial_seasons.266           -1.1958971                s.266                 True
# initial_seasons.267           -0.7948279                s.267                 True
# initial_seasons.268            1.5437144                s.268                 True
# initial_seasons.269           -0.1607652                s.269                 True
# initial_seasons.270            0.6763293                s.270                 True
# initial_seasons.271            2.8737759                s.271                 True
# initial_seasons.272            1.1440184                s.272                 True
# initial_seasons.273            0.5449154                s.273                 True
# initial_seasons.274           -2.1975567                s.274                 True
# initial_seasons.275           -0.4627219                s.275                 True
# initial_seasons.276           -0.9839502                s.276                 True
# initial_seasons.277           -1.2028462                s.277                 True
# initial_seasons.278            1.7126659                s.278                 True
# initial_seasons.279            0.7223490                s.279                 True
# initial_seasons.280           -0.6905978                s.280                 True
# initial_seasons.281           -2.4334965                s.281                 True
# initial_seasons.282           -1.7832805                s.282                 True
# initial_seasons.283           -1.2331400                s.283                 True
# initial_seasons.284           -0.0023261                s.284                 True
# initial_seasons.285           -0.6781444                s.285                 True
# initial_seasons.286            2.2875501                s.286                 True
# initial_seasons.287            2.3581040                s.287                 True
# initial_seasons.288            2.9077772                s.288                 True
# initial_seasons.289            0.8519392                s.289                 True
# initial_seasons.290           -1.6771215                s.290                 True
# initial_seasons.291            0.9349272                s.291                 True
# initial_seasons.292            2.9611995                s.292                 True
# initial_seasons.293            0.5961915                s.293                 True
# initial_seasons.294            2.6458333                s.294                 True
# initial_seasons.295            1.6520657                s.295                 True
# initial_seasons.296            0.9572306                s.296                 True
# initial_seasons.297            0.0265230                s.297                 True
# initial_seasons.298            0.0399618                s.298                 True
# initial_seasons.299            0.8394638                s.299                 True
# initial_seasons.300           -1.7937319                s.300                 True
# initial_seasons.301            2.5692506                s.301                 True
# initial_seasons.302            1.4322147                s.302                 True
# initial_seasons.303            2.5308356                s.303                 True
# initial_seasons.304            0.1692308                s.304                 True
# initial_seasons.305            1.9348510                s.305                 True
# initial_seasons.306            0.5884688                s.306                 True
# initial_seasons.307            0.4758943                s.307                 True
# initial_seasons.308            4.3600717                s.308                 True
# initial_seasons.309            7.0829106                s.309                 True
# initial_seasons.310            2.5990656                s.310                 True
# initial_seasons.311            2.3815695                s.311                 True
# initial_seasons.312            0.0646922                s.312                 True
# initial_seasons.313            3.4299459                s.313                 True
# initial_seasons.314            1.1494835                s.314                 True
# initial_seasons.315            2.0776238                s.315                 True
# initial_seasons.316            5.8784457                s.316                 True
# initial_seasons.317            5.9964140                s.317                 True
# initial_seasons.318            4.4880475                s.318                 True
# initial_seasons.319            2.2942748                s.319                 True
# initial_seasons.320            0.6017554                s.320                 True
# initial_seasons.321            0.3359441                s.321                 True
# initial_seasons.322            2.9905148                s.322                 True
# initial_seasons.323            0.1088459                s.323                 True
# initial_seasons.324            2.1370641                s.324                 True
# initial_seasons.325            1.4416724                s.325                 True
# initial_seasons.326            2.5921636                s.326                 True
# initial_seasons.327            1.3120247                s.327                 True
# initial_seasons.328           -7.6323412                s.328                 True
# initial_seasons.329           -4.7646060                s.329                 True
# initial_seasons.330            0.2042370                s.330                 True
# initial_seasons.331            3.6725586                s.331                 True
# initial_seasons.332            3.8614953                s.332                 True
# initial_seasons.333            7.6116890                s.333                 True
# initial_seasons.334            1.7325957                s.334                 True
# initial_seasons.335            1.0197564                s.335                 True
# initial_seasons.336            3.4581724                s.336                 True
# initial_seasons.337            6.1510305                s.337                 True
# initial_seasons.338            6.0946440                s.338                 True
# initial_seasons.339            1.4682459                s.339                 True
# initial_seasons.340            2.2223167                s.340                 True
# initial_seasons.341            5.4164700                s.341                 True
# initial_seasons.342            5.4525049                s.342                 True
# initial_seasons.343            5.7428359                s.343                 True
# initial_seasons.344            7.2487951                s.344                 True
# initial_seasons.345            5.8451792                s.345                 True
# initial_seasons.346            6.6971861                s.346                 True
# initial_seasons.347            8.0813225                s.347                 True
# initial_seasons.348            7.7739982                s.348                 True
# initial_seasons.349            7.4410576                s.349                 True
# initial_seasons.350            5.0734957                s.350                 True
# initial_seasons.351            7.1420111                s.351                 True
# initial_seasons.352            7.4003640                s.352                 True
# initial_seasons.353            7.0928387                s.353                 True
# initial_seasons.354            7.1936821                s.354                 True
# initial_seasons.355            0.5749519                s.355                 True
# initial_seasons.356            1.5831597                s.356                 True
# initial_seasons.357            0.2463595                s.357                 True
# initial_seasons.358            0.6624412                s.358                 True
# initial_seasons.359            4.0721588                s.359                 True
# initial_seasons.360            3.6748779                s.360                 True
# initial_seasons.361            2.3667138                s.361                 True
# initial_seasons.362            2.0566933                s.362                 True
# initial_seasons.363            1.9364733                s.363                 True
# initial_seasons.364            1.2852763                s.364                 True
# ----------------------------------------------------------------------------------

# %%
model = HWES(train_kl, seasonal_periods = 365, trend = 'add', seasonal = "mul")
fitted = model.fit(optimized=True, use_brute=True)
print(fitted.summary())
# Out:
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:               Kelembaban   No. Observations:                 1045
# Model:             ExponentialSmoothing   SSE                          10212.190
# Optimized:                         True   AIC                           3120.146
# Trend:                         Additive   BIC                           4947.350
# Seasonal:                Multiplicative   AICC                          3530.285
# Seasonal Periods:                   365   Date:                 Tue, 13 Aug 2024
# Box-Cox:                          False   Time:                         20:36:15
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.5296300                alpha                 True
# smoothing_trend                0.0001027                 beta                 True
# smoothing_seasonal             0.2433501                gamma                 True
# initial_level                  75.196494                  l.0                 True
# initial_trend                 -0.0119753                  b.0                 True
# initial_seasons.0              1.1610420                  s.0                 True
# initial_seasons.1              1.1710643                  s.1                 True
# initial_seasons.2              1.1927438                  s.2                 True
# initial_seasons.3              1.2153989                  s.3                 True
# initial_seasons.4              1.2160146                  s.4                 True
# initial_seasons.5              1.2127846                  s.5                 True
# initial_seasons.6              1.1701500                  s.6                 True
# initial_seasons.7              1.1817379                  s.7                 True
# initial_seasons.8              1.1768223                  s.8                 True
# initial_seasons.9              1.1690879                  s.9                 True
# initial_seasons.10             1.1470039                 s.10                 True
# initial_seasons.11             1.1393779                 s.11                 True
# initial_seasons.12             1.1912910                 s.12                 True
# initial_seasons.13             1.1982855                 s.13                 True
# initial_seasons.14             1.2013372                 s.14                 True
# initial_seasons.15             1.1806476                 s.15                 True
# initial_seasons.16             1.1740231                 s.16                 True
# initial_seasons.17             1.1848334                 s.17                 True
# initial_seasons.18             1.1795918                 s.18                 True
# initial_seasons.19             1.1921145                 s.19                 True
# initial_seasons.20             1.2146405                 s.20                 True
# initial_seasons.21             1.1676220                 s.21                 True
# initial_seasons.22             1.1797805                 s.22                 True
# initial_seasons.23             1.2249360                 s.23                 True
# initial_seasons.24             1.2239388                 s.24                 True
# initial_seasons.25             1.2267524                 s.25                 True
# initial_seasons.26             1.1714242                 s.26                 True
# initial_seasons.27             1.2552391                 s.27                 True
# initial_seasons.28             1.2471638                 s.28                 True
# initial_seasons.29             1.2401408                 s.29                 True
# initial_seasons.30             1.2027890                 s.30                 True
# initial_seasons.31             1.1518265                 s.31                 True
# initial_seasons.32             1.2142501                 s.32                 True
# initial_seasons.33             1.2575897                 s.33                 True
# initial_seasons.34             1.2388951                 s.34                 True
# initial_seasons.35             1.2193445                 s.35                 True
# initial_seasons.36             1.2344387                 s.36                 True
# initial_seasons.37             1.2135030                 s.37                 True
# initial_seasons.38             1.2600114                 s.38                 True
# initial_seasons.39             1.2536873                 s.39                 True
# initial_seasons.40             1.2310623                 s.40                 True
# initial_seasons.41             1.1690644                 s.41                 True
# initial_seasons.42             1.2496075                 s.42                 True
# initial_seasons.43             1.2388603                 s.43                 True
# initial_seasons.44             1.2635626                 s.44                 True
# initial_seasons.45             1.2659402                 s.45                 True
# initial_seasons.46             1.2409195                 s.46                 True
# initial_seasons.47             1.2083993                 s.47                 True
# initial_seasons.48             1.2235332                 s.48                 True
# initial_seasons.49             1.1531941                 s.49                 True
# initial_seasons.50             1.2070670                 s.50                 True
# initial_seasons.51             1.2371641                 s.51                 True
# initial_seasons.52             1.2701445                 s.52                 True
# initial_seasons.53             1.2487576                 s.53                 True
# initial_seasons.54             1.2423578                 s.54                 True
# initial_seasons.55             1.2672522                 s.55                 True
# initial_seasons.56             1.2712668                 s.56                 True
# initial_seasons.57             1.2733066                 s.57                 True
# initial_seasons.58             1.2485282                 s.58                 True
# initial_seasons.59             1.2680429                 s.59                 True
# initial_seasons.60             1.2050026                 s.60                 True
# initial_seasons.61             1.2034403                 s.61                 True
# initial_seasons.62             1.2445982                 s.62                 True
# initial_seasons.63             1.2933073                 s.63                 True
# initial_seasons.64             1.2999775                 s.64                 True
# initial_seasons.65             1.2622482                 s.65                 True
# initial_seasons.66             1.2748408                 s.66                 True
# initial_seasons.67             1.2910885                 s.67                 True
# initial_seasons.68             1.3131047                 s.68                 True
# initial_seasons.69             1.2507724                 s.69                 True
# initial_seasons.70             1.2536629                 s.70                 True
# initial_seasons.71             1.2647123                 s.71                 True
# initial_seasons.72             1.2716494                 s.72                 True
# initial_seasons.73             1.2612722                 s.73                 True
# initial_seasons.74             1.3070891                 s.74                 True
# initial_seasons.75             1.2777852                 s.75                 True
# initial_seasons.76             1.3114515                 s.76                 True
# initial_seasons.77             1.3007840                 s.77                 True
# initial_seasons.78             1.3619242                 s.78                 True
# initial_seasons.79             1.3100748                 s.79                 True
# initial_seasons.80             1.2686279                 s.80                 True
# initial_seasons.81             1.2984064                 s.81                 True
# initial_seasons.82             1.3549923                 s.82                 True
# initial_seasons.83             1.3739692                 s.83                 True
# initial_seasons.84             1.3395382                 s.84                 True
# initial_seasons.85             1.3402164                 s.85                 True
# initial_seasons.86             1.3721692                 s.86                 True
# initial_seasons.87             1.3487809                 s.87                 True
# initial_seasons.88             1.3045023                 s.88                 True
# initial_seasons.89             1.3232199                 s.89                 True
# initial_seasons.90             1.3023135                 s.90                 True
# initial_seasons.91             1.3546016                 s.91                 True
# initial_seasons.92             1.2774054                 s.92                 True
# initial_seasons.93             1.2909591                 s.93                 True
# initial_seasons.94             1.2917099                 s.94                 True
# initial_seasons.95             1.2763519                 s.95                 True
# initial_seasons.96             1.3277373                 s.96                 True
# initial_seasons.97             1.3246698                 s.97                 True
# initial_seasons.98             1.3529672                 s.98                 True
# initial_seasons.99             1.3146389                 s.99                 True
# initial_seasons.100            1.3294835                s.100                 True
# initial_seasons.101            1.2934321                s.101                 True
# initial_seasons.102            1.3111206                s.102                 True
# initial_seasons.103            1.3526686                s.103                 True
# initial_seasons.104            1.3381576                s.104                 True
# initial_seasons.105            1.3157941                s.105                 True
# initial_seasons.106            1.3265339                s.106                 True
# initial_seasons.107            1.3426922                s.107                 True
# initial_seasons.108            1.3754631                s.108                 True
# initial_seasons.109            1.3123372                s.109                 True
# initial_seasons.110            1.3840146                s.110                 True
# initial_seasons.111            1.4382601                s.111                 True
# initial_seasons.112            1.3900058                s.112                 True
# initial_seasons.113            1.3970224                s.113                 True
# initial_seasons.114            1.3830496                s.114                 True
# initial_seasons.115            1.3909072                s.115                 True
# initial_seasons.116            1.3605115                s.116                 True
# initial_seasons.117            1.3846714                s.117                 True
# initial_seasons.118            1.3872786                s.118                 True
# initial_seasons.119            1.3602509                s.119                 True
# initial_seasons.120            1.3639982                s.120                 True
# initial_seasons.121            1.4404270                s.121                 True
# initial_seasons.122            1.4177969                s.122                 True
# initial_seasons.123            1.3986984                s.123                 True
# initial_seasons.124            1.4216705                s.124                 True
# initial_seasons.125            1.4760747                s.125                 True
# initial_seasons.126            1.4537837                s.126                 True
# initial_seasons.127            1.4384859                s.127                 True
# initial_seasons.128            1.4596937                s.128                 True
# initial_seasons.129            1.4545873                s.129                 True
# initial_seasons.130            1.4146612                s.130                 True
# initial_seasons.131            1.3753365                s.131                 True
# initial_seasons.132            1.4065195                s.132                 True
# initial_seasons.133            1.3950283                s.133                 True
# initial_seasons.134            1.4210142                s.134                 True
# initial_seasons.135            1.3736196                s.135                 True
# initial_seasons.136            1.4650560                s.136                 True
# initial_seasons.137            1.4549901                s.137                 True
# initial_seasons.138            1.4319834                s.138                 True
# initial_seasons.139            1.4394848                s.139                 True
# initial_seasons.140            1.4610676                s.140                 True
# initial_seasons.141            1.4678943                s.141                 True
# initial_seasons.142            1.4662923                s.142                 True
# initial_seasons.143            1.4719517                s.143                 True
# initial_seasons.144            1.4282873                s.144                 True
# initial_seasons.145            1.4400703                s.145                 True
# initial_seasons.146            1.5116317                s.146                 True
# initial_seasons.147            1.4903727                s.147                 True
# initial_seasons.148            1.4983894                s.148                 True
# initial_seasons.149            1.4931411                s.149                 True
# initial_seasons.150            1.4967976                s.150                 True
# initial_seasons.151            1.4925212                s.151                 True
# initial_seasons.152            1.4409505                s.152                 True
# initial_seasons.153            1.4508930                s.153                 True
# initial_seasons.154            1.4829450                s.154                 True
# initial_seasons.155            1.4208314                s.155                 True
# initial_seasons.156            1.4373898                s.156                 True
# initial_seasons.157            1.4482929                s.157                 True
# initial_seasons.158            1.4766259                s.158                 True
# initial_seasons.159            1.4618164                s.159                 True
# initial_seasons.160            1.4843661                s.160                 True
# initial_seasons.161            1.4206318                s.161                 True
# initial_seasons.162            1.4575175                s.162                 True
# initial_seasons.163            1.4536966                s.163                 True
# initial_seasons.164            1.4344640                s.164                 True
# initial_seasons.165            1.4463595                s.165                 True
# initial_seasons.166            1.3997739                s.166                 True
# initial_seasons.167            1.3769743                s.167                 True
# initial_seasons.168            1.4013068                s.168                 True
# initial_seasons.169            1.4260255                s.169                 True
# initial_seasons.170            1.3995031                s.170                 True
# initial_seasons.171            1.4891160                s.171                 True
# initial_seasons.172            1.4963528                s.172                 True
# initial_seasons.173            1.5015124                s.173                 True
# initial_seasons.174            1.4659382                s.174                 True
# initial_seasons.175            1.4793295                s.175                 True
# initial_seasons.176            1.5360772                s.176                 True
# initial_seasons.177            1.5131397                s.177                 True
# initial_seasons.178            1.5327810                s.178                 True
# initial_seasons.179            1.5466335                s.179                 True
# initial_seasons.180            1.4854797                s.180                 True
# initial_seasons.181            1.4661601                s.181                 True
# initial_seasons.182            1.4710015                s.182                 True
# initial_seasons.183            1.4440797                s.183                 True
# initial_seasons.184            1.4849757                s.184                 True
# initial_seasons.185            1.5015448                s.185                 True
# initial_seasons.186            1.5114716                s.186                 True
# initial_seasons.187            1.4782173                s.187                 True
# initial_seasons.188            1.5177035                s.188                 True
# initial_seasons.189            1.5836423                s.189                 True
# initial_seasons.190            1.5336864                s.190                 True
# initial_seasons.191            1.5308553                s.191                 True
# initial_seasons.192            1.5055343                s.192                 True
# initial_seasons.193            1.5025478                s.193                 True
# initial_seasons.194            1.4674725                s.194                 True
# initial_seasons.195            1.5092972                s.195                 True
# initial_seasons.196            1.4515252                s.196                 True
# initial_seasons.197            1.4476884                s.197                 True
# initial_seasons.198            1.4727813                s.198                 True
# initial_seasons.199            1.5278914                s.199                 True
# initial_seasons.200            1.5099107                s.200                 True
# initial_seasons.201            1.5391077                s.201                 True
# initial_seasons.202            1.5102806                s.202                 True
# initial_seasons.203            1.4906046                s.203                 True
# initial_seasons.204            1.5104909                s.204                 True
# initial_seasons.205            1.5296790                s.205                 True
# initial_seasons.206            1.5476766                s.206                 True
# initial_seasons.207            1.5850989                s.207                 True
# initial_seasons.208            1.5367666                s.208                 True
# initial_seasons.209            1.5751766                s.209                 True
# initial_seasons.210            1.5681378                s.210                 True
# initial_seasons.211            1.5545331                s.211                 True
# initial_seasons.212            1.5569437                s.212                 True
# initial_seasons.213            1.5487350                s.213                 True
# initial_seasons.214            1.5135741                s.214                 True
# initial_seasons.215            1.4720517                s.215                 True
# initial_seasons.216            1.5268356                s.216                 True
# initial_seasons.217            1.5242705                s.217                 True
# initial_seasons.218            1.5136354                s.218                 True
# initial_seasons.219            1.5429779                s.219                 True
# initial_seasons.220            1.5549737                s.220                 True
# initial_seasons.221            1.5881853                s.221                 True
# initial_seasons.222            1.5550423                s.222                 True
# initial_seasons.223            1.5511027                s.223                 True
# initial_seasons.224            1.5315640                s.224                 True
# initial_seasons.225            1.5300486                s.225                 True
# initial_seasons.226            1.4832984                s.226                 True
# initial_seasons.227            1.4618771                s.227                 True
# initial_seasons.228            1.4489195                s.228                 True
# initial_seasons.229            1.4759614                s.229                 True
# initial_seasons.230            1.5485854                s.230                 True
# initial_seasons.231            1.5271505                s.231                 True
# initial_seasons.232            1.4823238                s.232                 True
# initial_seasons.233            1.4737142                s.233                 True
# initial_seasons.234            1.4329599                s.234                 True
# initial_seasons.235            1.4728238                s.235                 True
# initial_seasons.236            1.4853311                s.236                 True
# initial_seasons.237            1.4658447                s.237                 True
# initial_seasons.238            1.4674670                s.238                 True
# initial_seasons.239            1.4872091                s.239                 True
# initial_seasons.240            1.4903396                s.240                 True
# initial_seasons.241            1.5139735                s.241                 True
# initial_seasons.242            1.5411609                s.242                 True
# initial_seasons.243            1.5361727                s.243                 True
# initial_seasons.244            1.4432038                s.244                 True
# initial_seasons.245            1.4450428                s.245                 True
# initial_seasons.246            1.4745801                s.246                 True
# initial_seasons.247            1.3979830                s.247                 True
# initial_seasons.248            1.3839978                s.248                 True
# initial_seasons.249            1.4201089                s.249                 True
# initial_seasons.250            1.4258950                s.250                 True
# initial_seasons.251            1.4583497                s.251                 True
# initial_seasons.252            1.4489820                s.252                 True
# initial_seasons.253            1.3910730                s.253                 True
# initial_seasons.254            1.4423546                s.254                 True
# initial_seasons.255            1.4207353                s.255                 True
# initial_seasons.256            1.3790414                s.256                 True
# initial_seasons.257            1.3448731                s.257                 True
# initial_seasons.258            1.3973404                s.258                 True
# initial_seasons.259            1.3717506                s.259                 True
# initial_seasons.260            1.4104064                s.260                 True
# initial_seasons.261            1.4067890                s.261                 True
# initial_seasons.262            1.4027272                s.262                 True
# initial_seasons.263            1.4460943                s.263                 True
# initial_seasons.264            1.3839570                s.264                 True
# initial_seasons.265            1.4523591                s.265                 True
# initial_seasons.266            1.4102491                s.266                 True
# initial_seasons.267            1.4033240                s.267                 True
# initial_seasons.268            1.4632539                s.268                 True
# initial_seasons.269            1.4226329                s.269                 True
# initial_seasons.270            1.4459493                s.270                 True
# initial_seasons.271            1.4938749                s.271                 True
# initial_seasons.272            1.4709556                s.272                 True
# initial_seasons.273            1.4704667                s.273                 True
# initial_seasons.274            1.4175431                s.274                 True
# initial_seasons.275            1.4238950                s.275                 True
# initial_seasons.276            1.4042758                s.276                 True
# initial_seasons.277            1.4018708                s.277                 True
# initial_seasons.278            1.4553937                s.278                 True
# initial_seasons.279            1.4486682                s.279                 True
# initial_seasons.280            1.4223707                s.280                 True
# initial_seasons.281            1.3681192                s.281                 True
# initial_seasons.282            1.3902457                s.282                 True
# initial_seasons.283            1.4089870                s.283                 True
# initial_seasons.284            1.4307014                s.284                 True
# initial_seasons.285            1.4100677                s.285                 True
# initial_seasons.286            1.4649331                s.286                 True
# initial_seasons.287            1.4554423                s.287                 True
# initial_seasons.288            1.4632609                s.288                 True
# initial_seasons.289            1.4222696                s.289                 True
# initial_seasons.290            1.3669221                s.290                 True
# initial_seasons.291            1.4090008                s.291                 True
# initial_seasons.292            1.4589099                s.292                 True
# initial_seasons.293            1.4174557                s.293                 True
# initial_seasons.294            1.4527150                s.294                 True
# initial_seasons.295            1.4341482                s.295                 True
# initial_seasons.296            1.4306974                s.296                 True
# initial_seasons.297            1.4116431                s.297                 True
# initial_seasons.298            1.4009720                s.298                 True
# initial_seasons.299            1.4123935                s.299                 True
# initial_seasons.300            1.3637945                s.300                 True
# initial_seasons.301            1.4384621                s.301                 True
# initial_seasons.302            1.4319203                s.302                 True
# initial_seasons.303            1.4332122                s.303                 True
# initial_seasons.304            1.3799665                s.304                 True
# initial_seasons.305            1.4123461                s.305                 True
# initial_seasons.306            1.3963778                s.306                 True
# initial_seasons.307            1.3757523                s.307                 True
# initial_seasons.308            1.4503256                s.308                 True
# initial_seasons.309            1.5144078                s.309                 True
# initial_seasons.310            1.4357270                s.310                 True
# initial_seasons.311            1.4303048                s.311                 True
# initial_seasons.312            1.3841506                s.312                 True
# initial_seasons.313            1.4391767                s.313                 True
# initial_seasons.314            1.3895763                s.314                 True
# initial_seasons.315            1.3921375                s.315                 True
# initial_seasons.316            1.4468134                s.316                 True
# initial_seasons.317            1.4461770                s.317                 True
# initial_seasons.318            1.4189838                s.318                 True
# initial_seasons.319            1.3697900                s.319                 True
# initial_seasons.320            1.3369661                s.320                 True
# initial_seasons.321            1.3365599                s.321                 True
# initial_seasons.322            1.3826231                s.322                 True
# initial_seasons.323            1.3334546                s.323                 True
# initial_seasons.324            1.3612159                s.324                 True
# initial_seasons.325            1.3393162                s.325                 True
# initial_seasons.326            1.3539887                s.326                 True
# initial_seasons.327            1.3303953                s.327                 True
# initial_seasons.328            1.1740475                s.328                 True
# initial_seasons.329            1.2113187                s.329                 True
# initial_seasons.330            1.3011889                s.330                 True
# initial_seasons.331            1.3561637                s.331                 True
# initial_seasons.332            1.3505490                s.332                 True
# initial_seasons.333            1.4110293                s.333                 True
# initial_seasons.334            1.3040118                s.334                 True
# initial_seasons.335            1.2856495                s.335                 True
# initial_seasons.336            1.3234285                s.336                 True
# initial_seasons.337            1.3615238                s.337                 True
# initial_seasons.338            1.3500427                s.338                 True
# initial_seasons.339            1.2717687                s.339                 True
# initial_seasons.340            1.2889781                s.340                 True
# initial_seasons.341            1.3248030                s.341                 True
# initial_seasons.342            1.3239211                s.342                 True
# initial_seasons.343            1.3207188                s.343                 True
# initial_seasons.344            1.3428580                s.344                 True
# initial_seasons.345            1.3169850                s.345                 True
# initial_seasons.346            1.3194541                s.346                 True
# initial_seasons.347            1.3362853                s.347                 True
# initial_seasons.348            1.3296907                s.348                 True
# initial_seasons.349            1.3171619                s.349                 True
# initial_seasons.350            1.2768206                s.350                 True
# initial_seasons.351            1.3034766                s.351                 True
# initial_seasons.352            1.2993924                s.352                 True
# initial_seasons.353            1.2899502                s.353                 True
# initial_seasons.354            1.2900502                s.354                 True
# initial_seasons.355            1.1909241                s.355                 True
# initial_seasons.356            1.1943809                s.356                 True
# initial_seasons.357            1.1687120                s.357                 True
# initial_seasons.358            1.1625176                s.358                 True
# initial_seasons.359            1.2014073                s.359                 True
# initial_seasons.360            1.1934010                s.360                 True
# initial_seasons.361            1.1743156                s.361                 True
# initial_seasons.362            1.1594090                s.362                 True
# initial_seasons.363            1.1501347                s.363                 True
# initial_seasons.364            1.1450831                s.364                 True
# ----------------------------------------------------------------------------------
# D:\anaconda2\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
forecast = fitted.forecast(steps=12)

# %%
fig = plt.figure()
fig.suptitle('Retail Sales of Used Cars in the US (1992-2020)')
past, = plt.plot(train_kl.index, train_kl, 'b.-', label='Sales History')
future, = plt.plot(test_kl.index, test_kl, 'r.-', label='Actual Sales')
predicted_future, = plt.plot(test_kl.index, forecast, 'g.-', label='Sales Forecast')
plt.legend(handles=[past, future, predicted_future])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\anaconda2\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File D:\anaconda2\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\anaconda2\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [60], in <cell line: 3>()
#       1 fig = plt.figure()
#       2 fig.suptitle('Retail Sales of Used Cars in the US (1992-2020)')
# ----> 3 past, = plt.plot(train_kl.index, train_kl, 'b.-', label='Sales History')
#       4 future, = plt.plot(test_kl.index, test_kl, 'r.-', label='Actual Sales')
#       5 predicted_future, = plt.plot(test_kl.index, forecast, 'g.-', label='Sales Forecast')
#
# File D:\anaconda2\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File D:\anaconda2\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File D:\anaconda2\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File D:\anaconda2\lib\site-packages\matplotlib\axes\_base.py:488, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     486 if len(xy) == 2:
#     487     x = _check_1d(xy[0])
# --> 488     y = _check_1d(xy[1])
#     489 else:
#     490     x, y = index_of(xy[-1])
#
# File D:\anaconda2\lib\site-packages\matplotlib\cbook\__init__.py:1327, in _check_1d(x)
#    1321 with warnings.catch_warnings(record=True) as w:
#    1322     warnings.filterwarnings(
#    1323         "always",
#    1324         category=Warning,
#    1325         message='Support for multi-dimensional indexing')
# -> 1327     ndim = x[:, None].ndim
#    1328     # we have definitely hit a pandas index or series object
#    1329     # cast to a numpy array.
#    1330     if len(w) > 0:
#
# File D:\anaconda2\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File D:\anaconda2\lib\site-packages\pandas\core\indexes\base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    3623         raise KeyError(key) from err
#    3624     except TypeError:
#    3625         # If we have a listlike key, _check_indexing_error will raise
#    3626         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627         #  the TypeError.
# -> 3628         self._check_indexing_error(key)
#    3629         raise
#    3631 # GH#42269
#
# File D:\anaconda2\lib\site-packages\pandas\core\indexes\base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), None)

# %%
fig = plt.figure(figsize=(10,5))
fig.suptitle('Kelembaban') 
past, = plt.plot(train_kl.index, train_kl, 'b.-', label='train')
future, = plt.plot(test_kl.index, test_kl, 'r.-', label='test')
predicted_future, = plt.plot(test_kl.index, forecast, 'g.-', label='Forecast')
plt.legend(handles=[past, future, predicted_future])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\anaconda2\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File D:\anaconda2\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\anaconda2\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [63], in <cell line: 3>()
#       1 fig = plt.figure(figsize=(10,5))
#       2 fig.suptitle('Kelembaban')
# ----> 3 past, = plt.plot(train_kl.index, train_kl, 'b.-', label='train')
#       4 future, = plt.plot(test_kl.index, test_kl, 'r.-', label='test')
#       5 predicted_future, = plt.plot(test_kl.index, forecast, 'g.-', label='Forecast')
#
# File D:\anaconda2\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File D:\anaconda2\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File D:\anaconda2\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File D:\anaconda2\lib\site-packages\matplotlib\axes\_base.py:488, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     486 if len(xy) == 2:
#     487     x = _check_1d(xy[0])
# --> 488     y = _check_1d(xy[1])
#     489 else:
#     490     x, y = index_of(xy[-1])
#
# File D:\anaconda2\lib\site-packages\matplotlib\cbook\__init__.py:1327, in _check_1d(x)
#    1321 with warnings.catch_warnings(record=True) as w:
#    1322     warnings.filterwarnings(
#    1323         "always",
#    1324         category=Warning,
#    1325         message='Support for multi-dimensional indexing')
# -> 1327     ndim = x[:, None].ndim
#    1328     # we have definitely hit a pandas index or series object
#    1329     # cast to a numpy array.
#    1330     if len(w) > 0:
#
# File D:\anaconda2\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File D:\anaconda2\lib\site-packages\pandas\core\indexes\base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    3623         raise KeyError(key) from err
#    3624     except TypeError:
#    3625         # If we have a listlike key, _check_indexing_error will raise
#    3626         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627         #  the TypeError.
# -> 3628         self._check_indexing_error(key)
#    3629         raise
#    3631 # GH#42269
#
# File D:\anaconda2\lib\site-packages\pandas\core\indexes\base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), None)

# %%
train_kl['Kelembaban'].plot(legend=True, label='Train', figsize=(20,5))
test_kl['Kelembaban'].plot(legend=True, label="Test")
prediction_kl.plot(legend=True,label='Prediction')
plt.title("Model Result",size=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 3>()
#       1 train_kl['Kelembaban'].plot(legend=True, label='Train', figsize=(20,5))
#       2 test_kl['Kelembaban'].plot(legend=True, label="Test")
# ----> 3 prediction_kl.plot(legend=True,label='Prediction')
#       4 plt.title("Model Result",size=30)
#       5 plt.show()
#
# NameError: name 'prediction_kl' is not defined

# %%
df=df.groupby('Tanggal').sum()

# %%
hwmodel_kl=ExponentialSmoothing(train.Kelembaban, trend='add', seasonal='mul', seasonal_periods=4).fit()
# Out:
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
test_pred=hwmodel_kl.forecast(300)

# %%
train['Kelembaban'].plot(legend=True, label='Train', figsize=(10,6))
test['Kelembaban'].plot(legend=True, label='Test')
test_pred.plot(legend=True, label='predict_test')
# Out:
# <AxesSubplot:xlabel='Tanggal'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
np.sqrt(mean_squared_error(test,test_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 np.sqrt(mean_squared_error(test,test_pred))
#
# File D:\anaconda2\lib\site-packages\sklearn\metrics\_regression.py:438, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     378 def mean_squared_error(
#     379     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     380 ):
#     381     """Mean squared error regression loss.
#     382
#     383     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#     442     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File D:\anaconda2\lib\site-packages\sklearn\metrics\_regression.py:94, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      60 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      61     """Check that y_true and y_pred belong to the same regression task.
#      62
#      63     Parameters
#    (...)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File D:\anaconda2\lib\site-packages\sklearn\utils\validation.py:332, in check_consistent_length(*arrays)
#     330 uniques = np.unique(lengths)
#     331 if len(uniques) > 1:
# --> 332     raise ValueError(
#     333         "Found input variables with inconsistent numbers of samples: %r"
#     334         % [int(l) for l in lengths]
#     335     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [481, 300]

# %%
ch = df.drop(columns=['Kelembaban','Suhu'])

# %%
ch.plot()
# Out:
# <AxesSubplot:xlabel='Tanggal'>

# %%
# Tentukan proporsi pembagian
train_size = int(len(ch) * 0.8)

# Membagi data
train = df.iloc[:train_size]
test = df.iloc[train_size:]

# %%
train.tail()
# Out:
#             Curah_Hujan  Kelembaban   Suhu
# Tanggal
# 25-04-2018        14.80       75.75  30.26
# 25-04-2019        11.53       88.50  27.99
# 25-04-2020         5.29       81.25  29.31
# 25-04-2021         0.14       80.06  29.19
# 25-04-2022         7.14       77.75  29.91

# %%
hwmodel=ExponentialSmoothing(train.Curah_Hujan, trend='add', seasonal='add', seasonal_periods=4).fit()
# Out:
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-02-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-02-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-03-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-04-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-06-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-07-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '13-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-02-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-02-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-03-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-04-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-06-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-07-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '14-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-02-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-02-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-03-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-04-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-04-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-05-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-05-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-05-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-05-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-05-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-05-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-05-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-06-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-06-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-06-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-06-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-06-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '15-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# ...
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-06-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-06-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-06-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-07-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-07-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-07-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-07-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-07-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-07-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-08-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-08-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-08-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-09-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-09-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-09-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-09-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-09-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-10-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-10-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-10-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-11-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-11-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-11-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-12-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-12-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-12-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '24-12-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-01-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-01-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-01-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-01-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-02-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-02-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-02-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-02-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-02-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-02-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-03-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-03-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-03-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-03-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-03-2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-03-2024' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-04-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-04-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-04-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-04-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:557: UserWarning: Parsing '25-04-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   _index = to_datetime(index)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\anaconda2\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
test_pred=hwmodel.forecast(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 test_pred=hwmodel.forecast(5)
#
# NameError: name 'hwmodel' is not defined

# %%
decompose_result = seasonal_decompose(ch['Curah_Hujan'],model='multiplicative')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 decompose_result = seasonal_decompose(ch['Curah_Hujan'],model='multiplicative')
#
# File D:\anaconda2\lib\site-packages\statsmodels\tsa\seasonal.py:149, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     147 if model.startswith("m"):
#     148     if np.any(x <= 0):
# --> 149         raise ValueError(
#     150             "Multiplicative seasonality is not appropriate "
#     151             "for zero and negative values"
#     152         )
#     154 if period is None:
#     155     if pfreq is not None:
#
# ValueError: Multiplicative seasonality is not appropriate for zero and negative values

# %%
ch = ch.set_index('Tanggal')

# %%
plt.figure(figsize=(20, 5))
plt.plot(ch.index,ch['Curah Hujan'])

# Menambahkan judul dan label
plt.title('Plot Time Series Nilai Harian')
plt.xlabel('Tanggal')
plt.ylabel('Curah Hujan')
# Out:
# Text(0, 0.5, 'Curah Hujan')

# %%
ch.sort_index(inplace = TRUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 ch.sort_index(inplace = TRUE)
#
# NameError: name 'TRUE' is not defined

# %%
from forecast import plot_components_x13
plot_components_x13(ch)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 from forecast import plot_components_x13
#       2 plot_components_x13(ch)
#       3 plt.show()
#
# ModuleNotFoundError: No module named 'forecast'

# %%
decompose_result = seasonal_decompose(ch['Curah Hujan'], model = 'aditive')
decompose_result.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 decompose_result = seasonal_decompose(ch['Curah Hujan'], model = 'aditive')
#       2 decompose_result.plot()
#
# File D:\anaconda2\lib\site-packages\statsmodels\tsa\seasonal.py:159, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157         period = pfreq
#     158     else:
# --> 159         raise ValueError(
#     160             "You must specify a period or x must be a pandas object with "
#     161             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162         )
#     163 if x.shape[0] < 2 * pfreq:
#     164     raise ValueError(
#     165         f"x must have 2 complete cycles requires {2 * pfreq} "
#     166         f"observations. x only has {x.shape[0]} observation(s)"
#     167     )
#
# ValueError: You must specify a period or x must be a pandas object with a PeriodIndex or a DatetimeIndex with a freq not set to None

# %%
ch = ch['Curah Hujan'].plot(figsize=(20,5))
plt.show()

# %%
df_decompose = seasonal_decompose(df['SST'],model = "additive")
fig = df_decompose.plot()
fig.set_size_inches(16,9)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df_decompose = seasonal_decompose(df['SST'],model = "additive")
#       2 fig = df_decompose.plot()
#       3 fig.set_size_inches(16,9)
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
size = int(len(df)*0.8)
train_df = df[:size]
test_df = df[size:]

# %%
train_df.tail()
# Out:
#                SST
# Tahun
# 2010-08-01  880.24
# 2010-09-01  860.53
# 2010-10-01  896.96
# 2010-11-01  882.95
# 2010-12-01  919.93

# %%
train_df['SST'].plot(legend=True, label="Train", figsize=(20,5))
test_df['SST'].plot(legend=True, label="Test")
predictions_df.plot(legend=True, label="Prediction")
plt.title("Model Result", size=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 train_df['SST'].plot(legend=True, label="Train", figsize=(20,5))
#       2 test_df['SST'].plot(legend=True, label="Test")
# ----> 3 predictions_df.plot(legend=True, label="Prediction")
#       4 plt.title("Model Result", size=20)
#       5 plt.show()
#
# NameError: name 'predictions_df' is not defined

# %%
fitted_model = ExponentialSmoothing(train_df['SST'], trend='add', seasonal='add', seasonal_periods=12)
predictions_df = fitted_model.forecast(60)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 fitted_model = ExponentialSmoothing(train_df['SST'], trend='add', seasonal='add', seasonal_periods=12)
# ----> 2 predictions_df = fitted_model.forecast(60)
#
# AttributeError: 'ExponentialSmoothing' object has no attribute 'forecast'
